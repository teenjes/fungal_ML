# %%
import pandas as pd
from Bio import SeqIO
import numpy as np
import os
import random

# %% [markdown]
# Ideas of the program would be:
#
# - want to read in reference_dataframe.csv
#
# - taxonomic level e.g. genus=Candida -> species level comparision
#
# - path to location of data. Root of analysis/.....

# %% [markdown]
# With arg parse
#
# ref_df_fn = args.ref_df_fn
# data_root = args.data_root
# tax_rank = args.tax_rank #use with flag e.g. -r
# name = args.name #name of the rank to select from, use flag e.g. -n

# %%
ref_df_fn = '../../analysis/Stats/reference_dataframe.csv'
ref_df_fn = os.path.abspath(ref_df_fn)

# %%
try:
    os.path.exists(ref_df_fn)
except:
    print('Cannot find %s' % ref_df_fn)

# %%
#to be able to handle anything from command lien
tax_rank = 'family'
name = 'Saccharomycetaceae'

# %%
n_reads = 15000

# %%
name = name.lower()
tax_rank = tax_rank.lower()

# %%
ref_df = pd.read_csv(ref_df_fn, index_col=None)

# %%
ref_df[ref_df["# reads after length filtering"] < n_reads].shape[0]

# %%
try:
    if ref_df[ref_df["# reads after length filtering"] \
              < n_reads].shape[0] >0 :
        print("These species need more reads.")
        print(ref_df[ref_df["# reads after length filtering"] \
              < n_reads])
        #exit()
except:
    print('Check %s to have the wanted column names' % ref_df_fn)

# %%
#not neccessary pull from command line
# name = "Trichocomaceae"
data_root = '../../'

# %%
indecies = ref_df[ref_df[tax_rank] == name].index

# %%
indecies

# %%
SeqIO_dicts = {}
for index in indecies:
    fasta_path = os.path.join(data_root, ref_df.loc[index, 'path to length filtering'])
    print(fasta_path)
    try:
        SeqIO_dicts[index] = SeqIO.to_dict(SeqIO.parse(fasta_path, 'fasta'))
    except:
        print('Check location of fasta files.')

# %%
def max_seq_len(SeqIO_dict):
    """
    Fucntion takes a SeqIO_dict and returns the lenghts of the
    longest sequence.
    """
    total_lens = []
    for key in SeqIO_dict.keys():
        total_lens.append(len(SeqIO_dict[key].seq))
    return max(total_lens)

# %%
def numberfi(SeqIO_dict, seq_len, nsubsample):
    """
    Take SeqIO_dict and return SeqIO_dict were bases have been replaced
    with numbers
    ACGT- to 01234
    Take the seq_len each sequence should have.
    """
    num_dict = {}
    
    keys = list(SeqIO_dict.keys())
    randkeys = random.sample(keys, k= nsubsample)
    
    
    for key in randkeys:
        seq = str(SeqIO_dict[key].seq).replace("A",'0 ')\
        .replace("C",'1 ').replace("G",'2 ').replace("T",'3 ')
        seq_new = seq + '4 '*(seq_len -int(len(seq)/2))
        num_dict[key] = list(map(int, seq_new.split(' ')[:-1]))
    return num_dict

# %%
total_lens = []
for key, value in SeqIO_dicts.items():
    total_lens.append(max_seq_len(value))
print("This is the maximum sequence length of all sampled sequences.")
print(total_lens)

numSeqIO_dicts = {}
max_len = max(total_lens)
for key, value in SeqIO_dicts.items():
    numSeqIO_dicts[key] = numberfi(value, max_len, s_reads)

seq_list = []
for index in indecies:
    seq_list.append(np.array(list(numSeqIO_dicts[index].values())))
seq_comb = np.concatenate(seq_list, axis = 0)

# %%
num_class = len(numSeqIO_dicts.keys())
ids_comb = np.zeros( (n_reads*num_class,num_class) )
for i in range(0, num_class):
    ids_comb[i*n_reads:(i+1)*n_reads,i] = 1

# %%
num_class = 5
ids_comb = np.zeros( (n_reads*num_class,num_class) )

# %%
for i in range(0, num_class):
    ids_comb[i*n_reads:(i+1)*n_reads,i] = 1

# %%
ids_comb

# %%
ref_df.head()

# %%
ref_df[tax_rank] == 'Candida'

# %%
ref_df.head()

# %%
location = (ref_df.columns.get_loc(tax_rank)-1)

# %%
classes = ref_df.iloc[indecies,location].unique()

# %%
count_dict = {}
for item in classes:
    count_dict[item] = sum(ref_df.iloc[:,location] == item)

# %%
classes

# %%
count_dict

# %%
for item in count_dict.keys():
    print(n_reads/count_dict[item])

# %%
# define n_reads

min_vals = []
for key, value in count_dict.items():
    if value == min(count_dict.values()):
        min_vals.append(ref_df[ref_df.iloc[:,location] == item]['# reads after length filtering'].min())
min(min_vals)

# %%
max_reads = 0
for key, value in count_dict.items():
    if value == max(count_dict.values()):
        max_reads = value*n_reads

# %%
max_reads

# %%
min_vals = [44999]

# %%
# is max_reads < min_reads?
# if yes, use max_reads to subsample as base value

# %%
if max_reads <= min(min_vals):
    for key, value in count_dict.items():
        s_reads = int(max_reads/value)
        print(key, s_reads)
else:
    for key, value in count_dict.items():
        s_reads = int(min(min_vals)/value)
        print(key, s_reads)

# %%
location = (ref_df.columns.get_loc(tax_rank)-1)
col_name = ref_df.columns[location]

classes = ref_df.iloc[indecies,location].unique()

count_dict = {}
for item in classes:
    count_dict[item] = sum(ref_df.iloc[:,location] == item)

min_vals = []
for key, value in count_dict.items():
    if value == min(count_dict.values()):
        min_vals.append(ref_df[ref_df.iloc[:,location] == item]['# reads after length filtering'].min())
minimum_value = min(min_vals)

max_reads = 0
for key, value in count_dict.items():
    if value == max(count_dict.values()):
        max_reads = value*n_reads

if max_reads <= minimum_value:
    minimum_value = max_reads
for key, n_class in count_dict.items():
    s_reads = int(minimum_value/n_class)
    if ref_df[ref_df.loc[:,col_name]==key]['# reads after length filtering'].min() < s_reads:
        minimum_value = ref_df[ref_df.loc[:,col_name]==key]['# reads after length filtering'].min()/n_class
        s_reads = int(minimum_value/n_class)
    print(key, s_reads)
    
# parse s_reads into numberfy

# %%
tax_ranks = ref_df.columns[2:-6]
print(tax_ranks)
# Out:
# Index(['genus', 'family', 'order', 'class', 'phylum', 'kingdom'], dtype='object')

# %%
for tax_rank in tax_ranks:
    print(tax_rank + "\n\n")
    for name in ref_df[tax_rank].unique():
        total_class_reads = []
        
        print("\n\n"+name)
        indecies = ref_df[ref_df[tax_rank] == name].index
        location = (ref_df.columns.get_loc(tax_rank)-1)
        col_name = ref_df.columns[location]

        classes = ref_df.iloc[indecies,location].unique()
        print(classes)

        count_dict = {}
        for class_ in classes:
            count_dict[class_] = sum(ref_df.iloc[indecies,location] == class_)
        print(count_dict)

        min_vals = []
        for class_, n_class in count_dict.items():
            if n_class == min(count_dict.values()):
                min_vals.append(ref_df[ref_df.iloc[:,location] == class_]['# reads after length filtering'].min())
        if min(min_vals) % 2 == 0:
            minimum_value = min(min_vals)
        else:
            minimum_value = min(min_vals)-1
        print("minimum_value =", minimum_value)
        
        if len(count_dict) > 1:
            max_reads = 0
            for key, value in count_dict.items():
                if value == max(count_dict.values()):
                    max_reads = value*n_reads

            if max_reads <= minimum_value:
                minimum_value = max_reads
                
            for key, n_class in count_dict.items():
                s_reads = int(minimum_value/n_class)
                if ref_df[ref_df.loc[:,col_name]==key]['# reads after length filtering'].min() < s_reads:
                    minimum_value = ref_df[ref_df.loc[:,col_name]==key]['# reads after length filtering'].min()/n_class
                    s_reads = int(minimum_value/n_class)
                print(key, s_reads)
                total_class_reads.append(s_reads*n_class)
            print(total_class_reads)
        elif len(count_dict) == 1:
            s_reads = n_reads
            print(s_reads)
#             print("no comparison for the rank")
#             exit()

        # parse s_reads into numberfy
# Out:
# genus
#
#
#
#
# puccinia
# ['striiformis-tritici']
# {'striiformis-tritici': 1}
# minimum_value = 113336
# 15000
#
#
# zymoseptoria
# ['tritici']
# {'tritici': 1}
# minimum_value = 133088
# 15000
#
#
# pyrenophora
# ['tritici-repentis']
# {'tritici-repentis': 1}
# minimum_value = 90014
# 15000
#
#
# fusarium
# ['oxysporum']
# {'oxysporum': 1}
# minimum_value = 123742
# 15000
#
#
# tuber
# ['brumale']
# {'brumale': 1}
# minimum_value = 74232
# 15000
#
#
# cortinarius
# ['globuliformis']
# {'globuliformis': 1}
# minimum_value = 117090
# 15000
#
#
# aspergillus
# ['niger' 'flavus' 'unidentified']
# {'niger': 1, 'flavus': 1, 'unidentified': 1}
# minimum_value = 25916
# niger 15000
# flavus 15000
# unidentified 15000
# [15000, 15000, 15000]
#
#
# clavispora
# ['lusitaniae']
# {'lusitaniae': 1}
# minimum_value = 131936
# 15000
#
#
# kluyveromyces
# ['unidentified' 'marxianus']
# {'unidentified': 1, 'marxianus': 1}
# minimum_value = 25916
# unidentified 15000
# marxianus 15000
# [15000, 15000]
#
#
# penicillium
# ['chrysogenum']
# {'chrysogenum': 1}
# minimum_value = 72306
# 15000
#
#
# rhodotorula
# ['mucilaginosa']
# {'mucilaginosa': 1}
# minimum_value = 117800
# 15000
#
#
# scedosporium
# ['boydii']
# {'boydii': 1}
# minimum_value = 93722
# 15000
#
#
# blastobotrys
# ['proliferans']
# {'proliferans': 1}
# minimum_value = 37314
# 15000
#
#
# debaryomyces
# ['unidentified']
# {'unidentified': 1}
# minimum_value = 25916
# 15000
#
#
# galactomyces
# ['geotrichum']
# {'geotrichum': 1}
# minimum_value = 7804
# 15000
#
#
# kodamaea
# ['ohmeri']
# {'ohmeri': 1}
# minimum_value = 36478
# 15000
#
#
# meyerozyma
# ['guillermondii']
# {'guillermondii': 1}
# minimum_value = 18944
# 15000
#
#
# wickerhamomyces
# ['anomalus']
# {'anomalus': 1}
# minimum_value = 42588
# 15000
#
#
# yamadazyma
# ['mexicana' 'scolyti']
# {'mexicana': 1, 'scolyti': 1}
# minimum_value = 34840
# mexicana 15000
# scolyti 15000
# [15000, 15000]
#
#
# yarrowia
# ['lipolytica']
# {'lipolytica': 1}
# minimum_value = 33872
# 15000
#
#
# zygoascus
# ['hellenicus']
# {'hellenicus': 1}
# minimum_value = 34002
# 15000
#
#
# cryptococcus
# ['zero' 'gattii']
# {'zero': 1, 'gattii': 1}
# minimum_value = 23660
# zero 15000
# gattii 15000
# [15000, 15000]
#
#
# diaporthe
# ['ccl067' 'unidentified']
# {'ccl067': 1, 'unidentified': 1}
# minimum_value = 25916
# ccl067 15000
# unidentified 15000
# [15000, 15000]
#
#
# oculimacula
# ['yallundae-ccl031' 'yallundae-ccl029']
# {'yallundae-ccl031': 1, 'yallundae-ccl029': 1}
# minimum_value = 49480
# yallundae-ccl031 15000
# yallundae-ccl029 15000
# [15000, 15000]
#
#
# dothiorella
# ['vidmadera']
# {'vidmadera': 1}
# minimum_value = 44256
# 15000
#
#
# quambalaria
# ['cyanescens']
# {'cyanescens': 1}
# minimum_value = 46170
# 15000
#
#
# entoleuca
# ['unidentified']
# {'unidentified': 1}
# minimum_value = 25916
# 15000
#
#
# asteroma
# ['ccl060' 'ccl068']
# {'ccl060': 1, 'ccl068': 1}
# minimum_value = 31996
# ccl060 15000
# ccl068 15000
# [15000, 15000]
#
#
# saccharomyces
# ['cerevisiae']
# {'cerevisiae': 1}
# minimum_value = 30260
# 15000
#
#
# cladophialophora
# ['unidentified']
# {'unidentified': 1}
# minimum_value = 25916
# 15000
#
#
# candida
# ['albicans' 'metapsilosis' 'orthopsilosis' 'parapsilosis' 'unidentified']
# {'albicans': 1, 'metapsilosis': 1, 'orthopsilosis': 1, 'parapsilosis': 1, 'unidentified': 1}
# minimum_value = 25596
# albicans 15000
# metapsilosis 15000
# orthopsilosis 15000
# parapsilosis 15000
# unidentified 15000
# [15000, 15000, 15000, 15000, 15000]
#
#
# geotrichum
# ['candidum']
# {'candidum': 1}
# minimum_value = 27094
# 15000
#
#
# pichia
# ['kudriavzevii' 'membranifaciens']
# {'kudriavzevii': 1, 'membranifaciens': 1}
# minimum_value = 26936
# kudriavzevii 15000
# membranifaciens 15000
# [15000, 15000]
# family
#
#
#
#
# pucciniaceae
# ['puccinia']
# {'puccinia': 1}
# minimum_value = 113336
# 15000
#
#
# mycosphaerellaceae
# ['zymoseptoria']
# {'zymoseptoria': 1}
# minimum_value = 133088
# 15000
#
#
# pleosporaceae
# ['pyrenophora']
# {'pyrenophora': 1}
# minimum_value = 90014
# 15000
#
#
# nectriaceae
# ['fusarium']
# {'fusarium': 1}
# minimum_value = 123742
# 15000
#
#
# tuberaceae
# ['tuber']
# {'tuber': 1}
# minimum_value = 74232
# 15000
#
#
# cortinariaceae
# ['cortinarius']
# {'cortinarius': 1}
# minimum_value = 117090
# 15000
#
#
# trichocomaceae
# ['aspergillus' 'penicillium']
# {'aspergillus': 3, 'penicillium': 1}
# minimum_value = 72306
# aspergillus 15000
# penicillium 45000
# [45000, 45000]
#
#
# metschnikowiaceae
# ['clavispora' 'kodamaea']
# {'clavispora': 1, 'kodamaea': 1}
# minimum_value = 36478
# clavispora 15000
# kodamaea 15000
# [15000, 15000]
#
#
# saccharomycetaceae
# ['kluyveromyces' 'saccharomyces' 'candida']
# {'kluyveromyces': 2, 'saccharomyces': 1, 'candida': 5}
# minimum_value = 30260
# kluyveromyces 15130
# saccharomyces 30260
# candida 6052
# [30260, 30260, 30260]
#
#
# sporidiobolaceae
# ['rhodotorula']
# {'rhodotorula': 1}
# minimum_value = 117800
# 15000
#
#
# microascaceae
# ['scedosporium']
# {'scedosporium': 1}
# minimum_value = 93722
# 15000
#
#
# trichomonascaceae
# ['blastobotrys' 'zygoascus']
# {'blastobotrys': 1, 'zygoascus': 1}
# minimum_value = 34002
# blastobotrys 15000
# zygoascus 15000
# [15000, 15000]
#
#
# debaryomycetaceae
# ['debaryomyces' 'meyerozyma' 'yamadazyma']
# {'debaryomyces': 1, 'meyerozyma': 1, 'yamadazyma': 2}
# minimum_value = 18944
# debaryomyces 18944
# meyerozyma 18944
# yamadazyma 9472
# [18944, 18944, 18944]
#
#
# dipodascaceae
# ['galactomyces' 'yarrowia' 'geotrichum']
# {'galactomyces': 1, 'yarrowia': 1, 'geotrichum': 1}
# minimum_value = 7804
# galactomyces 7804
# yarrowia 7804
# geotrichum 7804
# [7804, 7804, 7804]
#
#
# phaffomycetaceae
# ['wickerhamomyces']
# {'wickerhamomyces': 1}
# minimum_value = 42588
# 15000
#
#
# tremellaceae
# ['cryptococcus']
# {'cryptococcus': 2}
# minimum_value = 23660
# 15000
#
#
# diaporthaceae
# ['diaporthe']
# {'diaporthe': 2}
# minimum_value = 27940
# 15000
#
#
# dermateaceae
# ['oculimacula']
# {'oculimacula': 2}
# minimum_value = 49480
# 15000
#
#
# botryosphaeriaceae
# ['dothiorella']
# {'dothiorella': 1}
# minimum_value = 44256
# 15000
#
#
# quambalariaceae
# ['quambalaria']
# {'quambalaria': 1}
# minimum_value = 46170
# 15000
#
#
# xylariaceae
# ['entoleuca']
# {'entoleuca': 1}
# minimum_value = 31356
# 15000
#
#
# gnomoniaceae
# ['asteroma']
# {'asteroma': 2}
# minimum_value = 31996
# 15000
#
#
# herpotrichiellaceae
# ['cladophialophora']
# {'cladophialophora': 1}
# minimum_value = 25916
# 15000
#
#
# pichiaceae
# ['pichia']
# {'pichia': 2}
# minimum_value = 26936
# 15000
# order
#
#
#
#
# pucciniales
# ['pucciniaceae']
# {'pucciniaceae': 1}
# minimum_value = 113336
# 15000
#
#
# capnodiales
# ['mycosphaerellaceae']
# {'mycosphaerellaceae': 1}
# minimum_value = 133088
# 15000
#
#
# pleosporales
# ['pleosporaceae']
# {'pleosporaceae': 1}
# minimum_value = 90014
# 15000
#
#
# hypocreales
# ['nectriaceae']
# {'nectriaceae': 1}
# minimum_value = 123742
# 15000
#
#
# pezizales
# ['tuberaceae']
# {'tuberaceae': 1}
# minimum_value = 74232
# 15000
#
#
# agaricales
# ['cortinariaceae']
# {'cortinariaceae': 1}
# minimum_value = 117090
# 15000
#
#
# eurotiales
# ['trichocomaceae']
# {'trichocomaceae': 4}
# minimum_value = 39988
# 15000
#
#
# saccharomycetales
# ['metschnikowiaceae' 'saccharomycetaceae' 'trichomonascaceae'
#  'debaryomycetaceae' 'dipodascaceae' 'phaffomycetaceae' 'pichiaceae']
# {'metschnikowiaceae': 2, 'saccharomycetaceae': 8, 'trichomonascaceae': 2, 'debaryomycetaceae': 4, 'dipodascaceae': 3, 'phaffomycetaceae': 1, 'pichiaceae': 2}
# minimum_value = 42588
# metschnikowiaceae 21294
# saccharomycetaceae 5323
# trichomonascaceae 21294
# debaryomycetaceae 10647
# dipodascaceae 867
# phaffomycetaceae 2601
# pichiaceae 1300
# [42588, 42584, 42588, 42588, 2601, 2601, 2600]
#
#
# sporidiobolales
# ['sporidiobolaceae']
# {'sporidiobolaceae': 1}
# minimum_value = 117800
# 15000
#
#
# microascales
# ['microascaceae']
# {'microascaceae': 1}
# minimum_value = 93722
# 15000
#
#
# tremellales
# ['tremellaceae']
# {'tremellaceae': 2}
# minimum_value = 23660
# 15000
#
#
# diaporthales
# ['diaporthaceae' 'gnomoniaceae']
# {'diaporthaceae': 2, 'gnomoniaceae': 2}
# minimum_value = 27940
# diaporthaceae 13970
# gnomoniaceae 13970
# [27940, 27940]
#
#
# helotiales
# ['dermateaceae']
# {'dermateaceae': 2}
# minimum_value = 49480
# 15000
#
#
# botryosphaeriales
# ['botryosphaeriaceae']
# {'botryosphaeriaceae': 1}
# minimum_value = 44256
# 15000
#
#
# microstromatales
# ['quambalariaceae']
# {'quambalariaceae': 1}
# minimum_value = 46170
# 15000
#
#
# xylariales
# ['xylariaceae']
# {'xylariaceae': 1}
# minimum_value = 31356
# 15000
#
#
# chaetothyriales
# ['herpotrichiellaceae']
# {'herpotrichiellaceae': 1}
# minimum_value = 25916
# 15000
# class
#
#
#
#
# pucciniomycetes
# ['pucciniales']
# {'pucciniales': 1}
# minimum_value = 113336
# 15000
#
#
# dothideomycetes
# ['capnodiales' 'pleosporales' 'botryosphaeriales']
# {'capnodiales': 1, 'pleosporales': 1, 'botryosphaeriales': 1}
# minimum_value = 44256
# capnodiales 15000
# pleosporales 15000
# botryosphaeriales 15000
# [15000, 15000, 15000]
#
#
# sordariomycetes
# ['hypocreales' 'microascales' 'diaporthales' 'xylariales']
# {'hypocreales': 1, 'microascales': 1, 'diaporthales': 4, 'xylariales': 1}
# minimum_value = 31356
# hypocreales 31356
# microascales 31356
# diaporthales 7839
# xylariales 31356
# [31356, 31356, 31356, 31356]
#
#
# pezizomycetes
# ['pezizales']
# {'pezizales': 1}
# minimum_value = 74232
# 15000
#
#
# agaricomyctes
# ['agaricales']
# {'agaricales': 1}
# minimum_value = 117090
# 15000
#
#
# eurotiomycetes
# ['eurotiales' 'chaetothyriales']
# {'eurotiales': 4, 'chaetothyriales': 1}
# minimum_value = 25916
# eurotiales 6479
# chaetothyriales 25916
# [25916, 25916]
#
#
# saccharomycetes
# ['saccharomycetales']
# {'saccharomycetales': 22}
# minimum_value = 7804
# 15000
#
#
# microbotryomycetes
# ['sporidiobolales']
# {'sporidiobolales': 1}
# minimum_value = 117800
# 15000
#
#
# tremellomycetes
# ['tremellales']
# {'tremellales': 2}
# minimum_value = 23660
# 15000
#
#
# leotiomycetes
# ['helotiales']
# {'helotiales': 2}
# minimum_value = 49480
# 15000
#
#
# exobasidiomycetes
# ['microstromatales']
# {'microstromatales': 1}
# minimum_value = 46170
# 15000
# phylum
#
#
#
#
# basidiomycota
# ['pucciniomycetes' 'agaricomyctes' 'microbotryomycetes' 'tremellomycetes'
#  'exobasidiomycetes']
# {'pucciniomycetes': 1, 'agaricomyctes': 1, 'microbotryomycetes': 1, 'tremellomycetes': 2, 'exobasidiomycetes': 1}
# minimum_value = 46170
# pucciniomycetes 30000
# agaricomyctes 30000
# microbotryomycetes 30000
# tremellomycetes 15000
# exobasidiomycetes 30000
# [30000, 30000, 30000, 30000, 30000]
#
#
# ascomycota
# ['dothideomycetes' 'sordariomycetes' 'pezizomycetes' 'eurotiomycetes'
#  'saccharomycetes' 'leotiomycetes']
# {'dothideomycetes': 3, 'sordariomycetes': 7, 'pezizomycetes': 1, 'eurotiomycetes': 5, 'saccharomycetes': 22, 'leotiomycetes': 2}
# minimum_value = 74232
# dothideomycetes 24744
# sordariomycetes 10604
# pezizomycetes 74232
# eurotiomycetes 14846
# saccharomycetes 3374
# leotiomycetes 37116
# [74232, 74228, 74232, 74230, 74228, 74232]
# kingdom
#
#
#
#
# fungi
# ['basidiomycota' 'ascomycota']
# {'basidiomycota': 6, 'ascomycota': 40}
# minimum_value = 23660
# basidiomycota 3943
# ascomycota 591
# [23658, 23640]
