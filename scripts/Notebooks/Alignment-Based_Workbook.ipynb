# %% [markdown]
# ### Notebook to analyzse the efficiency of minimap2 mapping for Oxford Nanopore MinION reads against Consensus Database

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd
import json

# %%
reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/reference_dataframe.csv')
max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/custom_database_labelled.fasta')
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_qiime.csv')

# %%
#threads to use
threads = 6

# %%
INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping_mock_gsref')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis-tritici',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']

species_delete = [
# 'Candida_orthopsilosis',
#                  'Candida_metapsilosis',
#                  'Aspergillus_niger'
]

mock_community = ['Puccinia_striiformis-tritici',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']

# %%
ref_df = pd.read_csv(reference_dataframe_fn)
ref_df['name_species'] = ref_df['genus'] +"_"+ ref_df['species']

# %%
ref_df.name_species.tolist()
# Out:
# ['puccinia_striiformis-tritici',
#  'zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis',
#  'fusarium_oxysporum',
#  'tuber_brumale',
#  'cortinarius_globuliformis',
#  'aspergillus_niger',
#  'clavispora_lusitaniae',
#  'kluyveromyces_unidentified',
#  'penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa',
#  'scedosporium_boydii',
#  'blastobotrys_proliferans',
#  'debaryomyces_unidentified',
#  'galactomyces_geotrichum',
#  'kodamaea_ohmeri',
#  'meyerozyma_guilliermondii',
#  'wickerhamomyces_anomalus',
#  'yamadazyma_mexicana',
#  'yamadazyma_scolyti',
#  'yarrowia_lipolytica',
#  'zygoascus_hellenicus',
#  'aspergillus_flavus',
#  'cryptococcus_zero',
#  'aspergillus_unidentified',
#  'diaporthe_ccl067',
#  'diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031',
#  'oculimacula_yallundae-ccl029',
#  'dothiorella_vidmadera',
#  'quambalaria_cyanescens',
#  'entoleuca_unidentified',
#  'asteroma_ccl060',
#  'asteroma_ccl068',
#  'saccharomyces_cerevisiae',
#  'cladophialophora_unidentified',
#  'candida_albicans',
#  'candida_metapsilosis',
#  'candida_orthopsilosis',
#  'candida_parapsilosis',
#  'candida_unidentified',
#  'kluyveromyces_marxianus',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens']

# %%
new_db_fn = os.path.join(OUT_DIR, 'gsref.db.fasta')

# %%
new_db_list = []
old_db_list = []
for seq in SeqIO.parse(max_custom_database_fn, 'fasta'):
    old_db_list.append(seq.id)
    if seq.id.lower() in ref_df.name_species.tolist():
        #print(seq.id)
        seq.id = seq.name = seq.description = seq.id.lower()
        new_db_list.append(seq)
    else:
        print(seq.id)

# %%
if len(new_db_list) == len(old_db_list):
    SeqIO.write(new_db_list, new_db_fn, 'fasta')
else:
    print("please check!")

# %%
sub_db_fn = os.path.join(OUT_DIR, 'gsref.subdb.fasta')
sub_db_list = []
for seq in new_db_list:
    if seq.id not in [x.lower() for x in species_delete]:
        sub_db_list.append(seq)

# %%
if len(sub_db_list) + len(species_delete) == len(new_db_list):
    SeqIO.write(sub_db_list, sub_db_fn, 'fasta' )
else:
    print("please check!")

# %%
[x.id for x in sub_db_list]
# Out:
# ['puccinia_striiformis-tritici',
#  'zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis',
#  'fusarium_oxysporum',
#  'tuber_brumale',
#  'cortinarius_globuliformis',
#  'aspergillus_niger',
#  'clavispora_lusitaniae',
#  'kluyveromyces_unidentified',
#  'penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa',
#  'scedosporium_boydii',
#  'blastobotrys_proliferans',
#  'debaryomyces_unidentified',
#  'galactomyces_geotrichum',
#  'kodamaea_ohmeri',
#  'meyerozyma_guilliermondii',
#  'wickerhamomyces_anomalus',
#  'yamadazyma_mexicana',
#  'yamadazyma_scolyti',
#  'yarrowia_lipolytica',
#  'zygoascus_hellenicus',
#  'aspergillus_flavus',
#  'cryptococcus_zero',
#  'aspergillus_unidentified',
#  'diaporthe_ccl067',
#  'diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031',
#  'oculimacula_yallundae-ccl029',
#  'dothiorella_vidmadera',
#  'quambalaria_cyanescens',
#  'entoleuca_unidentified',
#  'asteroma_ccl060',
#  'asteroma_ccl068',
#  'saccharomyces_cerevisiae',
#  'cladophialophora_unidentified',
#  'candida_albicans',
#  'candida_metapsilosis',
#  'candida_orthopsilosis',
#  'candida_parapsilosis',
#  'candida_unidentified',
#  'kluyveromyces_marxianus',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens']

# %%
mock_community = [x.lower() for x in mock_community]

# %%
mock_community
# Out:
# ['puccinia_striiformis-tritici',
#  'zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis',
#  'fusarium_oxysporum',
#  'tuber_brumale',
#  'cortinarius_globuliformis',
#  'aspergillus_niger',
#  'clavispora_lusitaniae',
#  'kluyveromyces_unidentified',
#  'penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa',
#  'scedosporium_boydii',
#  'blastobotrys_proliferans',
#  'debaryomyces_unidentified',
#  'galactomyces_geotrichum',
#  'kodamaea_ohmeri',
#  'meyerozyma_guilliermondii',
#  'wickerhamomyces_anomalus',
#  'yamadazyma_mexicana',
#  'yamadazyma_scolyti',
#  'yarrowia_lipolytica',
#  'zygoascus_hellenicus',
#  'aspergillus_flavus',
#  'cryptococcus_zero',
#  'aspergillus_unidentified',
#  'diaporthe_ccl067',
#  'diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031',
#  'oculimacula_yallundae-ccl029',
#  'dothiorella_vidmadera',
#  'quambalaria_cyanescens',
#  'entoleuca_unidentified',
#  'asteroma_ccl060',
#  'asteroma_ccl068',
#  'saccharomyces_cerevisiae',
#  'cladophialophora_unidentified',
#  'candida_albicans',
#  'candida_metapsilosis',
#  'candida_orthopsilosis',
#  'candida_parapsilosis',
#  'candida_unidentified',
#  'kluyveromyces_marxianus',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens']

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 15000

# %%
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)

# %%
ref_df.columns
# Out:
# Index(['Unnamed: 0', 'species', 'genus', 'family', 'order', 'class', 'phylum',
#        'kingdom', '# raw reads', '# reads after homology filtering',
#        '# reads after length filtering', '# for use', 'path to raw reads',
#        'path to homology filtering', 'path to length filtering',
#        'path for use', 'name_species'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# {'puccinia_striiformis-tritici': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode01/length_restricted_for_use.fasta',
#  'zymoseptoria_tritici': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode02/length_restricted_for_use.fasta',
#  'pyrenophora_tritici-repentis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode03/length_restricted_for_use.fasta',
#  'fusarium_oxysporum': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode04/length_restricted_for_use.fasta',
#  'tuber_brumale': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode05/length_restricted_for_use.fasta',
#  'cortinarius_globuliformis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode06/length_restricted_for_use.fasta',
#  'aspergillus_niger': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta',
#  'clavispora_lusitaniae': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode08/length_restricted_for_use.fasta',
#  'kluyveromyces_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode09/length_restricted_for_use.fasta',
#  'penicillium_chrysogenum': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode10/length_restricted_for_use.fasta',
#  'rhodotorula_mucilaginosa': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode11/length_restricted_for_use.fasta',
#  'scedosporium_boydii': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode12/length_restricted_for_use.fasta',
#  'blastobotrys_proliferans': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode01/length_restricted_for_use.fasta',
#  'debaryomyces_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode02/length_restricted_for_use.fasta',
#  'galactomyces_geotrichum': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode03/length_restricted_for_use.fasta',
#  'kodamaea_ohmeri': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode04/length_restricted_for_use.fasta',
#  'meyerozyma_guilliermondii': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode05/length_restricted_for_use.fasta',
#  'wickerhamomyces_anomalus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode06/length_restricted_for_use.fasta',
#  'yamadazyma_mexicana': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode07/length_restricted_for_use.fasta',
#  'yamadazyma_scolyti': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode08/length_restricted_for_use.fasta',
#  'yarrowia_lipolytica': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode09/length_restricted_for_use.fasta',
#  'zygoascus_hellenicus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode11/length_restricted_for_use.fasta',
#  'aspergillus_flavus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta',
#  'cryptococcus_zero': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode01/length_restricted_for_use.fasta',
#  'aspergillus_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode02/length_restricted_for_use.fasta',
#  'diaporthe_ccl067': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode03/length_restricted_for_use.fasta',
#  'diaporthe_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode04/length_restricted_for_use.fasta',
#  'oculimacula_yallundae-ccl031': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode05/length_restricted_for_use.fasta',
#  'oculimacula_yallundae-ccl029': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode06/length_restricted_for_use.fasta',
#  'dothiorella_vidmadera': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode07/length_restricted_for_use.fasta',
#  'quambalaria_cyanescens': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode08/length_restricted_for_use.fasta',
#  'entoleuca_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode09/length_restricted_for_use.fasta',
#  'asteroma_ccl060': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode11/length_restricted_for_use.fasta',
#  'asteroma_ccl068': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode12/length_restricted_for_use.fasta',
#  'saccharomyces_cerevisiae': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode01/length_restricted_for_use.fasta',
#  'cladophialophora_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode02/length_restricted_for_use.fasta',
#  'candida_albicans': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta',
#  'candida_metapsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta',
#  'candida_orthopsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta',
#  'candida_parapsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode06/length_restricted_for_use.fasta',
#  'candida_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode09/length_restricted_for_use.fasta',
#  'kluyveromyces_marxianus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode10/length_restricted_for_use.fasta',
#  'pichia_kudriavzevii': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode11/length_restricted_for_use.fasta',
#  'pichia_membranifaciens': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode12/length_restricted_for_use.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
    # Will print 'check one' if files already produced
# Out:
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/puccinia_striiformis-tritici.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode02/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zymoseptoria_tritici.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pyrenophora_tritici-repentis.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/fusarium_oxysporum.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode05/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/tuber_brumale.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode06/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cortinarius_globuliformis.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode08/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/clavispora_lusitaniae.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode09/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode10/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode11/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/rhodotorula_mucilaginosa.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/scedosporium_boydii.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/blastobotrys_proliferans.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode02/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/debaryomyces_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/galactomyces_geotrichum.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kodamaea_ohmeri.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode05/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/meyerozyma_guilliermondii.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode06/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/wickerhamomyces_anomalus.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode07/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_mexicana.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode08/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_scolyti.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode09/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yarrowia_lipolytica.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode11/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zygoascus_hellenicus.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cryptococcus_zero.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode02/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_ccl067.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode05/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl031.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode06/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl029.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode07/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/dothiorella_vidmadera.15000.fasta!!
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode08/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/quambalaria_cyanescens.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode09/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/entoleuca_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode11/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl060.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl068.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/saccharomyces_cerevisiae.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode02/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cladophialophora_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode06/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode09/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_unidentified.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode10/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_marxianus.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode11/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta!!
#
# :(check one reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta!!

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# {'/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb',
#  '/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/puccinia_striiformis-tritici.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.puccinia_striiformis-tritici.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zymoseptoria_tritici.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.zymoseptoria_tritici.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pyrenophora_tritici-repentis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pyrenophora_tritici-repentis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/fusarium_oxysporum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.fusarium_oxysporum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/tuber_brumale.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.tuber_brumale.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cortinarius_globuliformis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.cortinarius_globuliformis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_niger.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/clavispora_lusitaniae.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.clavispora_lusitaniae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.kluyveromyces_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.penicillium_chrysogenum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/rhodotorula_mucilaginosa.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.rhodotorula_mucilaginosa.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/scedosporium_boydii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.scedosporium_boydii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/blastobotrys_proliferans.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.blastobotrys_proliferans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/debaryomyces_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.debaryomyces_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/galactomyces_geotrichum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.galactomyces_geotrichum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kodamaea_ohmeri.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.kodamaea_ohmeri.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/meyerozyma_guilliermondii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.meyerozyma_guilliermondii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/wickerhamomyces_anomalus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.wickerhamomyces_anomalus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_mexicana.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.yamadazyma_mexicana.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_scolyti.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.yamadazyma_scolyti.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yarrowia_lipolytica.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.yarrowia_lipolytica.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zygoascus_hellenicus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.zygoascus_hellenicus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_flavus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cryptococcus_zero.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.cryptococcus_zero.minimap2.paf
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_ccl067.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.diaporthe_ccl067.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.diaporthe_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl031.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.oculimacula_yallundae-ccl031.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl029.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.oculimacula_yallundae-ccl029.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/dothiorella_vidmadera.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.dothiorella_vidmadera.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/quambalaria_cyanescens.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.quambalaria_cyanescens.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/entoleuca_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.entoleuca_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl060.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.asteroma_ccl060.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl068.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.asteroma_ccl068.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/saccharomyces_cerevisiae.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.saccharomyces_cerevisiae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cladophialophora_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.cladophialophora_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_albicans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_metapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_orthopsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_parapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_marxianus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.kluyveromyces_marxianus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_kudriavzevii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_membranifaciens.minimap2.paf

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/puccinia_striiformis-tritici.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.puccinia_striiformis-tritici.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zymoseptoria_tritici.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.zymoseptoria_tritici.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pyrenophora_tritici-repentis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.pyrenophora_tritici-repentis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/fusarium_oxysporum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.fusarium_oxysporum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/tuber_brumale.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.tuber_brumale.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cortinarius_globuliformis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.cortinarius_globuliformis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.aspergillus_niger.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/clavispora_lusitaniae.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.clavispora_lusitaniae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.kluyveromyces_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.penicillium_chrysogenum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/rhodotorula_mucilaginosa.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.rhodotorula_mucilaginosa.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/scedosporium_boydii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.scedosporium_boydii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/blastobotrys_proliferans.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.blastobotrys_proliferans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/debaryomyces_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.debaryomyces_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/galactomyces_geotrichum.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.galactomyces_geotrichum.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kodamaea_ohmeri.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.kodamaea_ohmeri.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/meyerozyma_guilliermondii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.meyerozyma_guilliermondii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/wickerhamomyces_anomalus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.wickerhamomyces_anomalus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_mexicana.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.yamadazyma_mexicana.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yamadazyma_scolyti.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.yamadazyma_scolyti.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/yarrowia_lipolytica.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.yarrowia_lipolytica.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/zygoascus_hellenicus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.zygoascus_hellenicus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.aspergillus_flavus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cryptococcus_zero.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.cryptococcus_zero.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/aspergillus_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.aspergillus_unidentified.minimap2.paf
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_ccl067.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.diaporthe_ccl067.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/diaporthe_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.diaporthe_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl031.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.oculimacula_yallundae-ccl031.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/oculimacula_yallundae-ccl029.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.oculimacula_yallundae-ccl029.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/dothiorella_vidmadera.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.dothiorella_vidmadera.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/quambalaria_cyanescens.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.quambalaria_cyanescens.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/entoleuca_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.entoleuca_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl060.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.asteroma_ccl060.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/asteroma_ccl068.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.asteroma_ccl068.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/saccharomyces_cerevisiae.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.saccharomyces_cerevisiae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/cladophialophora_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.cladophialophora_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_albicans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_metapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_orthopsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_parapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/candida_unidentified.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/kluyveromyces_marxianus.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.kluyveromyces_marxianus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.pichia_kudriavzevii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 6 /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping_mock_gsref/gsref_db/gsref.db.pichia_membranifaciens.minimap2.paf

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/%s.json' % species)

# %%
def pull_mapping_results(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
    return hit_df

# %%
def getquery_taxfileid(refdf_fn, species):
    """
    Takes the reference dataframe filename and the species name.
    Returns the taxfileid, which is the date/flowcellid (column 0 value) of the ref_df.
    """
    ref_df = pd.read_csv(refdf_fn)
    ref_df['name_species'] = ref_df['genus'] +"_"+ ref_df['species']
    return ref_df[ref_df.name_species == species].iloc[:,0].values[0]

# %%
def get_taxid_dict(taxid_fn, taxfileid):
    """
    Takes a taxonomy assignment file filename in the Qiime format and a taxonomic identifier.
    Returns the a dictionary with the taxonomic assignment at each rank.
    """
    tax_dict = {}
    with open(taxid_fn, 'r') as fh:
        for line in fh:
            if line.startswith(taxfileid):
                taxrankids = line.rstrip().split('\t')[1].split(';')
                for taxrank in taxrankids:
                    tax_dict[taxrank.split('__')[0]] = taxrank.split('__')[1]
    return tax_dict

# %%
def assign_taxranks_results(mapping_df, tax_fn, ref_df_fn = False):
    """
    This function assigns the taxonomic ranks for each hit in the mapping results dataframe.
    It takes a mapping_df, taxonomy assignment file, and if required a reference dataframe filename.
    Returns the mapping dataframe with assignment. 
    """
    for tname in mapping_df.index:
        if ref_df_fn:
            tmp_taxfileid = getquery_taxfileid(ref_df_fn, tname)
        else:
            tmp_taxfileid = tname
        tmp_tax_dict = get_taxid_dict(tax_fn, tmp_taxfileid)
        for key, value in tmp_tax_dict.items():
            mapping_df.loc[tname, key] = value
    return mapping_df

# %%
def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarieses the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = {}
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

# %%
### this is running the reads against the full database
### These results show which species each sample match to and the
### proportion of reads matching to each species
for species, hit_fn in new_db_mapping_fn.items():
    mapping_results(hit_fn, species)
# Out:
# True
# ##########
#
# This was the query species: puccinia_striiformis-tritici
#
# These are the results:
# tname
# puccinia_striiformis-tritici    0.994467
# pyrenophora_tritici-repentis    0.000533
# cortinarius_globuliformis       0.000467
# saccharomyces_cerevisiae        0.000400
# cryptococcus_zero               0.000400
# aspergillus_niger               0.000333
# yarrowia_lipolytica             0.000267
# blastobotrys_proliferans        0.000267
# kodamaea_ohmeri                 0.000267
# clavispora_lusitaniae           0.000200
# zymoseptoria_tritici            0.000200
# tuber_brumale                   0.000200
# yamadazyma_mexicana             0.000200
# scedosporium_boydii             0.000200
# penicillium_chrysogenum         0.000133
# oculimacula_yallundae-ccl031    0.000133
# kluyveromyces_marxianus         0.000133
# candida_metapsilosis            0.000133
# fusarium_oxysporum              0.000133
# candida_unidentified            0.000133
# rhodotorula_mucilaginosa        0.000133
# pichia_membranifaciens          0.000067
# aspergillus_unidentified        0.000067
# candida_parapsilosis            0.000067
# debaryomyces_unidentified       0.000067
# pichia_kudriavzevii             0.000067
# entoleuca_unidentified          0.000067
# galactomyces_geotrichum         0.000067
# quambalaria_cyanescens          0.000067
# zygoascus_hellenicus            0.000067
# oculimacula_yallundae-ccl029    0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: zymoseptoria_tritici
#
# These are the results:
# tname
# zymoseptoria_tritici             0.991542
# pyrenophora_tritici-repentis     0.001465
# penicillium_chrysogenum          0.000866
# dothiorella_vidmadera            0.000799
# oculimacula_yallundae-ccl029     0.000799
# tuber_brumale                    0.000466
# entoleuca_unidentified           0.000466
# fusarium_oxysporum               0.000400
# candida_metapsilosis             0.000333
# cladophialophora_unidentified    0.000266
# oculimacula_yallundae-ccl031     0.000266
# puccinia_striiformis-tritici     0.000200
# kluyveromyces_marxianus          0.000200
# asteroma_ccl060                  0.000200
# aspergillus_niger                0.000133
# saccharomyces_cerevisiae         0.000133
# aspergillus_unidentified         0.000133
# kluyveromyces_unidentified       0.000133
# scedosporium_boydii              0.000133
# candida_orthopsilosis            0.000133
# asteroma_ccl068                  0.000067
# blastobotrys_proliferans         0.000067
# candida_unidentified             0.000067
# diaporthe_ccl067                 0.000067
# cortinarius_globuliformis        0.000067
# debaryomyces_unidentified        0.000067
# pichia_kudriavzevii              0.000067
# diaporthe_unidentified           0.000067
# wickerhamomyces_anomalus         0.000067
# yamadazyma_mexicana              0.000067
# galactomyces_geotrichum          0.000067
# meyerozyma_guilliermondii        0.000067
# rhodotorula_mucilaginosa         0.000067
# aspergillus_flavus               0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: pyrenophora_tritici-repentis
#
# These are the results:
# tname
# pyrenophora_tritici-repentis     0.956842
# zymoseptoria_tritici             0.033331
# galactomyces_geotrichum          0.001660
# oculimacula_yallundae-ccl029     0.000996
# diaporthe_ccl067                 0.000797
# candida_albicans                 0.000730
# dothiorella_vidmadera            0.000598
# entoleuca_unidentified           0.000465
# aspergillus_niger                0.000398
# penicillium_chrysogenum          0.000332
# candida_metapsilosis             0.000266
# aspergillus_unidentified         0.000199
# asteroma_ccl060                  0.000199
# asteroma_ccl068                  0.000199
# cladophialophora_unidentified    0.000199
# clavispora_lusitaniae            0.000199
# diaporthe_unidentified           0.000199
# fusarium_oxysporum               0.000199
# puccinia_striiformis-tritici     0.000199
# scedosporium_boydii              0.000199
# wickerhamomyces_anomalus         0.000199
# aspergillus_flavus               0.000199
# meyerozyma_guilliermondii        0.000133
# candida_parapsilosis             0.000133
# candida_orthopsilosis            0.000133
# kodamaea_ohmeri                  0.000133
# kluyveromyces_unidentified       0.000133
# oculimacula_yallundae-ccl031     0.000066
# debaryomyces_unidentified        0.000066
# cryptococcus_zero                0.000066
# cortinarius_globuliformis        0.000066
# pichia_membranifaciens           0.000066
# yarrowia_lipolytica              0.000066
# saccharomyces_cerevisiae         0.000066
# tuber_brumale                    0.000066
# yamadazyma_mexicana              0.000066
# yamadazyma_scolyti               0.000066
# kluyveromyces_marxianus          0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: fusarium_oxysporum
#
# These are the results:
# tname
# fusarium_oxysporum               0.972563
# kodamaea_ohmeri                  0.009124
# diaporthe_unidentified           0.006104
# candida_metapsilosis             0.005579
# oculimacula_yallundae-ccl029     0.000722
# entoleuca_unidentified           0.000722
# scedosporium_boydii              0.000656
# asteroma_ccl060                  0.000591
# tuber_brumale                    0.000394
# zygoascus_hellenicus             0.000394
# puccinia_striiformis-tritici     0.000263
# diaporthe_ccl067                 0.000263
# asteroma_ccl068                  0.000263
# pyrenophora_tritici-repentis     0.000263
# saccharomyces_cerevisiae         0.000197
# candida_parapsilosis             0.000197
# penicillium_chrysogenum          0.000197
# dothiorella_vidmadera            0.000197
# clavispora_lusitaniae            0.000131
# zymoseptoria_tritici             0.000131
# kluyveromyces_unidentified       0.000131
# oculimacula_yallundae-ccl031     0.000131
# pichia_kudriavzevii              0.000131
# aspergillus_niger                0.000131
# galactomyces_geotrichum          0.000066
# meyerozyma_guilliermondii        0.000066
# cladophialophora_unidentified    0.000066
# quambalaria_cyanescens           0.000066
# candida_orthopsilosis            0.000066
# rhodotorula_mucilaginosa         0.000066
# yamadazyma_mexicana              0.000066
# yarrowia_lipolytica              0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: tuber_brumale
#
# These are the results:
# tname
# tuber_brumale                    0.990028
# oculimacula_yallundae-ccl031     0.000931
# meyerozyma_guilliermondii        0.000864
# candida_orthopsilosis            0.000731
# zymoseptoria_tritici             0.000598
# yamadazyma_mexicana              0.000598
# clavispora_lusitaniae            0.000465
# yarrowia_lipolytica              0.000399
# yamadazyma_scolyti               0.000399
# penicillium_chrysogenum          0.000399
# wickerhamomyces_anomalus         0.000332
# kluyveromyces_marxianus          0.000266
# pichia_kudriavzevii              0.000266
# candida_parapsilosis             0.000199
# asteroma_ccl068                  0.000199
# quambalaria_cyanescens           0.000199
# cladophialophora_unidentified    0.000199
# kodamaea_ohmeri                  0.000199
# saccharomyces_cerevisiae         0.000199
# aspergillus_unidentified         0.000199
# entoleuca_unidentified           0.000199
# diaporthe_unidentified           0.000133
# asteroma_ccl060                  0.000133
# debaryomyces_unidentified        0.000133
# galactomyces_geotrichum          0.000133
# aspergillus_flavus               0.000133
# scedosporium_boydii              0.000133
# rhodotorula_mucilaginosa         0.000133
# pyrenophora_tritici-repentis     0.000133
# zygoascus_hellenicus             0.000133
# oculimacula_yallundae-ccl029     0.000133
# puccinia_striiformis-tritici     0.000133
# candida_metapsilosis             0.000066
# blastobotrys_proliferans         0.000066
# candida_albicans                 0.000066
# dothiorella_vidmadera            0.000066
# diaporthe_ccl067                 0.000066
# candida_unidentified             0.000066
# cortinarius_globuliformis        0.000066
# cryptococcus_zero                0.000066
# fusarium_oxysporum               0.000066
# pichia_membranifaciens           0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: cortinarius_globuliformis
#
# These are the results:
# tname
# cortinarius_globuliformis        0.990614
# pyrenophora_tritici-repentis     0.000732
# puccinia_striiformis-tritici     0.000666
# rhodotorula_mucilaginosa         0.000599
# clavispora_lusitaniae            0.000466
# penicillium_chrysogenum          0.000466
# zymoseptoria_tritici             0.000333
# aspergillus_niger                0.000333
# cryptococcus_zero                0.000333
# galactomyces_geotrichum          0.000333
# tuber_brumale                    0.000333
# debaryomyces_unidentified        0.000266
# fusarium_oxysporum               0.000266
# kluyveromyces_marxianus          0.000266
# kluyveromyces_unidentified       0.000266
# candida_metapsilosis             0.000266
# blastobotrys_proliferans         0.000200
# asteroma_ccl060                  0.000200
# scedosporium_boydii              0.000200
# cladophialophora_unidentified    0.000200
# yarrowia_lipolytica              0.000200
# dothiorella_vidmadera            0.000200
# yamadazyma_mexicana              0.000200
# quambalaria_cyanescens           0.000200
# asteroma_ccl068                  0.000133
# aspergillus_unidentified         0.000133
# yamadazyma_scolyti               0.000133
# diaporthe_ccl067                 0.000133
# saccharomyces_cerevisiae         0.000133
# kodamaea_ohmeri                  0.000133
# meyerozyma_guilliermondii        0.000133
# oculimacula_yallundae-ccl031     0.000133
# pichia_kudriavzevii              0.000133
# pichia_membranifaciens           0.000133
# diaporthe_unidentified           0.000067
# entoleuca_unidentified           0.000067
# zygoascus_hellenicus             0.000067
# candida_parapsilosis             0.000067
# candida_orthopsilosis            0.000067
# candida_albicans                 0.000067
# oculimacula_yallundae-ccl029     0.000067
# aspergillus_flavus               0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: aspergillus_niger
#
# These are the results:
# tname
# aspergillus_niger                0.754601
# aspergillus_unidentified         0.223564
# aspergillus_flavus               0.008048
# yamadazyma_mexicana              0.004486
# dothiorella_vidmadera            0.004354
# penicillium_chrysogenum          0.001715
# entoleuca_unidentified           0.000462
# zymoseptoria_tritici             0.000330
# tuber_brumale                    0.000264
# galactomyces_geotrichum          0.000198
# scedosporium_boydii              0.000198
# puccinia_striiformis-tritici     0.000198
# cladophialophora_unidentified    0.000198
# pyrenophora_tritici-repentis     0.000198
# clavispora_lusitaniae            0.000198
# cortinarius_globuliformis        0.000132
# oculimacula_yallundae-ccl031     0.000132
# oculimacula_yallundae-ccl029     0.000132
# rhodotorula_mucilaginosa         0.000132
# kluyveromyces_marxianus          0.000132
# fusarium_oxysporum               0.000066
# candida_orthopsilosis            0.000066
# candida_metapsilosis             0.000066
# kodamaea_ohmeri                  0.000066
# cryptococcus_zero                0.000066
# dtype: float64
# True
# ##########
#
# This was the query species: clavispora_lusitaniae
#
# These are the results:
# tname
# clavispora_lusitaniae           0.984887
# candida_unidentified            0.002796
# kodamaea_ohmeri                 0.001931
# candida_orthopsilosis           0.000999
# yamadazyma_scolyti              0.000799
# candida_albicans                0.000666
# candida_metapsilosis            0.000666
# kluyveromyces_unidentified      0.000599
# saccharomyces_cerevisiae        0.000599
# kluyveromyces_marxianus         0.000533
# wickerhamomyces_anomalus        0.000466
# zymoseptoria_tritici            0.000399
# yamadazyma_mexicana             0.000399
# debaryomyces_unidentified       0.000333
# pichia_kudriavzevii             0.000333
# yarrowia_lipolytica             0.000333
# penicillium_chrysogenum         0.000266
# meyerozyma_guilliermondii       0.000266
# entoleuca_unidentified          0.000266
# puccinia_striiformis-tritici    0.000200
# blastobotrys_proliferans        0.000200
# zygoascus_hellenicus            0.000200
# pyrenophora_tritici-repentis    0.000200
# quambalaria_cyanescens          0.000200
# asteroma_ccl060                 0.000133
# candida_parapsilosis            0.000133
# scedosporium_boydii             0.000133
# aspergillus_flavus              0.000133
# fusarium_oxysporum              0.000133
# galactomyces_geotrichum         0.000133
# oculimacula_yallundae-ccl029    0.000133
# oculimacula_yallundae-ccl031    0.000133
# cryptococcus_zero               0.000067
# rhodotorula_mucilaginosa        0.000067
# diaporthe_ccl067                0.000067
# pichia_membranifaciens          0.000067
# tuber_brumale                   0.000067
# diaporthe_unidentified          0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: kluyveromyces_unidentified
#
# These are the results:
# tname
# kluyveromyces_marxianus          0.536898
# kluyveromyces_unidentified       0.365759
# cryptococcus_zero                0.060773
# rhodotorula_mucilaginosa         0.004407
# entoleuca_unidentified           0.003946
# candida_unidentified             0.003552
# cortinarius_globuliformis        0.003223
# yarrowia_lipolytica              0.002697
# wickerhamomyces_anomalus         0.001644
# candida_orthopsilosis            0.001579
# saccharomyces_cerevisiae         0.001381
# oculimacula_yallundae-ccl029     0.001184
# yamadazyma_mexicana              0.001184
# meyerozyma_guilliermondii        0.001184
# candida_metapsilosis             0.001118
# quambalaria_cyanescens           0.001118
# zymoseptoria_tritici             0.000855
# clavispora_lusitaniae            0.000658
# candida_albicans                 0.000526
# pyrenophora_tritici-repentis     0.000526
# penicillium_chrysogenum          0.000460
# blastobotrys_proliferans         0.000460
# debaryomyces_unidentified        0.000460
# candida_parapsilosis             0.000460
# tuber_brumale                    0.000460
# cladophialophora_unidentified    0.000395
# aspergillus_niger                0.000395
# kodamaea_ohmeri                  0.000395
# yamadazyma_scolyti               0.000263
# zygoascus_hellenicus             0.000263
# fusarium_oxysporum               0.000263
# puccinia_striiformis-tritici     0.000263
# asteroma_ccl060                  0.000197
# oculimacula_yallundae-ccl031     0.000197
# aspergillus_flavus               0.000197
# dothiorella_vidmadera            0.000132
# asteroma_ccl068                  0.000132
# pichia_kudriavzevii              0.000132
# galactomyces_geotrichum          0.000132
# pichia_membranifaciens           0.000066
# aspergillus_unidentified         0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: penicillium_chrysogenum
#
# These are the results:
# tname
# penicillium_chrysogenum         0.986958
# aspergillus_flavus              0.002462
# aspergillus_unidentified        0.002196
# aspergillus_niger               0.002129
# kluyveromyces_marxianus         0.000932
# zymoseptoria_tritici            0.000799
# kluyveromyces_unidentified      0.000799
# cortinarius_globuliformis       0.000466
# tuber_brumale                   0.000466
# dothiorella_vidmadera           0.000333
# diaporthe_unidentified          0.000200
# kodamaea_ohmeri                 0.000200
# fusarium_oxysporum              0.000133
# asteroma_ccl068                 0.000133
# blastobotrys_proliferans        0.000133
# clavispora_lusitaniae           0.000133
# saccharomyces_cerevisiae        0.000133
# scedosporium_boydii             0.000133
# oculimacula_yallundae-ccl029    0.000133
# puccinia_striiformis-tritici    0.000133
# entoleuca_unidentified          0.000133
# zygoascus_hellenicus            0.000067
# pichia_kudriavzevii             0.000067
# pichia_membranifaciens          0.000067
# diaporthe_ccl067                0.000067
# debaryomyces_unidentified       0.000067
# cryptococcus_zero               0.000067
# pyrenophora_tritici-repentis    0.000067
# candida_unidentified            0.000067
# quambalaria_cyanescens          0.000067
# rhodotorula_mucilaginosa        0.000067
# asteroma_ccl060                 0.000067
# yamadazyma_mexicana             0.000067
# yamadazyma_scolyti              0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: rhodotorula_mucilaginosa
#
# These are the results:
# tname
# rhodotorula_mucilaginosa         0.982583
# pichia_kudriavzevii              0.004948
# asteroma_ccl060                  0.003497
# zygoascus_hellenicus             0.003101
# cortinarius_globuliformis        0.000858
# penicillium_chrysogenum          0.000726
# aspergillus_niger                0.000462
# cryptococcus_zero                0.000462
# pyrenophora_tritici-repentis     0.000396
# tuber_brumale                    0.000330
# entoleuca_unidentified           0.000264
# zymoseptoria_tritici             0.000198
# cladophialophora_unidentified    0.000198
# puccinia_striiformis-tritici     0.000198
# candida_metapsilosis             0.000132
# kodamaea_ohmeri                  0.000132
# yamadazyma_scolyti               0.000132
# quambalaria_cyanescens           0.000132
# scedosporium_boydii              0.000132
# oculimacula_yallundae-ccl031     0.000132
# oculimacula_yallundae-ccl029     0.000066
# wickerhamomyces_anomalus         0.000066
# yarrowia_lipolytica              0.000066
# aspergillus_unidentified         0.000066
# asteroma_ccl068                  0.000066
# blastobotrys_proliferans         0.000066
# candida_albicans                 0.000066
# candida_parapsilosis             0.000066
# candida_orthopsilosis            0.000066
# saccharomyces_cerevisiae         0.000066
# debaryomyces_unidentified        0.000066
# diaporthe_ccl067                 0.000066
# dothiorella_vidmadera            0.000066
# pichia_membranifaciens           0.000066
# aspergillus_flavus               0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: scedosporium_boydii
#
# These are the results:
# tname
# scedosporium_boydii              0.991613
# fusarium_oxysporum               0.001531
# oculimacula_yallundae-ccl029     0.000865
# entoleuca_unidentified           0.000599
# pyrenophora_tritici-repentis     0.000466
# rhodotorula_mucilaginosa         0.000399
# asteroma_ccl068                  0.000399
# penicillium_chrysogenum          0.000399
# aspergillus_unidentified         0.000266
# asteroma_ccl060                  0.000266
# cryptococcus_zero                0.000266
# diaporthe_ccl067                 0.000266
# aspergillus_flavus               0.000266
# tuber_brumale                    0.000266
# clavispora_lusitaniae            0.000200
# oculimacula_yallundae-ccl031     0.000200
# pichia_membranifaciens           0.000200
# zymoseptoria_tritici             0.000200
# diaporthe_unidentified           0.000200
# dothiorella_vidmadera            0.000200
# cortinarius_globuliformis        0.000133
# cladophialophora_unidentified    0.000133
# galactomyces_geotrichum          0.000133
# kodamaea_ohmeri                  0.000067
# debaryomyces_unidentified        0.000067
# kluyveromyces_marxianus          0.000067
# candida_parapsilosis             0.000067
# candida_metapsilosis             0.000067
# blastobotrys_proliferans         0.000067
# pichia_kudriavzevii              0.000067
# zygoascus_hellenicus             0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: blastobotrys_proliferans
#
# These are the results:
# tname
# blastobotrys_proliferans         0.995003
# meyerozyma_guilliermondii        0.000866
# debaryomyces_unidentified        0.000733
# entoleuca_unidentified           0.000466
# candida_orthopsilosis            0.000400
# candida_albicans                 0.000267
# aspergillus_flavus               0.000200
# yamadazyma_mexicana              0.000200
# wickerhamomyces_anomalus         0.000200
# tuber_brumale                    0.000200
# candida_metapsilosis             0.000200
# oculimacula_yallundae-ccl029     0.000200
# yarrowia_lipolytica              0.000133
# yamadazyma_scolyti               0.000133
# kodamaea_ohmeri                  0.000133
# galactomyces_geotrichum          0.000067
# fusarium_oxysporum               0.000067
# cladophialophora_unidentified    0.000067
# candida_parapsilosis             0.000067
# oculimacula_yallundae-ccl031     0.000067
# pichia_membranifaciens           0.000067
# rhodotorula_mucilaginosa         0.000067
# scedosporium_boydii              0.000067
# asteroma_ccl068                  0.000067
# kluyveromyces_unidentified       0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: debaryomyces_unidentified
#
# These are the results:
# tname
# debaryomyces_unidentified       0.984419
# clavispora_lusitaniae           0.004994
# meyerozyma_guilliermondii       0.002464
# yamadazyma_mexicana             0.001665
# wickerhamomyces_anomalus        0.000599
# candida_metapsilosis            0.000533
# candida_parapsilosis            0.000533
# tuber_brumale                   0.000466
# yamadazyma_scolyti              0.000466
# candida_unidentified            0.000466
# oculimacula_yallundae-ccl029    0.000400
# kluyveromyces_marxianus         0.000333
# entoleuca_unidentified          0.000333
# candida_orthopsilosis           0.000266
# kluyveromyces_unidentified      0.000266
# kodamaea_ohmeri                 0.000200
# zygoascus_hellenicus            0.000200
# candida_albicans                0.000133
# blastobotrys_proliferans        0.000133
# zymoseptoria_tritici            0.000133
# galactomyces_geotrichum         0.000133
# aspergillus_flavus              0.000133
# diaporthe_ccl067                0.000067
# diaporthe_unidentified          0.000067
# dothiorella_vidmadera           0.000067
# fusarium_oxysporum              0.000067
# penicillium_chrysogenum         0.000067
# pyrenophora_tritici-repentis    0.000067
# quambalaria_cyanescens          0.000067
# saccharomyces_cerevisiae        0.000067
# yarrowia_lipolytica             0.000067
# asteroma_ccl068                 0.000067
# aspergillus_niger               0.000067
# dtype: float64
# True
# ##########
#
# This was the query species: galactomyces_geotrichum
#
# These are the results:
# tname
# galactomyces_geotrichum          0.984758
# candida_metapsilosis             0.000877
# pyrenophora_tritici-repentis     0.000809
# entoleuca_unidentified           0.000809
# diaporthe_ccl067                 0.000809
# candida_albicans                 0.000809
# yamadazyma_mexicana              0.000674
# wickerhamomyces_anomalus         0.000674
# kodamaea_ohmeri                  0.000607
# debaryomyces_unidentified        0.000540
# kluyveromyces_unidentified       0.000540
# blastobotrys_proliferans         0.000540
# yarrowia_lipolytica              0.000540
# zygoascus_hellenicus             0.000472
# pichia_kudriavzevii              0.000472
# saccharomyces_cerevisiae         0.000472
# clavispora_lusitaniae            0.000405
# yamadazyma_scolyti               0.000405
# candida_parapsilosis             0.000405
# dothiorella_vidmadera            0.000337
# aspergillus_flavus               0.000337
# tuber_brumale                    0.000337
# pichia_membranifaciens           0.000337
# cortinarius_globuliformis        0.000270
# candida_unidentified             0.000270
# quambalaria_cyanescens           0.000270
# candida_orthopsilosis            0.000202
# aspergillus_unidentified         0.000202
# oculimacula_yallundae-ccl029     0.000202
# diaporthe_unidentified           0.000202
# asteroma_ccl060                  0.000202
# penicillium_chrysogenum          0.000202
# kluyveromyces_marxianus          0.000135
# rhodotorula_mucilaginosa         0.000135
# cladophialophora_unidentified    0.000135
# cryptococcus_zero                0.000135
# meyerozyma_guilliermondii        0.000135
# fusarium_oxysporum               0.000067
# scedosporium_boydii              0.000067
# oculimacula_yallundae-ccl031     0.000067
# aspergillus_niger                0.000067
# zymoseptoria_tritici             0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: kodamaea_ohmeri
#
# These are the results:
# tname
# kodamaea_ohmeri                  0.946206
# candida_metapsilosis             0.018825
# diaporthe_unidentified           0.018697
# fusarium_oxysporum               0.013209
# clavispora_lusitaniae            0.000383
# entoleuca_unidentified           0.000319
# saccharomyces_cerevisiae         0.000255
# yarrowia_lipolytica              0.000191
# yamadazyma_mexicana              0.000191
# wickerhamomyces_anomalus         0.000191
# tuber_brumale                    0.000191
# oculimacula_yallundae-ccl029     0.000191
# cortinarius_globuliformis        0.000128
# candida_albicans                 0.000128
# yamadazyma_scolyti               0.000128
# meyerozyma_guilliermondii        0.000128
# oculimacula_yallundae-ccl031     0.000128
# pichia_membranifaciens           0.000128
# kluyveromyces_marxianus          0.000064
# debaryomyces_unidentified        0.000064
# cladophialophora_unidentified    0.000064
# candida_orthopsilosis            0.000064
# puccinia_striiformis-tritici     0.000064
# kluyveromyces_unidentified       0.000064
# dtype: float64
#
# True
# ##########
#
# This was the query species: meyerozyma_guilliermondii
#
# These are the results:
# tname
# meyerozyma_guilliermondii        0.988285
# debaryomyces_unidentified        0.001464
# yamadazyma_scolyti               0.000998
# yamadazyma_mexicana              0.000932
# candida_metapsilosis             0.000932
# candida_orthopsilosis            0.000799
# candida_parapsilosis             0.000666
# wickerhamomyces_anomalus         0.000599
# candida_albicans                 0.000599
# oculimacula_yallundae-ccl029     0.000466
# kluyveromyces_unidentified       0.000399
# candida_unidentified             0.000399
# kluyveromyces_marxianus          0.000399
# galactomyces_geotrichum          0.000333
# clavispora_lusitaniae            0.000333
# zygoascus_hellenicus             0.000266
# kodamaea_ohmeri                  0.000266
# yarrowia_lipolytica              0.000200
# saccharomyces_cerevisiae         0.000200
# aspergillus_flavus               0.000200
# entoleuca_unidentified           0.000200
# puccinia_striiformis-tritici     0.000133
# oculimacula_yallundae-ccl031     0.000133
# tuber_brumale                    0.000133
# cryptococcus_zero                0.000067
# cortinarius_globuliformis        0.000067
# penicillium_chrysogenum          0.000067
# cladophialophora_unidentified    0.000067
# scedosporium_boydii              0.000067
# asteroma_ccl068                  0.000067
# asteroma_ccl060                  0.000067
# aspergillus_unidentified         0.000067
# aspergillus_niger                0.000067
# rhodotorula_mucilaginosa         0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: wickerhamomyces_anomalus
#
# These are the results:
# tname
# wickerhamomyces_anomalus        0.992273
# debaryomyces_unidentified       0.000999
# meyerozyma_guilliermondii       0.000866
# yamadazyma_mexicana             0.000733
# blastobotrys_proliferans        0.000600
# aspergillus_flavus              0.000400
# kluyveromyces_marxianus         0.000400
# candida_metapsilosis            0.000333
# entoleuca_unidentified          0.000333
# zygoascus_hellenicus            0.000333
# kluyveromyces_unidentified      0.000266
# yarrowia_lipolytica             0.000266
# candida_parapsilosis            0.000266
# tuber_brumale                   0.000200
# galactomyces_geotrichum         0.000200
# candida_albicans                0.000200
# saccharomyces_cerevisiae        0.000200
# oculimacula_yallundae-ccl029    0.000200
# kodamaea_ohmeri                 0.000133
# yamadazyma_scolyti              0.000133
# candida_unidentified            0.000133
# candida_orthopsilosis           0.000133
# aspergillus_niger               0.000067
# pichia_membranifaciens          0.000067
# quambalaria_cyanescens          0.000067
# pyrenophora_tritici-repentis    0.000067
# puccinia_striiformis-tritici    0.000067
# clavispora_lusitaniae           0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: yamadazyma_mexicana
#
# These are the results:
# tname
# yamadazyma_mexicana              0.979692
# yamadazyma_scolyti               0.013050
# meyerozyma_guilliermondii        0.001265
# debaryomyces_unidentified        0.000866
# kodamaea_ohmeri                  0.000799
# wickerhamomyces_anomalus         0.000333
# entoleuca_unidentified           0.000333
# candida_parapsilosis             0.000333
# oculimacula_yallundae-ccl029     0.000266
# dothiorella_vidmadera            0.000266
# candida_orthopsilosis            0.000266
# aspergillus_flavus               0.000266
# candida_metapsilosis             0.000266
# saccharomyces_cerevisiae         0.000266
# tuber_brumale                    0.000266
# candida_unidentified             0.000200
# yarrowia_lipolytica              0.000200
# aspergillus_niger                0.000133
# blastobotrys_proliferans         0.000133
# kluyveromyces_unidentified       0.000133
# kluyveromyces_marxianus          0.000133
# zygoascus_hellenicus             0.000133
# cladophialophora_unidentified    0.000067
# pichia_membranifaciens           0.000067
# quambalaria_cyanescens           0.000067
# aspergillus_unidentified         0.000067
# scedosporium_boydii              0.000067
# zymoseptoria_tritici             0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: yamadazyma_scolyti
#
# These are the results:
# tname
# yamadazyma_scolyti              0.987078
# yamadazyma_mexicana             0.007527
# debaryomyces_unidentified       0.001332
# meyerozyma_guilliermondii       0.000799
# candida_parapsilosis            0.000466
# candida_metapsilosis            0.000333
# candida_albicans                0.000266
# clavispora_lusitaniae           0.000266
# entoleuca_unidentified          0.000266
# candida_orthopsilosis           0.000200
# quambalaria_cyanescens          0.000200
# yarrowia_lipolytica             0.000200
# candida_unidentified            0.000133
# galactomyces_geotrichum         0.000133
# kluyveromyces_marxianus         0.000133
# blastobotrys_proliferans        0.000133
# wickerhamomyces_anomalus        0.000133
# kluyveromyces_unidentified      0.000133
# zygoascus_hellenicus            0.000067
# oculimacula_yallundae-ccl029    0.000067
# saccharomyces_cerevisiae        0.000067
# aspergillus_flavus              0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: yarrowia_lipolytica
#
# These are the results:
# tname
# yarrowia_lipolytica             0.998867
# yamadazyma_scolyti              0.000133
# yamadazyma_mexicana             0.000133
# kluyveromyces_unidentified      0.000133
# entoleuca_unidentified          0.000133
# candida_unidentified            0.000133
# aspergillus_flavus              0.000133
# wickerhamomyces_anomalus        0.000067
# oculimacula_yallundae-ccl029    0.000067
# galactomyces_geotrichum         0.000067
# clavispora_lusitaniae           0.000067
# blastobotrys_proliferans        0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: zygoascus_hellenicus
#
# These are the results:
# tname
# zygoascus_hellenicus            0.973031
# pichia_kudriavzevii             0.008685
# rhodotorula_mucilaginosa        0.006922
# asteroma_ccl060                 0.006399
# oculimacula_yallundae-ccl029    0.000522
# entoleuca_unidentified          0.000457
# yamadazyma_scolyti              0.000392
# tuber_brumale                   0.000326
# candida_metapsilosis            0.000326
# galactomyces_geotrichum         0.000326
# yamadazyma_mexicana             0.000261
# candida_albicans                0.000261
# wickerhamomyces_anomalus        0.000196
# candida_orthopsilosis           0.000196
# meyerozyma_guilliermondii       0.000196
# yarrowia_lipolytica             0.000196
# debaryomyces_unidentified       0.000131
# kluyveromyces_unidentified      0.000131
# blastobotrys_proliferans        0.000131
# kodamaea_ohmeri                 0.000131
# saccharomyces_cerevisiae        0.000131
# candida_unidentified            0.000131
# aspergillus_unidentified        0.000065
# zymoseptoria_tritici            0.000065
# cortinarius_globuliformis       0.000065
# fusarium_oxysporum              0.000065
# kluyveromyces_marxianus         0.000065
# oculimacula_yallundae-ccl031    0.000065
# quambalaria_cyanescens          0.000065
# aspergillus_flavus              0.000065
# dtype: float64
#
# True
# ##########
#
# This was the query species: aspergillus_flavus
#
# These are the results:
# tname
# aspergillus_flavus               0.989142
# aspergillus_niger                0.003464
# aspergillus_unidentified         0.003397
# penicillium_chrysogenum          0.001399
# entoleuca_unidentified           0.000333
# asteroma_ccl068                  0.000266
# pichia_membranifaciens           0.000266
# tuber_brumale                    0.000200
# kodamaea_ohmeri                  0.000200
# diaporthe_ccl067                 0.000133
# scedosporium_boydii              0.000133
# blastobotrys_proliferans         0.000133
# clavispora_lusitaniae            0.000133
# candida_metapsilosis             0.000067
# cladophialophora_unidentified    0.000067
# zymoseptoria_tritici             0.000067
# dothiorella_vidmadera            0.000067
# yarrowia_lipolytica              0.000067
# pyrenophora_tritici-repentis     0.000067
# quambalaria_cyanescens           0.000067
# rhodotorula_mucilaginosa         0.000067
# saccharomyces_cerevisiae         0.000067
# yamadazyma_mexicana              0.000067
# yamadazyma_scolyti               0.000067
# oculimacula_yallundae-ccl031     0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: cryptococcus_zero
#
# These are the results:
# tname
# cryptococcus_zero                0.994200
# quambalaria_cyanescens           0.000733
# entoleuca_unidentified           0.000600
# rhodotorula_mucilaginosa         0.000533
# oculimacula_yallundae-ccl029     0.000467
# cortinarius_globuliformis        0.000467
# saccharomyces_cerevisiae         0.000333
# diaporthe_unidentified           0.000267
# aspergillus_niger                0.000267
# zymoseptoria_tritici             0.000200
# diaporthe_ccl067                 0.000200
# asteroma_ccl060                  0.000133
# asteroma_ccl068                  0.000133
# cladophialophora_unidentified    0.000133
# clavispora_lusitaniae            0.000133
# dothiorella_vidmadera            0.000133
# yarrowia_lipolytica              0.000133
# kluyveromyces_unidentified       0.000133
# fusarium_oxysporum               0.000067
# debaryomyces_unidentified        0.000067
# kluyveromyces_marxianus          0.000067
# oculimacula_yallundae-ccl031     0.000067
# pichia_membranifaciens           0.000067
# candida_unidentified             0.000067
# candida_metapsilosis             0.000067
# puccinia_striiformis-tritici     0.000067
# wickerhamomyces_anomalus         0.000067
# aspergillus_unidentified         0.000067
# yamadazyma_mexicana              0.000067
# aspergillus_flavus               0.000067
# dtype: float64
# True
# ##########
#
# This was the query species: aspergillus_unidentified
#
# These are the results:
# tname
# aspergillus_unidentified         0.667932
# aspergillus_niger                0.319217
# aspergillus_flavus               0.006526
# penicillium_chrysogenum          0.001065
# entoleuca_unidentified           0.000533
# oculimacula_yallundae-ccl031     0.000466
# zymoseptoria_tritici             0.000400
# dothiorella_vidmadera            0.000333
# diaporthe_unidentified           0.000333
# saccharomyces_cerevisiae         0.000266
# tuber_brumale                    0.000266
# asteroma_ccl068                  0.000266
# cladophialophora_unidentified    0.000266
# oculimacula_yallundae-ccl029     0.000266
# diaporthe_ccl067                 0.000200
# debaryomyces_unidentified        0.000200
# kluyveromyces_marxianus          0.000200
# puccinia_striiformis-tritici     0.000133
# quambalaria_cyanescens           0.000133
# fusarium_oxysporum               0.000133
# blastobotrys_proliferans         0.000133
# asteroma_ccl060                  0.000133
# kluyveromyces_unidentified       0.000133
# zygoascus_hellenicus             0.000067
# galactomyces_geotrichum          0.000067
# candida_unidentified             0.000067
# candida_orthopsilosis            0.000067
# candida_metapsilosis             0.000067
# yarrowia_lipolytica              0.000067
# scedosporium_boydii              0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: diaporthe_ccl067
#
# These are the results:
# tname
# asteroma_ccl068                  0.528731
# diaporthe_ccl067                 0.455928
# galactomyces_geotrichum          0.003967
# pyrenophora_tritici-repentis     0.002380
# candida_albicans                 0.001984
# asteroma_ccl060                  0.001785
# diaporthe_unidentified           0.001719
# entoleuca_unidentified           0.000926
# cryptococcus_zero                0.000661
# oculimacula_yallundae-ccl029     0.000529
# dothiorella_vidmadera            0.000198
# saccharomyces_cerevisiae         0.000132
# fusarium_oxysporum               0.000132
# kluyveromyces_marxianus          0.000132
# oculimacula_yallundae-ccl031     0.000132
# aspergillus_niger                0.000132
# quambalaria_cyanescens           0.000066
# kluyveromyces_unidentified       0.000066
# cladophialophora_unidentified    0.000066
# candida_unidentified             0.000066
# candida_parapsilosis             0.000066
# candida_orthopsilosis            0.000066
# meyerozyma_guilliermondii        0.000066
# penicillium_chrysogenum          0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: diaporthe_unidentified
#
# These are the results:
# tname
# diaporthe_unidentified          0.552707
# asteroma_ccl060                 0.418716
# kodamaea_ohmeri                 0.009417
# candida_metapsilosis            0.006801
# fusarium_oxysporum              0.005166
# asteroma_ccl068                 0.001700
# entoleuca_unidentified          0.001635
# diaporthe_ccl067                0.001439
# oculimacula_yallundae-ccl029    0.000327
# dothiorella_vidmadera           0.000327
# scedosporium_boydii             0.000262
# aspergillus_unidentified        0.000196
# oculimacula_yallundae-ccl031    0.000196
# cryptococcus_zero               0.000131
# zymoseptoria_tritici            0.000131
# pyrenophora_tritici-repentis    0.000131
# quambalaria_cyanescens          0.000131
# rhodotorula_mucilaginosa        0.000131
# yarrowia_lipolytica             0.000065
# clavispora_lusitaniae           0.000065
# saccharomyces_cerevisiae        0.000065
# tuber_brumale                   0.000065
# wickerhamomyces_anomalus        0.000065
# yamadazyma_scolyti              0.000065
# aspergillus_flavus              0.000065
# dtype: float64
#
# True
# ##########
#
# This was the query species: oculimacula_yallundae-ccl031
#
# These are the results:
# tname
# oculimacula_yallundae-ccl031     0.885486
# oculimacula_yallundae-ccl029     0.106591
# entoleuca_unidentified           0.001198
# quambalaria_cyanescens           0.000866
# dothiorella_vidmadera            0.000732
# tuber_brumale                    0.000666
# meyerozyma_guilliermondii        0.000466
# cladophialophora_unidentified    0.000333
# yamadazyma_mexicana              0.000266
# saccharomyces_cerevisiae         0.000266
# asteroma_ccl060                  0.000200
# asteroma_ccl068                  0.000200
# clavispora_lusitaniae            0.000200
# cryptococcus_zero                0.000200
# diaporthe_ccl067                 0.000200
# diaporthe_unidentified           0.000200
# zymoseptoria_tritici             0.000200
# pyrenophora_tritici-repentis     0.000200
# rhodotorula_mucilaginosa         0.000200
# yarrowia_lipolytica              0.000133
# scedosporium_boydii              0.000133
# aspergillus_niger                0.000133
# debaryomyces_unidentified        0.000067
# kodamaea_ohmeri                  0.000067
# cortinarius_globuliformis        0.000067
# penicillium_chrysogenum          0.000067
# kluyveromyces_unidentified       0.000067
# candida_unidentified             0.000067
# candida_parapsilosis             0.000067
# candida_orthopsilosis            0.000067
# candida_metapsilosis             0.000067
# candida_albicans                 0.000067
# kluyveromyces_marxianus          0.000067
# galactomyces_geotrichum          0.000067
# aspergillus_unidentified         0.000067
# fusarium_oxysporum               0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: oculimacula_yallundae-ccl029
#
# These are the results:
# tname
# oculimacula_yallundae-ccl029     0.895094
# oculimacula_yallundae-ccl031     0.093671
# dothiorella_vidmadera            0.000864
# diaporthe_ccl067                 0.000598
# aspergillus_unidentified         0.000532
# blastobotrys_proliferans         0.000532
# cladophialophora_unidentified    0.000532
# quambalaria_cyanescens           0.000465
# diaporthe_unidentified           0.000465
# zymoseptoria_tritici             0.000465
# cryptococcus_zero                0.000465
# yarrowia_lipolytica              0.000465
# wickerhamomyces_anomalus         0.000399
# asteroma_ccl060                  0.000399
# pyrenophora_tritici-repentis     0.000332
# pichia_membranifaciens           0.000332
# zygoascus_hellenicus             0.000266
# entoleuca_unidentified           0.000266
# galactomyces_geotrichum          0.000266
# kluyveromyces_unidentified       0.000266
# kodamaea_ohmeri                  0.000266
# penicillium_chrysogenum          0.000266
# scedosporium_boydii              0.000266
# aspergillus_niger                0.000199
# fusarium_oxysporum               0.000199
# pichia_kudriavzevii              0.000199
# yamadazyma_mexicana              0.000199
# saccharomyces_cerevisiae         0.000199
# kluyveromyces_marxianus          0.000199
# tuber_brumale                    0.000199
# candida_metapsilosis             0.000133
# yamadazyma_scolyti               0.000133
# asteroma_ccl068                  0.000133
# aspergillus_flavus               0.000133
# rhodotorula_mucilaginosa         0.000133
# puccinia_striiformis-tritici     0.000133
# candida_orthopsilosis            0.000066
# candida_unidentified             0.000066
# cortinarius_globuliformis        0.000066
# meyerozyma_guilliermondii        0.000066
# clavispora_lusitaniae            0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: dothiorella_vidmadera
#
# These are the results:
# tname
# dothiorella_vidmadera            0.986621
# oculimacula_yallundae-ccl029     0.001797
# zymoseptoria_tritici             0.001664
# entoleuca_unidentified           0.001464
# oculimacula_yallundae-ccl031     0.000865
# pyrenophora_tritici-repentis     0.000799
# asteroma_ccl060                  0.000599
# diaporthe_ccl067                 0.000533
# tuber_brumale                    0.000466
# fusarium_oxysporum               0.000466
# diaporthe_unidentified           0.000466
# quambalaria_cyanescens           0.000399
# saccharomyces_cerevisiae         0.000333
# cladophialophora_unidentified    0.000266
# cryptococcus_zero                0.000266
# aspergillus_unidentified         0.000266
# candida_parapsilosis             0.000266
# asteroma_ccl068                  0.000200
# candida_metapsilosis             0.000200
# cortinarius_globuliformis        0.000200
# galactomyces_geotrichum          0.000200
# kodamaea_ohmeri                  0.000200
# kluyveromyces_marxianus          0.000200
# kluyveromyces_unidentified       0.000133
# aspergillus_niger                0.000133
# yarrowia_lipolytica              0.000133
# candida_orthopsilosis            0.000133
# zygoascus_hellenicus             0.000067
# candida_albicans                 0.000067
# yamadazyma_scolyti               0.000067
# wickerhamomyces_anomalus         0.000067
# puccinia_striiformis-tritici     0.000067
# rhodotorula_mucilaginosa         0.000067
# candida_unidentified             0.000067
# pichia_membranifaciens           0.000067
# pichia_kudriavzevii              0.000067
# penicillium_chrysogenum          0.000067
# aspergillus_flavus               0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: quambalaria_cyanescens
#
# These are the results:
# tname
# quambalaria_cyanescens           0.992534
# oculimacula_yallundae-ccl029     0.001000
# entoleuca_unidentified           0.000733
# asteroma_ccl068                  0.000400
# saccharomyces_cerevisiae         0.000400
# rhodotorula_mucilaginosa         0.000400
# cortinarius_globuliformis        0.000400
# dothiorella_vidmadera            0.000333
# kodamaea_ohmeri                  0.000333
# cryptococcus_zero                0.000333
# oculimacula_yallundae-ccl031     0.000333
# tuber_brumale                    0.000267
# diaporthe_unidentified           0.000267
# yarrowia_lipolytica              0.000200
# galactomyces_geotrichum          0.000200
# clavispora_lusitaniae            0.000200
# puccinia_striiformis-tritici     0.000200
# diaporthe_ccl067                 0.000133
# asteroma_ccl060                  0.000133
# aspergillus_niger                0.000133
# pichia_membranifaciens           0.000133
# scedosporium_boydii              0.000133
# fusarium_oxysporum               0.000067
# kluyveromyces_marxianus          0.000067
# meyerozyma_guilliermondii        0.000067
# debaryomyces_unidentified        0.000067
# penicillium_chrysogenum          0.000067
# pyrenophora_tritici-repentis     0.000067
# cladophialophora_unidentified    0.000067
# candida_unidentified             0.000067
# candida_metapsilosis             0.000067
# blastobotrys_proliferans         0.000067
# yamadazyma_scolyti               0.000067
# zygoascus_hellenicus             0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: entoleuca_unidentified
#
# These are the results:
# tname
# entoleuca_unidentified           0.988216
# asteroma_ccl068                  0.000999
# zymoseptoria_tritici             0.000799
# oculimacula_yallundae-ccl031     0.000799
# diaporthe_ccl067                 0.000599
# fusarium_oxysporum               0.000599
# diaporthe_unidentified           0.000533
# cladophialophora_unidentified    0.000533
# asteroma_ccl060                  0.000466
# scedosporium_boydii              0.000399
# wickerhamomyces_anomalus         0.000399
# dothiorella_vidmadera            0.000399
# cryptococcus_zero                0.000399
# clavispora_lusitaniae            0.000333
# pichia_kudriavzevii              0.000333
# zygoascus_hellenicus             0.000333
# pyrenophora_tritici-repentis     0.000333
# aspergillus_unidentified         0.000333
# penicillium_chrysogenum          0.000266
# oculimacula_yallundae-ccl029     0.000266
# blastobotrys_proliferans         0.000266
# rhodotorula_mucilaginosa         0.000266
# candida_parapsilosis             0.000200
# candida_orthopsilosis            0.000200
# galactomyces_geotrichum          0.000200
# kluyveromyces_unidentified       0.000200
# aspergillus_niger                0.000200
# quambalaria_cyanescens           0.000200
# yarrowia_lipolytica              0.000200
# aspergillus_flavus               0.000133
# candida_albicans                 0.000133
# candida_metapsilosis             0.000133
# pichia_membranifaciens           0.000133
# tuber_brumale                    0.000067
# meyerozyma_guilliermondii        0.000067
# saccharomyces_cerevisiae         0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: asteroma_ccl060
#
# These are the results:
# tname
# diaporthe_unidentified           0.519429
# asteroma_ccl060                  0.446994
# zygoascus_hellenicus             0.010301
# rhodotorula_mucilaginosa         0.010106
# pichia_kudriavzevii              0.005542
# diaporthe_ccl067                 0.001695
# entoleuca_unidentified           0.001108
# asteroma_ccl068                  0.000913
# oculimacula_yallundae-ccl029     0.000848
# fusarium_oxysporum               0.000456
# oculimacula_yallundae-ccl031     0.000391
# scedosporium_boydii              0.000326
# zymoseptoria_tritici             0.000261
# quambalaria_cyanescens           0.000261
# tuber_brumale                    0.000196
# dothiorella_vidmadera            0.000130
# cryptococcus_zero                0.000130
# candida_parapsilosis             0.000130
# aspergillus_unidentified         0.000130
# penicillium_chrysogenum          0.000065
# puccinia_striiformis-tritici     0.000065
# pyrenophora_tritici-repentis     0.000065
# cortinarius_globuliformis        0.000065
# clavispora_lusitaniae            0.000065
# cladophialophora_unidentified    0.000065
# candida_albicans                 0.000065
# blastobotrys_proliferans         0.000065
# saccharomyces_cerevisiae         0.000065
# aspergillus_flavus               0.000065
# dtype: float64
# True
# ##########
#
# This was the query species: asteroma_ccl068
#
# These are the results:
# tname
# asteroma_ccl068                  0.556854
# diaporthe_ccl067                 0.431663
# asteroma_ccl060                  0.001792
# aspergillus_flavus               0.001394
# pichia_membranifaciens           0.001328
# diaporthe_unidentified           0.001062
# entoleuca_unidentified           0.001062
# oculimacula_yallundae-ccl029     0.000797
# ...
#
# This was the query species: saccharomyces_cerevisiae
#
# These are the results:
# tname
# saccharomyces_cerevisiae         0.987414
# kluyveromyces_unidentified       0.002730
# kluyveromyces_marxianus          0.001132
# oculimacula_yallundae-ccl029     0.000733
# candida_metapsilosis             0.000599
# clavispora_lusitaniae            0.000599
# pichia_membranifaciens           0.000533
# debaryomyces_unidentified        0.000466
# entoleuca_unidentified           0.000466
# kodamaea_ohmeri                  0.000466
# wickerhamomyces_anomalus         0.000400
# yamadazyma_mexicana              0.000400
# candida_albicans                 0.000333
# pichia_kudriavzevii              0.000266
# candida_orthopsilosis            0.000266
# tuber_brumale                    0.000266
# dothiorella_vidmadera            0.000266
# blastobotrys_proliferans         0.000266
# meyerozyma_guilliermondii        0.000266
# cladophialophora_unidentified    0.000200
# yamadazyma_scolyti               0.000200
# candida_parapsilosis             0.000200
# galactomyces_geotrichum          0.000200
# asteroma_ccl060                  0.000133
# candida_unidentified             0.000133
# zymoseptoria_tritici             0.000133
# oculimacula_yallundae-ccl031     0.000133
# pyrenophora_tritici-repentis     0.000133
# yarrowia_lipolytica              0.000133
# aspergillus_flavus               0.000133
# diaporthe_ccl067                 0.000067
# zygoascus_hellenicus             0.000067
# penicillium_chrysogenum          0.000067
# scedosporium_boydii              0.000067
# asteroma_ccl068                  0.000067
# aspergillus_niger                0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: cladophialophora_unidentified
#
# These are the results:
# tname
# cladophialophora_unidentified    0.994075
# zymoseptoria_tritici             0.000666
# oculimacula_yallundae-ccl029     0.000466
# aspergillus_unidentified         0.000333
# tuber_brumale                    0.000333
# pyrenophora_tritici-repentis     0.000333
# clavispora_lusitaniae            0.000333
# kluyveromyces_unidentified       0.000266
# debaryomyces_unidentified        0.000266
# candida_albicans                 0.000200
# candida_metapsilosis             0.000200
# candida_orthopsilosis            0.000200
# dothiorella_vidmadera            0.000200
# entoleuca_unidentified           0.000200
# fusarium_oxysporum               0.000200
# oculimacula_yallundae-ccl031     0.000200
# rhodotorula_mucilaginosa         0.000133
# penicillium_chrysogenum          0.000133
# cryptococcus_zero                0.000133
# galactomyces_geotrichum          0.000133
# kluyveromyces_marxianus          0.000067
# aspergillus_niger                0.000067
# yamadazyma_mexicana              0.000067
# asteroma_ccl060                  0.000067
# asteroma_ccl068                  0.000067
# wickerhamomyces_anomalus         0.000067
# saccharomyces_cerevisiae         0.000067
# candida_unidentified             0.000067
# candida_parapsilosis             0.000067
# puccinia_striiformis-tritici     0.000067
# pichia_membranifaciens           0.000067
# diaporthe_unidentified           0.000067
# meyerozyma_guilliermondii        0.000067
# yarrowia_lipolytica              0.000067
# aspergillus_flavus               0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: candida_albicans
#
# These are the results:
# tname
# candida_unidentified             0.424446
# candida_albicans                 0.361687
# candida_orthopsilosis            0.098020
# candida_metapsilosis             0.060062
# candida_parapsilosis             0.032169
# galactomyces_geotrichum          0.003618
# pyrenophora_tritici-repentis     0.003421
# diaporthe_ccl067                 0.002895
# debaryomyces_unidentified        0.002039
# meyerozyma_guilliermondii        0.001447
# yamadazyma_scolyti               0.001184
# kluyveromyces_unidentified       0.001184
# yamadazyma_mexicana              0.000987
# kodamaea_ohmeri                  0.000855
# kluyveromyces_marxianus          0.000855
# saccharomyces_cerevisiae         0.000592
# wickerhamomyces_anomalus         0.000526
# clavispora_lusitaniae            0.000526
# oculimacula_yallundae-ccl029     0.000460
# zygoascus_hellenicus             0.000460
# blastobotrys_proliferans         0.000395
# entoleuca_unidentified           0.000395
# tuber_brumale                    0.000197
# cortinarius_globuliformis        0.000197
# asteroma_ccl068                  0.000132
# zymoseptoria_tritici             0.000132
# oculimacula_yallundae-ccl031     0.000132
# pichia_kudriavzevii              0.000132
# pichia_membranifaciens           0.000132
# quambalaria_cyanescens           0.000132
# rhodotorula_mucilaginosa         0.000132
# yarrowia_lipolytica              0.000132
# cryptococcus_zero                0.000066
# fusarium_oxysporum               0.000066
# cladophialophora_unidentified    0.000066
# scedosporium_boydii              0.000066
# aspergillus_flavus               0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: candida_metapsilosis
#
# These are the results:
# tname
# candida_orthopsilosis            0.557372
# candida_metapsilosis             0.353986
# candida_parapsilosis             0.045290
# kodamaea_ohmeri                  0.016152
# diaporthe_unidentified           0.011888
# fusarium_oxysporum               0.006202
# candida_albicans                 0.001357
# candida_unidentified             0.001292
# meyerozyma_guilliermondii        0.000711
# debaryomyces_unidentified        0.000646
# saccharomyces_cerevisiae         0.000581
# kluyveromyces_unidentified       0.000581
# yamadazyma_mexicana              0.000517
# oculimacula_yallundae-ccl029     0.000388
# yamadazyma_scolyti               0.000388
# clavispora_lusitaniae            0.000323
# entoleuca_unidentified           0.000323
# kluyveromyces_marxianus          0.000258
# pichia_kudriavzevii              0.000194
# pyrenophora_tritici-repentis     0.000194
# zygoascus_hellenicus             0.000194
# cladophialophora_unidentified    0.000194
# yarrowia_lipolytica              0.000129
# galactomyces_geotrichum          0.000129
# wickerhamomyces_anomalus         0.000129
# blastobotrys_proliferans         0.000065
# asteroma_ccl060                  0.000065
# asteroma_ccl068                  0.000065
# zymoseptoria_tritici             0.000065
# oculimacula_yallundae-ccl031     0.000065
# pichia_membranifaciens           0.000065
# puccinia_striiformis-tritici     0.000065
# tuber_brumale                    0.000065
# aspergillus_flavus               0.000065
# dtype: float64
#
# True
# ##########
#
# This was the query species: candida_orthopsilosis
#
# These are the results:
# tname
# candida_orthopsilosis            0.567648
# candida_metapsilosis             0.366399
# candida_parapsilosis             0.046207
# meyerozyma_guilliermondii        0.009441
# candida_unidentified             0.002194
# candida_albicans                 0.001263
# debaryomyces_unidentified        0.001197
# saccharomyces_cerevisiae         0.000665
# kluyveromyces_marxianus          0.000465
# clavispora_lusitaniae            0.000399
# entoleuca_unidentified           0.000332
# yamadazyma_scolyti               0.000332
# kluyveromyces_unidentified       0.000266
# wickerhamomyces_anomalus         0.000266
# yamadazyma_mexicana              0.000266
# blastobotrys_proliferans         0.000199
# zygoascus_hellenicus             0.000199
# galactomyces_geotrichum          0.000199
# oculimacula_yallundae-ccl029     0.000199
# oculimacula_yallundae-ccl031     0.000199
# quambalaria_cyanescens           0.000199
# pichia_membranifaciens           0.000199
# aspergillus_flavus               0.000133
# aspergillus_unidentified         0.000133
# cladophialophora_unidentified    0.000133
# puccinia_striiformis-tritici     0.000066
# aspergillus_niger                0.000066
# asteroma_ccl068                  0.000066
# tuber_brumale                    0.000066
# scedosporium_boydii              0.000066
# kodamaea_ohmeri                  0.000066
# yarrowia_lipolytica              0.000066
# penicillium_chrysogenum          0.000066
# cortinarius_globuliformis        0.000066
# cryptococcus_zero                0.000066
# diaporthe_unidentified           0.000066
# dothiorella_vidmadera            0.000066
# pichia_kudriavzevii              0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: candida_parapsilosis
#
# These are the results:
# tname
# candida_parapsilosis             0.828866
# candida_orthopsilosis            0.090323
# candida_metapsilosis             0.072098
# candida_unidentified             0.001330
# meyerozyma_guilliermondii        0.000998
# debaryomyces_unidentified        0.000865
# candida_albicans                 0.000732
# kluyveromyces_unidentified       0.000466
# wickerhamomyces_anomalus         0.000399
# oculimacula_yallundae-ccl029     0.000399
# entoleuca_unidentified           0.000333
# cortinarius_globuliformis        0.000333
# kluyveromyces_marxianus          0.000333
# saccharomyces_cerevisiae         0.000266
# yamadazyma_mexicana              0.000266
# tuber_brumale                    0.000200
# yamadazyma_scolyti               0.000200
# clavispora_lusitaniae            0.000133
# cryptococcus_zero                0.000133
# zymoseptoria_tritici             0.000133
# kodamaea_ohmeri                  0.000133
# pyrenophora_tritici-repentis     0.000133
# galactomyces_geotrichum          0.000067
# dothiorella_vidmadera            0.000067
# zygoascus_hellenicus             0.000067
# penicillium_chrysogenum          0.000067
# pichia_membranifaciens           0.000067
# cladophialophora_unidentified    0.000067
# quambalaria_cyanescens           0.000067
# rhodotorula_mucilaginosa         0.000067
# scedosporium_boydii              0.000067
# yarrowia_lipolytica              0.000067
# blastobotrys_proliferans         0.000067
# asteroma_ccl060                  0.000067
# aspergillus_unidentified         0.000067
# aspergillus_niger                0.000067
# dtype: float64
# True
# ##########
#
# This was the query species: candida_unidentified
#
# These are the results:
# tname
# candida_unidentified             0.818551
# candida_albicans                 0.166079
# candida_metapsilosis             0.002861
# candida_orthopsilosis            0.002063
# meyerozyma_guilliermondii        0.001530
# debaryomyces_unidentified        0.001131
# candida_parapsilosis             0.000865
# yamadazyma_mexicana              0.000798
# saccharomyces_cerevisiae         0.000732
# kluyveromyces_unidentified       0.000665
# oculimacula_yallundae-ccl029     0.000665
# entoleuca_unidentified           0.000599
# blastobotrys_proliferans         0.000466
# kodamaea_ohmeri                  0.000466
# yarrowia_lipolytica              0.000333
# wickerhamomyces_anomalus         0.000266
# yamadazyma_scolyti               0.000266
# pichia_membranifaciens           0.000200
# tuber_brumale                    0.000200
# oculimacula_yallundae-ccl031     0.000133
# zygoascus_hellenicus             0.000133
# diaporthe_unidentified           0.000133
# cryptococcus_zero                0.000133
# clavispora_lusitaniae            0.000133
# kluyveromyces_marxianus          0.000133
# zymoseptoria_tritici             0.000067
# cladophialophora_unidentified    0.000067
# cortinarius_globuliformis        0.000067
# galactomyces_geotrichum          0.000067
# quambalaria_cyanescens           0.000067
# rhodotorula_mucilaginosa         0.000067
# asteroma_ccl060                  0.000067
# dtype: float64
#
# True
# ##########
#
# This was the query species: kluyveromyces_marxianus
#
# These are the results:
# tname
# kluyveromyces_marxianus          0.633453
# kluyveromyces_unidentified       0.352464
# saccharomyces_cerevisiae         0.002657
# candida_metapsilosis             0.000930
# wickerhamomyces_anomalus         0.000864
# entoleuca_unidentified           0.000664
# yarrowia_lipolytica              0.000664
# oculimacula_yallundae-ccl029     0.000598
# candida_parapsilosis             0.000598
# debaryomyces_unidentified        0.000531
# meyerozyma_guilliermondii        0.000465
# yamadazyma_scolyti               0.000465
# yamadazyma_mexicana              0.000465
# penicillium_chrysogenum          0.000399
# tuber_brumale                    0.000399
# clavispora_lusitaniae            0.000332
# candida_unidentified             0.000332
# candida_albicans                 0.000332
# zymoseptoria_tritici             0.000266
# kodamaea_ohmeri                  0.000266
# pichia_membranifaciens           0.000266
# cladophialophora_unidentified    0.000266
# zygoascus_hellenicus             0.000199
# pichia_kudriavzevii              0.000199
# dothiorella_vidmadera            0.000199
# quambalaria_cyanescens           0.000199
# blastobotrys_proliferans         0.000199
# cryptococcus_zero                0.000199
# candida_orthopsilosis            0.000133
# galactomyces_geotrichum          0.000133
# cortinarius_globuliformis        0.000133
# diaporthe_ccl067                 0.000066
# diaporthe_unidentified           0.000066
# oculimacula_yallundae-ccl031     0.000066
# puccinia_striiformis-tritici     0.000066
# rhodotorula_mucilaginosa         0.000066
# scedosporium_boydii              0.000066
# asteroma_ccl068                  0.000066
# asteroma_ccl060                  0.000066
# aspergillus_unidentified         0.000066
# aspergillus_niger                0.000066
# aspergillus_flavus               0.000066
# dtype: float64
#
# True
# ##########
#
# This was the query species: pichia_kudriavzevii
#
# These are the results:
# tname
# pichia_kudriavzevii              0.944954
# zygoascus_hellenicus             0.018135
# rhodotorula_mucilaginosa         0.017943
# asteroma_ccl060                  0.012047
# pichia_membranifaciens           0.002371
# kodamaea_ohmeri                  0.000449
# kluyveromyces_unidentified       0.000384
# candida_unidentified             0.000384
# candida_orthopsilosis            0.000384
# saccharomyces_cerevisiae         0.000320
# yamadazyma_scolyti               0.000256
# oculimacula_yallundae-ccl029     0.000256
# yamadazyma_mexicana              0.000192
# yarrowia_lipolytica              0.000192
# tuber_brumale                    0.000192
# kluyveromyces_marxianus          0.000192
# candida_parapsilosis             0.000192
# cortinarius_globuliformis        0.000192
# candida_albicans                 0.000128
# candida_metapsilosis             0.000128
# meyerozyma_guilliermondii        0.000128
# clavispora_lusitaniae            0.000128
# quambalaria_cyanescens           0.000128
# cladophialophora_unidentified    0.000064
# debaryomyces_unidentified        0.000064
# penicillium_chrysogenum          0.000064
# scedosporium_boydii              0.000064
# wickerhamomyces_anomalus         0.000064
# dtype: float64
#
# True
# ##########
#
# This was the query species: pichia_membranifaciens
#
# These are the results:
# tname
# pichia_membranifaciens           0.987299
# pichia_kudriavzevii              0.003591
# asteroma_ccl068                  0.000731
# scedosporium_boydii              0.000598
# aspergillus_flavus               0.000598
# saccharomyces_cerevisiae         0.000532
# kluyveromyces_marxianus          0.000532
# kodamaea_ohmeri                  0.000465
# kluyveromyces_unidentified       0.000465
# oculimacula_yallundae-ccl029     0.000399
# candida_metapsilosis             0.000332
# candida_albicans                 0.000332
# debaryomyces_unidentified        0.000332
# yamadazyma_scolyti               0.000332
# candida_unidentified             0.000332
# candida_orthopsilosis            0.000266
# candida_parapsilosis             0.000266
# meyerozyma_guilliermondii        0.000266
# clavispora_lusitaniae            0.000199
# cortinarius_globuliformis        0.000199
# zygoascus_hellenicus             0.000199
# entoleuca_unidentified           0.000199
# tuber_brumale                    0.000199
# yamadazyma_mexicana              0.000199
# cryptococcus_zero                0.000133
# yarrowia_lipolytica              0.000133
# quambalaria_cyanescens           0.000133
# wickerhamomyces_anomalus         0.000133
# galactomyces_geotrichum          0.000133
# dothiorella_vidmadera            0.000066
# diaporthe_ccl067                 0.000066
# fusarium_oxysporum               0.000066
# cladophialophora_unidentified    0.000066
# oculimacula_yallundae-ccl031     0.000066
# puccinia_striiformis-tritici     0.000066
# aspergillus_unidentified         0.000066
# dtype: float64

# %%
### These results show which the proportion of reads that match
### the sample label at each taxonomic rank

for species in mock_community:
    print(species)
    mapping_results = pull_mapping_results(sub_db_mapping_fn[species])
    
    mapping_results = assign_taxranks_results(mapping_results, taxonomy_file_fn, ref_df_fn=reference_dataframe_fn)

    taxfileid = getquery_taxfileid(reference_dataframe_fn, species)

    query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

    sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

    print(json.dumps(sensitivity_dict, indent=1))
    
    with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/tax_rank/%s.json' % species,'w+') as json_file:
        json.dump(sensitivity_dict,json_file)
# Out:
# puccinia_striiformis-tritici
# {
#  "k": 1.0,
#  "p": 0.9955339288094921,
#  "c": 0.9944674043460872,
#  "o": 0.9944674043460872,
#  "f": 0.9944674043460872,
#  "g": 0.9944674043460872,
#  "s": 0.9944674043460872
# }
# zymoseptoria_tritici
# {
#  "k": 1.0,
#  "p": 0.9996670218433671,
#  "c": 0.9938066062866276,
#  "o": 0.9915423548215238,
#  "f": 0.9915423548215238,
#  "g": 0.9915423548215238,
#  "s": 0.9915423548215238
# }
# pyrenophora_tritici-repentis
# {
#  "k": 1.0,
#  "p": 0.9996680167319567,
#  "c": 0.9907708651483965,
#  "o": 0.9568421751543722,
#  "f": 0.9568421751543722,
#  "g": 0.9568421751543722,
#  "s": 0.9568421751543722
# }
# fusarium_oxysporum
# {
#  "k": 1.0,
#  "p": 0.9996061700032819,
#  "c": 0.9811617984903184,
#  "o": 0.9725631768953069,
#  "f": 0.9725631768953069,
#  "g": 0.9725631768953069,
#  "s": 0.9725631768953069
# }
# tuber_brumale
# {
#  "k": 1.0,
#  "p": 0.9994016753091344,
#  "c": 0.9900279218189071,
#  "o": 0.9900279218189071,
#  "f": 0.9900279218189071,
#  "g": 0.9900279218189071,
#  "s": 0.9900279218189071
# }
# cortinarius_globuliformis
# {
#  "k": 1.0,
#  "p": 0.9924116354922452,
#  "c": 0.9906143912667243,
#  "o": 0.9906143912667243,
#  "f": 0.9906143912667243,
#  "g": 0.9906143912667243,
#  "s": 0.9906143912667243
# }
# aspergillus_niger
# {
#  "k": 1.0,
#  "p": 0.9994722607032126,
#  "c": 0.9881258658222838,
#  "o": 0.9879279635859886,
#  "f": 0.9879279635859886,
#  "g": 0.9862128108714295,
#  "s": 0.754601226993865
# }
# clavispora_lusitaniae
# {
#  "k": 1.0,
#  "p": 0.9994673768308922,
#  "c": 0.9973368841544608,
#  "o": 0.9973368841544608,
#  "f": 0.9868175765645806,
#  "g": 0.9848868175765646,
#  "s": 0.9848868175765646
# }
# kluyveromyces_unidentified
# {
#  "k": 1.0,
#  "p": 0.9302157327019206,
#  "c": 0.9208103130755064,
#  "o": 0.9208103130755064,
#  "f": 0.9040384109444883,
#  "g": 0.902657195474875,
#  "s": 0.374177847934754
# }
# penicillium_chrysogenum
# {
#  "k": 1.0,
#  "p": 0.9992014905509715,
#  "c": 0.9937450093159436,
#  "o": 0.9937450093159436,
#  "f": 0.9937450093159436,
#  "g": 0.9869576789992015,
#  "s": 0.9869576789992015
# }
# rhodotorula_mucilaginosa
# {
#  "k": 1.0,
#  "p": 0.9842327483836918,
#  "c": 0.9825834542815675,
#  "o": 0.9825834542815675,
#  "f": 0.9825834542815675,
#  "g": 0.9825834542815675,
#  "s": 0.9825834542815675
# }
# scedosporium_boydii
# {
#  "k": 1.0,
#  "p": 0.9992012247886574,
#  "c": 0.9948745257272182,
#  "o": 0.9916128602809026,
#  "f": 0.9916128602809026,
#  "g": 0.9916128602809026,
#  "s": 0.9916128602809026
# }
# blastobotrys_proliferans
# {
#  "k": 1.0,
#  "p": 0.9999333733093477,
#  "c": 0.9985342128056499,
#  "o": 0.9985342128056499,
#  "f": 0.9950029982010794,
#  "g": 0.9950029982010794,
#  "s": 0.9950029982010794
# }
# debaryomyces_unidentified
# {
#  "k": 1.0,
#  "p": 0.9999334132374484,
#  "c": 0.9979358103609003,
#  "o": 0.9979358103609003,
#  "f": 0.9890131841789852,
#  "g": 0.9844186975629244,
#  "s": 0.9855506725263018
# }
# galactomyces_geotrichum
# {
#  "k": 1.0,
#  "p": 0.9991906656774803,
#  "c": 0.9942672152154852,
#  "o": 0.9942672152154852,
#  "f": 0.9852970931408916,
#  "g": 0.9847575369258784,
#  "s": 0.9847575369258784
# }
# kodamaea_ohmeri
# {
#  "k": 1.0,
#  "p": 0.9998085635887946,
#  "c": 0.9670091251356008,
#  "o": 0.9670091251356008,
#  "f": 0.9465892412736903,
#  "g": 0.9462063684512795,
#  "s": 0.9462063684512795
# }
# meyerozyma_guilliermondii
# {
#  "k": 1.0,
#  "p": 0.9996671991480298,
#  "c": 0.998069755058573,
#  "o": 0.998069755058573,
#  "f": 0.9916799787007454,
#  "g": 0.9882854100106496,
#  "s": 0.9882854100106496
# }
# wickerhamomyces_anomalus
# {
#  "k": 1.0,
#  "p": 0.9998667732480682,
#  "c": 0.9986011191047163,
#  "o": 0.9986011191047163,
#  "f": 0.9922728483879563,
#  "g": 0.9922728483879563,
#  "s": 0.9922728483879563
# }
# yamadazyma_mexicana
# {
#  "k": 1.0,
#  "p": 0.9999334176709501,
#  "c": 0.9981356947866037,
#  "o": 0.9981356947866037,
#  "f": 0.99487316066316,
#  "g": 0.9927425261335642,
#  "s": 0.9796923896397896
# }
# yamadazyma_scolyti
# {
#  "k": 1.0,
#  "p": 0.9998001731832412,
#  "c": 0.9994005195497235,
#  "o": 0.9994005195497235,
#  "f": 0.9967361619929395,
#  "g": 0.9946046759475121,
#  "s": 0.987077865849597
# }
# yarrowia_lipolytica
# {
#  "k": 1.0,
#  "p": 1.0,
#  "c": 0.9996667777407531,
#  "o": 0.9996667777407531,
#  "f": 0.9989336887704099,
#  "g": 0.9988670443185604,
#  "s": 0.9988670443185604
# }
# zygoascus_hellenicus
# {
#  "k": 1.0,
#  "p": 0.9929476296199556,
#  "c": 0.9849157633537939,
#  "o": 0.9849157633537939,
#  "f": 0.9731618127203866,
#  "g": 0.9730312132689043,
#  "s": 0.9730312132689043
# }
# aspergillus_flavus
# {
#  "k": 1.0,
#  "p": 0.9998667732480682,
#  "c": 0.997468691713296,
#  "o": 0.9974020783373302,
#  "f": 0.9974020783373302,
#  "g": 0.9960031974420464,
#  "s": 0.9891420197175593
# }
# cryptococcus_zero
# {
#  "k": 1.0,
#  "p": 0.9960002666488901,
#  "c": 0.9942003866408906,
#  "o": 0.9942003866408906,
#  "f": 0.9942003866408906,
#  "g": 0.9942003866408906,
#  "s": 0.9942003866408906
# }
# aspergillus_unidentified
# {
#  "k": 1.0,
#  "p": 0.9997336529497935,
#  "c": 0.9950059928086297,
#  "o": 0.9947396457584232,
#  "f": 0.9947396457584232,
#  "g": 0.9936742575575975,
#  "s": 0.669463310693834
# }
# diaporthe_ccl067
# {
#  "k": 1.0,
#  "p": 0.9992726310917146,
#  "c": 0.9892217152681346,
#  "o": 0.9881637241288104,
#  "f": 0.4576472922039278,
#  "g": 0.4576472922039278,
#  "s": 0.45592805660252594
# }
# diaporthe_unidentified
# {
#  "k": 1.0,
#  "p": 0.9996076379806434,
#  "c": 0.981624378760136,
#  "o": 0.9745618624117185,
#  "f": 0.5541459586712006,
#  "g": 0.5541459586712006,
#  "s": 0.5545383206905572
# }
# oculimacula_yallundae-ccl031
# {
#  "k": 1.0,
#  "p": 0.9986684420772304,
#  "c": 0.9920772303595207,
#  "o": 0.9920772303595207,
#  "f": 0.9920772303595207,
#  "g": 0.9920772303595207,
#  "s": 0.9920772303595207
# }
# oculimacula_yallundae-ccl029
# {
#  "k": 1.0,
#  "p": 0.9987368700970616,
#  "c": 0.9887647919159687,
#  "o": 0.9887647919159687,
#  "f": 0.9887647919159687,
#  "g": 0.9887647919159687,
#  "s": 0.9887647919159687
# }
# dothiorella_vidmadera
# {
#  "k": 1.0,
#  "p": 0.9990015309858218,
#  "c": 0.9890834054449844,
#  "o": 0.9866205152100113,
#  "f": 0.9866205152100113,
#  "g": 0.9866205152100113,
#  "s": 0.9866205152100113
# }
# quambalaria_cyanescens
# {
#  "k": 1.0,
#  "p": 0.9938674843354219,
#  "c": 0.9925343287561659,
#  "o": 0.9925343287561659,
#  "f": 0.9925343287561659,
#  "g": 0.9925343287561659,
#  "s": 0.9925343287561659
# }
# entoleuca_unidentified
# {
#  "k": 1.0,
#  "p": 0.9991345449703748,
#  "c": 0.9918114639504694,
#  "o": 0.9882164969043339,
#  "f": 0.9882164969043339,
#  "g": 0.9882164969043339,
#  "s": 0.9898142600359496
# }
# asteroma_ccl060
# {
#  "k": 1.0,
#  "p": 0.9893727995827357,
#  "c": 0.9709218933368106,
#  "o": 0.9690311644282175,
#  "f": 0.44790715869083325,
#  "g": 0.44790715869083325,
#  "s": 0.4469943930108228
# }
# asteroma_ccl068
# {
#  "k": 1.0,
#  "p": 0.9990706936608031,
#  "c": 0.9932957185529373,
#  "o": 0.9913707268503154,
#  "f": 0.5586458679057418,
#  "g": 0.5586458679057418,
#  "s": 0.5568536342515765
# }
# saccharomyces_cerevisiae
# {
#  "k": 1.0,
#  "p": 1.0,
#  "c": 0.9970699873476726,
#  "o": 0.9970699873476726,
#  "f": 0.9912765532396617,
#  "g": 0.9874142638343211,
#  "s": 0.9874142638343211
# }
# cladophialophora_unidentified
# {
#  "k": 1.0,
#  "p": 0.9996671326809133,
#  "c": 0.9946741228946142,
#  "o": 0.9940749617202583,
#  "f": 0.9940749617202583,
#  "g": 0.9940749617202583,
#  "s": 0.9952732840689701
# }
# candida_albicans
# {
#  "k": 1.0,
#  "p": 0.9994737188342873,
#  "c": 0.9914479310571673,
#  "o": 0.9914479310571673,
#  "f": 0.9763831326886389,
#  "g": 0.9763831326886389,
#  "s": 0.36168673113610944
# }
# candida_metapsilosis
# {
#  "k": 1.0,
#  "p": 0.999935392169531,
#  "c": 0.9803592195374079,
#  "o": 0.9803592195374079,
#  "f": 0.9592970668044967,
#  "g": 0.9592970668044967,
#  "s": 0.35398630313994056
# }
# candida_orthopsilosis
# {
#  "k": 1.0,
#  "p": 0.999601090353035,
#  "c": 0.9980054517651752,
#  "o": 0.9980054517651752,
#  "f": 0.9837111894155973,
#  "g": 0.9837111894155973,
#  "s": 0.5676484276311415
# }
# candida_parapsilosis
# {
#  "k": 1.0,
#  "p": 0.9994013967409379,
#  "c": 0.9977386099102095,
#  "o": 0.9977386099102095,
#  "f": 0.9933488526770868,
#  "g": 0.9933488526770868,
#  "s": 0.8288659793814434
# }
# candida_unidentified
# {
#  "k": 1.0,
#  "p": 0.9996673098675893,
#  "c": 0.9977377070996074,
#  "o": 0.9977377070996074,
#  "f": 0.9904185241865726,
#  "g": 0.9904185241865726,
#  "s": 0.8211457848160224
# }
# kluyveromyces_marxianus
# {
#  "k": 1.0,
#  "p": 0.9993357247243257,
#  "c": 0.9959479208183871,
#  "o": 0.9959479208183871,
#  "f": 0.9885744652584031,
#  "g": 0.9859173641557061,
#  "s": 0.6334529028829547
# }
# pichia_kudriavzevii
# {
#  "k": 1.0,
#  "p": 0.9817366228772829,
#  "c": 0.969048381928869,
#  "o": 0.969048381928869,
#  "f": 0.9473245754565844,
#  "g": 0.9473245754565844,
#  "s": 0.9449535405318809
# }
# pichia_membranifaciens
# {
#  "k": 1.0,
#  "p": 0.9994680143636122,
#  "c": 0.9963425987498338,
#  "o": 0.9963425987498338,
#  "f": 0.9908897459768586,
#  "g": 0.9908897459768586,
#  "s": 0.9872988429312408
# }

# %% [markdown]
# ### Notebook to analyzse the efficiency of minimap2 mapping for Oxford Nanopore MinION reads against Qiime2 Database

# %%
os.path.abspath(os.curdir)
# Out:
# '/media/MassStorage/tmp/TE/honours/scripts/Notebooks'

# %%
qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10
QIIME_DIR = os.path.abspath('../../analysis/qiime2/')

# %%
##mapping folder
mapping_dir = os.path.join(QIIME_DIR, os.path.basename(qiime_db_fn).replace('.fasta', '').replace('.','_'))
if not os.path.exists(mapping_dir):
    os.mkdir(mapping_dir)
subsampling_dir = os.path.join(QIIME_DIR, 'subsamplereads')
if not os.path.exists(subsampling_dir):
    os.mkdir(subsampling_dir)

# %%
import json
from collections import OrderedDict

def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarises the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = OrderedDict()
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        tmps_df = pd.DataFrame(data=None)
        if tax_rank == 's':
            for index, row in mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]].iterrows():
                if row['s'] == 'unidentified' and row['g'] != query_tax_dict['g']:
                    mapping_df.drop(index, axis=0, inplace=True)
                else:
                    continue
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        else:
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)

def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df
    
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)

test_species_list = []
for entry in ref_df.name_species.tolist():
#     if entry[-7:] != '-ccl031' and entry[-7:] != '-ccl029':
#         test_species_list.append(entry)
#     else:
#         test_species_list.append(entry[:-7])
#         print(entry[:-7])
    test_species_list.append(entry)
    
for test_species in test_species_list:
    
    print(test_species)
    
    #subsample tests species
    fn_subsampling = {}
    test_species = [test_species]
    for x in test_species:
        fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
        fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

    sub_reads_fn = {}
    n_reads = 15000
    for key, value in fn_subsampling.items():
        species = key
        in_fn = value
        out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
        subsamplereads(in_fn, out_fn, n_reads)
        sub_reads_fn[species] = out_fn
        
    ###Map the reads
    db_fn = qiime_db_fn
    sub_db_mapping_fn = {}
    for species, fasta_fn in sub_reads_fn.items():
        db_name = os.path.basename(db_fn).replace('.fasta', '')
        out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
        sub_db_mapping_fn[species] = out_fn
        minimapmapping(fasta_fn, db_fn, out_fn, threads)
        
    ###Test out the summary results statistic for a single mapping result
    species = test_species[0]
    mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
    mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
    taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
    
    query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

    print(query_tax_dict)
    
    sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)
        
    print(json.dumps(sensitivity_dict, indent=1))
    
    with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/qiime_results/tax_rank/%s.json' % species,'w+') as json_file:
        json.dump(sensitivity_dict,json_file)
# Out:
# puccinia_striiformis-tritici
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Pucciniomycetes', 'o': 'Pucciniales', 'f': 'Pucciniaceae', 'g': 'Puccinia', 's': 'Puccinia_striiformis'}
# {
#  "k": 1.0,
#  "p": 0.9562130177514793,
#  "c": 0.8740959894806049,
#  "o": 0.8740959894806049,
#  "f": 0.8723208415516108,
#  "g": 0.8619986850756082,
#  "s": 0.801051939513478
# }
# zymoseptoria_tritici
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Dothideomycetes', 'o': 'Capnodiales', 'f': 'Mycosphaerellaceae', 'g': 'Zymoseptoria', 's': 'Zymoseptoria_tritici'}
# {
#  "k": 1.0,
#  "p": 0.8341285085816965,
#  "c": 0.35993555982402875,
#  "o": 0.18811574446991758,
#  "f": 0.1839023483487205,
#  "g": 0.16159613358944172,
#  "s": 0.0
# }
# pyrenophora_tritici-repentis
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Dothideomycetes', 'o': 'Pleosporales', 'f': 'Pleosporaceae', 'g': 'Pyrenophora', 's': 'Pyrenophora_tritici-repentis'}
# {
#  "k": 1.0,
#  "p": 0.844637829536729,
#  "c": 0.6033401586895316,
#  "o": 0.5959175838239058,
#  "f": 0.35865113898131556,
#  "g": 0.3045175326337343,
#  "s": 0.2966470437675966
# }
# fusarium_oxysporum
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Hypocreales', 'f': 'Nectriaceae', 'g': 'Fusarium', 's': 'Fusarium_oxysporum'}
# {
#  "k": 1.0,
#  "p": 0.9889788015687832,
#  "c": 0.8369656952787569,
#  "o": 0.5967830015389962,
#  "f": 0.5790100779427096,
#  "g": 0.49262771186019955,
#  "s": 0.10599215608399941
# }
# tuber_brumale
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Pezizomycetes', 'o': 'Pezizales', 'f': 'Tuberaceae', 'g': 'Tuber', 's': 'Tuber_brumale'}
# {
#  "k": 1.0,
#  "p": 0.9242064217388656,
#  "c": 0.48333637969901905,
#  "o": 0.48333637969901905,
#  "f": 0.48333637969901905,
#  "g": 0.48333637969901905,
#  "s": 0.48327545238530434
# }
# cortinarius_globuliformis
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Agaricomycetes', 'o': 'Agaricales', 'f': 'Cortinariaceae', 'g': 'Cortinarius', 's': 'Cortinarius_globuliformis'}
# {
#  "k": 1.0,
#  "p": 0.9101073345259392,
#  "c": 0.8448121645796064,
#  "o": 0.7964477383082035,
#  "f": 0.4217352415026834,
#  "g": 0.40780730897009965,
#  "s": 0.1348709430104779
# }
# aspergillus_niger
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Eurotiomycetes', 'o': 'Eurotiales', 'f': 'Aspergillaceae', 'g': 'Aspergillus', 's': 'Aspergillus_niger'}
# {
#  "k": 1.0,
#  "p": 0.94044933682216,
#  "c": 0.619146440494451,
#  "o": 0.6179734728864026,
#  "f": 0.6177479021925472,
#  "g": 0.4781196426960209,
#  "s": 0.15614003428674547
# }
# clavispora_lusitaniae
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Metschnikowiaceae', 'g': 'Clavispora', 's': 'Clavispora_lusitaniae'}
# {
#  "k": 1.0,
#  "p": 0.9166620552266062,
#  "c": 0.5796580156051132,
#  "o": 0.5796580156051132,
#  "f": 0.17547451718222568,
#  "g": 0.1746997952520613,
#  "s": 0.1722096176193902
# }
# kluyveromyces_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetaceae', 'g': 'Kluyveromyces', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.8710018668326074,
#  "c": 0.7006845052893591,
#  "o": 0.7006845052893591,
#  "f": 0.6092097075295582,
#  "g": 0.4976975731176105,
#  "s": 0.0
# }
# penicillium_chrysogenum
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Eurotiomycetes', 'o': 'Eurotiales', 'f': 'Aspergillaceae', 'g': 'Penicillium', 's': 'Penicillium_chrysogenum'}
# {
#  "k": 1.0,
#  "p": 0.9554882091107112,
#  "c": 0.6781418694952174,
#  "o": 0.6507718533952079,
#  "f": 0.6482621460365565,
#  "g": 0.5539350317264893,
#  "s": 0.045885026991192346
# }
# rhodotorula_mucilaginosa
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Microbotryomycetes', 'o': 'Sporidiobolales', 'f': 'Sporidiobolaceae', 'g': 'Rhodotorula', 's': 'Rhodotorula_mucilaginosa'}
# {
#  "k": 1.0,
#  "p": 0.9285580815945188,
#  "c": 0.8092805979445655,
#  "o": 0.8088445966988477,
#  "f": 0.8088445966988477,
#  "g": 0.7986919962628465,
#  "s": 0.6029274369355341
# }
# scedosporium_boydii
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Microascales', 'f': 'Microascaceae', 'g': 'Scedosporium', 's': 'Scedosporium_boydii'}
# {
#  "k": 1.0,
#  "p": 0.9904975812024879,
#  "c": 0.8690969822621516,
#  "o": 0.7303040774015204,
#  "f": 0.49550794747753973,
#  "g": 0.2988366735775167,
#  "s": 0.28656991476618293
# }
# blastobotrys_proliferans
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Trichomonascaceae', 'g': 'Blastobotrys', 's': 'Blastobotrys_proliferans'}
# {
#  "k": 1.0,
#  "p": 0.9189696136051019,
#  "c": 0.664124046517444,
#  "o": 0.664124046517444,
#  "f": 0.540515193197449,
#  "g": 0.531824434162811,
#  "s": 0.5312617231461798
# }
# debaryomyces_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Debaryomycetaceae', 'g': 'Debaryomyces', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.9712056827551214,
#  "c": 0.884125071351557,
#  "o": 0.884125071351557,
#  "f": 0.02257880383078582,
#  "g": 0.0013953193378575506,
#  "s": 0.0
# }
# galactomyces_geotrichum
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Dipodascaceae', 'g': 'Galactomyces', 's': 'Galactomyces_geotrichum'}
# {
#  "k": 1.0,
#  "p": 0.9411825298722702,
#  "c": 0.7701380304903173,
#  "o": 0.7575710754017305,
#  "f": 0.7259476720230738,
#  "g": 0.0,
#  "s": 0.0
# }
# kodamaea_ohmeri
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Metschnikowiaceae', 'g': 'Kodamaea', 's': 'Kodamaea_ohmeri'}
# {
#  "k": 1.0,
#  "p": 0.8881764555014107,
#  "c": 0.625673249551167,
#  "o": 0.625673249551167,
#  "f": 0.45800205180815595,
#  "g": 0.45800205180815595,
#  "s": 0.45800205180815595
# }
# meyerozyma_guilliermondii
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Debaryomycetaceae', 'g': 'Meyerozyma', 's': 'Meyerozyma_guilliermondii'}
# {
#  "k": 1.0,
#  "p": 0.963316304548532,
#  "c": 0.7987936234381732,
#  "o": 0.7987936234381732,
#  "f": 0.5183110728134425,
#  "g": 0.5098787468455714,
#  "s": 0.44759032436757556
# }
# wickerhamomyces_anomalus
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Phaffomycetaceae', 'g': 'Wickerhamomyces', 's': 'Wickerhamomyces_anomalus'}
# {
#  "k": 1.0,
#  "p": 0.9676904412234212,
#  "c": 0.8233190728561395,
#  "o": 0.8233190728561395,
#  "f": 0.6517463763488921,
#  "g": 0.6511078475193155,
#  "s": 0.6206500223485091
# }
# yamadazyma_mexicana
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Debaryomycetaceae', 'g': 'Yamadazyma', 's': 'Yamadazyma_mexicana'}
# {
#  "k": 1.0,
#  "p": 0.9470909552845529,
#  "c": 0.7951600609756098,
#  "o": 0.7951600609756098,
#  "f": 0.6092479674796748,
#  "g": 0.5994029471544715,
#  "s": 0.5383638211382114
# }
# yamadazyma_scolyti
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Debaryomycetaceae', 'g': 'Yamadazyma', 's': 'Yamadazyma_scolyti'}
# {
#  "k": 1.0,
#  "p": 0.9493841416474211,
#  "c": 0.8085706954067231,
#  "o": 0.8085706954067231,
#  "f": 0.45008981267641773,
#  "g": 0.44194251988709266,
#  "s": 0.42596869386707725
# }
# yarrowia_lipolytica
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Dipodascaceae', 'g': 'Yarrowia', 's': 'Yarrowia_lipolytica'}
# {
#  "k": 1.0,
#  "p": 0.8699395964528981,
#  "c": 0.20376558282997045,
#  "o": 0.20376558282997045,
#  "f": 0.00025703637064644646,
#  "g": 0.0,
#  "s": 0.0
# }
# zygoascus_hellenicus
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Trichomonascaceae', 'g': 'Zygoascus', 's': 'Zygoascus_hellenicus'}
# {
#  "k": 1.0,
#  "p": 0.9421318498625232,
#  "c": 0.794935737579129,
#  "o": 0.794935737579129,
#  "f": 0.7159664940213568,
#  "g": 0.6739561353027688,
#  "s": 0.6504252190037726
# }
# aspergillus_flavus
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Eurotiomycetes', 'o': 'Eurotiales', 'f': 'Aspergillaceae', 'g': 'Aspergillus', 's': 'Aspergillus_flavus'}
# {
#  "k": 1.0,
#  "p": 0.951682519382943,
#  "c": 0.7709215890016785,
#  "o": 0.7702821517064983,
#  "f": 0.7702421868755495,
#  "g": 0.6473902965390457,
#  "s": 0.5963552074174726
# }
# cryptococcus_zero
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Tremellomycetes', 'o': 'Tremellales', 'f': 'Tremellaceae', 'g': 'Cryptococcus', 's': 'Cryptococcus_zero'}
# {
#  "k": 1.0,
#  "p": 0.8877897252090801,
#  "c": 0.773142174432497,
#  "o": 0.0021983273596176823,
#  "f": 0.00023894862604540023,
#  "g": 0.0021983273596176823,
#  "s": 0.0
# }
# aspergillus_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Eurotiomycetes', 'o': 'Eurotiales', 'f': 'Aspergillaceae', 'g': 'Aspergillus', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.9483128364479846,
#  "c": 0.6535078121580813,
#  "o": 0.6524574379622741,
#  "f": 0.6523699067792901,
#  "g": 0.5191036806862445,
#  "s": 0.03221147533808919
# }
# diaporthe_ccl067
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Diaporthales', 'f': 'Diaporthaceae', 'g': 'Diaporthe', 's': 'Diaporthe_CCL067'}
# {
#  "k": 1.0,
#  "p": 0.9729810508697472,
#  "c": 0.7845657241915237,
#  "o": 0.47934724131747264,
#  "f": 0.004722338454181361,
#  "g": 0.004722338454181361,
#  "s": 0.0
# }
# diaporthe_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Diaporthales', 'f': 'Diaporthaceae', 'g': 'Diaporthe', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.9779748794571106,
#  "c": 0.7123638311804275,
#  "o": 0.311387582594202,
#  "f": 0.27424251443538306,
#  "g": 0.2722781117923686,
#  "s": 0.024822906125364606
# }
# oculimacula_yallundae-ccl031
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Leotiomycetes', 'o': 'Helotiales', 'f': 'Dermateaceae', 'g': 'Oculimacula', 's': 'Oculimacula_yallundae'}
# {
#  "k": 1.0,
#  "p": 0.9573016064742118,
#  "c": 0.8018480492813141,
#  "o": 0.6465152796231429,
#  "f": 0.12018359705278416,
#  "g": 0.10321294842372267,
#  "s": 0.0521198212344486
# }
# oculimacula_yallundae-ccl029
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Leotiomycetes', 'o': 'Helotiales', 'f': 'Dermateaceae', 'g': 'Oculimacula', 's': 'Oculimacula_yallundae'}
# {
#  "k": 1.0,
#  "p": 0.9545668549905838,
#  "c": 0.8302142184557438,
#  "o": 0.5726224105461394,
#  "f": 0.1832627118644068,
#  "g": 0.16148775894538606,
#  "s": 0.09080743879472693
# }
# dothiorella_vidmadera
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Dothideomycetes', 'o': 'Botryosphaeriales', 'f': 'Botryosphaeriaceae', 'g': 'Dothiorella', 's': 'Dothiorella_vidmadera'}
# {
#  "k": 1.0,
#  "p": 0.9229026260748315,
#  "c": 0.5569370206832442,
#  "o": 0.3101324657215896,
#  "f": 0.3095514757146177,
#  "g": 0.28526609342319315,
#  "s": 0.0
# }
# quambalaria_cyanescens
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Exobasidiomycetes', 'o': 'Microstromatales', 'f': 'Quambalariaceae', 'g': 'Quambalaria', 's': 'Quambalaria_cyanescens'}
# {
#  "k": 1.0,
#  "p": 0.9052947283423693,
#  "c": 0.7707924789479755,
#  "o": 0.770561771830661,
#  "f": 0.764101972545853,
#  "g": 0.764101972545853,
#  "s": 0.7110393355635022
# }
# entoleuca_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Xylariales', 'f': 'Xylariaceae', 'g': 'Entoleuca', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.9679527604196526,
#  "c": 0.8599438170039557,
#  "o": 0.6274150088860861,
#  "f": 0.595425098893539,
#  "g": 0.03147394370234478,
#  "s": 0.015192340767069885
# }
# asteroma_ccl060
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Diaporthales', 'f': 'Gnomoniaceae', 'g': 'Asteroma', 's': 'Asteroma_CCL060'}
# {
#  "k": 1.0,
#  "p": 0.9763606049779683,
#  "c": 0.7185304275336429,
#  "o": 0.3088603072525902,
#  "f": 0.00011909015124449208,
#  "g": 0.0,
#  "s": 0.0
# }
# asteroma_ccl068
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Sordariomycetes', 'o': 'Diaporthales', 'f': 'Gnomoniaceae', 'g': 'Asteroma', 's': 'Asteroma_CCL068'}
# {
#  "k": 1.0,
#  "p": 0.9735481543825899,
#  "c": 0.7914512444391006,
#  "o": 0.47457015750871706,
#  "f": 0.4475171335818204,
#  "g": 0.0,
#  "s": 0.0
# }
# saccharomyces_cerevisiae
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetaceae', 'g': 'Saccharomyces', 's': 'Saccharomyces_cerevisiae'}
# {
#  "k": 1.0,
#  "p": 0.9554016441193605,
#  "c": 0.7639329406434073,
#  "o": 0.7639329406434073,
#  "f": 0.7048352644184089,
#  "g": 0.6630849893196971,
#  "s": 0.4988025114894168
# }
# cladophialophora_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Eurotiomycetes', 'o': 'Chaetothyriales', 'f': 'Herpotrichiellaceae', 'g': 'Cladophialophora', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.9231377799415774,
#  "c": 0.43433544303797467,
#  "o": 0.4000730282375852,
#  "f": 0.3869279454722493,
#  "g": 0.3591163583252191,
#  "s": 0.3337390457643622
# }
# candida_albicans
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetales_fam_Incertae_sedis', 'g': 'Candida', 's': 'Candida_albicans'}
# {
#  "k": 1.0,
#  "p": 0.9345638619667881,
#  "c": 0.5976294833014384,
#  "o": 0.5976294833014384,
#  "f": 0.3740971664917587,
#  "g": 0.3740971664917587,
#  "s": 0.30551268596826964
# }
# candida_metapsilosis
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetales_fam_Incertae_sedis', 'g': 'Candida', 's': 'Candida_metapsilosis'}
# {
#  "k": 1.0,
#  "p": 0.9502836576587568,
#  "c": 0.6719941438418837,
#  "o": 0.6719941438418837,
#  "f": 0.6510705789056305,
#  "g": 0.651009577258586,
#  "s": 0.017995485878118708
# }
# candida_orthopsilosis
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetales_fam_Incertae_sedis', 'g': 'Candida', 's': 'Candida_orthopsilosis'}
# {
#  "k": 1.0,
#  "p": 0.9510279226756674,
#  "c": 0.6717397974838908,
#  "o": 0.6717397974838908,
#  "f": 0.6462104940165695,
#  "g": 0.6460263884627186,
#  "s": 0.3096655415771709
# }
# candida_parapsilosis
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetales_fam_Incertae_sedis', 'g': 'Candida', 's': 'Candida_parapsilosis'}
# {
#  "k": 1.0,
#  "p": 0.9498905375820968,
#  "c": 0.6724641206519095,
#  "o": 0.6724641206519095,
#  "f": 0.6569569447822914,
#  "g": 0.6569569447822914,
#  "s": 0.1899172950620287
# }
# candida_unidentified
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetales_fam_Incertae_sedis', 'g': 'Candida', 's': 'unidentified'}
# {
#  "k": 1.0,
#  "p": 0.937395296891481,
#  "c": 0.5846621579698456,
#  "o": 0.5846621579698456,
#  "f": 0.2989390085003413,
#  "g": 0.2989390085003413,
#  "s": 0.00043432400570825834
# }
# kluyveromyces_marxianus
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Saccharomycetaceae', 'g': 'Kluyveromyces', 's': 'Kluyveromyces_marxianus'}
# {
#  "k": 1.0,
#  "p": 0.9490740740740741,
#  "c": 0.7819634703196348,
#  "o": 0.7819634703196348,
#  "f": 0.6944444444444444,
#  "g": 0.5779426686960933,
#  "s": 0.5154743784880771
# }
# pichia_kudriavzevii
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Pichiaceae', 'g': 'Pichia', 's': 'Pichia_kudriavzevii'}
# {
#  "k": 1.0,
#  "p": 0.9504913480025635,
#  "c": 0.8423413800469985,
#  "o": 0.8423413800469985,
#  "f": 0.20732749412518692,
#  "g": 0.20679342020935698,
#  "s": 0.0
# }
# pichia_membranifaciens
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Saccharomycetes', 'o': 'Saccharomycetales', 'f': 'Pichiaceae', 'g': 'Pichia', 's': 'Pichia_membranifaciens'}
# {
#  "k": 1.0,
#  "p": 0.9436147516001219,
#  "c": 0.7956110941786041,
#  "o": 0.7956110941786041,
#  "f": 0.748796098750381,
#  "g": 0.747698872295032,
#  "s": 0.6996647363608656
# }

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')
subsampling_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/subsample_reads')
mapping_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/qiime_results')

wheat_reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/wheat_reference_dataframe_v3.csv')
wheat_max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/wheat_database_labelled.fasta')
wheat_taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/wheat_taxonomy_file_qiime.csv')

qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10

wheat_ref_df = pd.read_csv(wheat_reference_dataframe_fn)
wheat_ref_df
# Out:
#    Unnamed: 0    barcode  # raw reads  # reads after homology filtering  \
# 0   barcode01  barcode01       115052                             23477
# 1   barcode02  barcode02       151005                             20416
# 2   barcode03  barcode03        92927                             23616
# 3   barcode04  barcode04       115407                             22716
# 4   barcode05  barcode05       134094                             24785
# 5   barcode06  barcode06       150739                             25462
# 6   barcode07  barcode07       109201                             24688
# 7   barcode08  barcode08       114215                             21725
# 8   barcode09  barcode09       106976                             22012
# 9   barcode10  barcode10       108583                             21514
# 10  barcode11  barcode11       118345                             22462
# 11  barcode12  barcode12          260                                 3
#
#     # reads after length filtering  # for use  \
# 0                            21590    21590.0
# 1                            18100    18100.0
# 2                            21919    21919.0
# 3                            20568    20568.0
# 4                            22433    22433.0
# 5                            23769    23769.0
# 6                            22931    22931.0
# 7                            20105    20105.0
# 8                            20451    20451.0
# 9                            19810    19810.0
# 10                           20832    20832.0
# 11                               3        3.0
#
#                                     path to raw reads  \
# 0   analysis/Concatenated/wheat/barcode01/merged.f...
# 1   analysis/Concatenated/wheat/barcode02/merged.f...
# 2   analysis/Concatenated/wheat/barcode03/merged.f...
# 3   analysis/Concatenated/wheat/barcode04/merged.f...
# 4   analysis/Concatenated/wheat/barcode05/merged.f...
# 5   analysis/Concatenated/wheat/barcode06/merged.f...
# 6   analysis/Concatenated/wheat/barcode07/merged.f...
# 7   analysis/Concatenated/wheat/barcode08/merged.f...
# 8   analysis/Concatenated/wheat/barcode09/merged.f...
# 9   analysis/Concatenated/wheat/barcode10/merged.f...
# 10  analysis/Concatenated/wheat/barcode11/merged.f...
# 11  analysis/Concatenated/wheat/barcode12/merged.f...
#
#                            path to homology filtering  \
# 0   analysis/Python_Processing/wheat/barcode01/com...
# 1   analysis/Python_Processing/wheat/barcode02/com...
# 2   analysis/Python_Processing/wheat/barcode03/com...
# 3   analysis/Python_Processing/wheat/barcode04/com...
# 4   analysis/Python_Processing/wheat/barcode05/com...
# 5   analysis/Python_Processing/wheat/barcode06/com...
# 6   analysis/Python_Processing/wheat/barcode07/com...
# 7   analysis/Python_Processing/wheat/barcode08/com...
# 8   analysis/Python_Processing/wheat/barcode09/com...
# 9   analysis/Python_Processing/wheat/barcode10/com...
# 10  analysis/Python_Processing/wheat/barcode11/com...
# 11  analysis/Python_Processing/wheat/barcode12/com...
#
#                              path to length filtering  \
# 0   analysis/Length_Filtered/wheat/barcode01/lengt...
# 1   analysis/Length_Filtered/wheat/barcode02/lengt...
# 2   analysis/Length_Filtered/wheat/barcode03/lengt...
# 3   analysis/Length_Filtered/wheat/barcode04/lengt...
# 4   analysis/Length_Filtered/wheat/barcode05/lengt...
# 5   analysis/Length_Filtered/wheat/barcode06/lengt...
# 6   analysis/Length_Filtered/wheat/barcode07/lengt...
# 7   analysis/Length_Filtered/wheat/barcode08/lengt...
# 8   analysis/Length_Filtered/wheat/barcode09/lengt...
# 9   analysis/Length_Filtered/wheat/barcode10/lengt...
# 10  analysis/Length_Filtered/wheat/barcode11/lengt...
# 11  analysis/Length_Filtered/wheat/barcode12/lengt...
#
#                                          path for use
# 0   analysis/Length_Filtered/wheat/barcode01/lengt...
# 1   analysis/Length_Filtered/wheat/barcode02/lengt...
# 2   analysis/Length_Filtered/wheat/barcode03/lengt...
# 3   analysis/Length_Filtered/wheat/barcode04/lengt...
# 4   analysis/Length_Filtered/wheat/barcode05/lengt...
# 5   analysis/Length_Filtered/wheat/barcode06/lengt...
# 6   analysis/Length_Filtered/wheat/barcode07/lengt...
# 7   analysis/Length_Filtered/wheat/barcode08/lengt...
# 8   analysis/Length_Filtered/wheat/barcode09/lengt...
# 9   analysis/Length_Filtered/wheat/barcode10/lengt...
# 10  analysis/Length_Filtered/wheat/barcode11/lengt...
# 11  analysis/Length_Filtered/wheat/barcode12/lengt...

# %%
mock_community = ['barcode01','barcode02',
                  'barcode03','barcode04',
                 'barcode05','barcode06',
                  'barcode07','barcode08',
                  'barcode09','barcode10',
                  'barcode11','barcode12',
                 ]

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping/wheat')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)
sub_db_fn = os.path.join('../../analysis/Mapping/gsref.subdb.fasta')
new_db_fn = os.path.join('../../analysis/Mapping/gsref.db.fasta')

# %%
wheat_ref_df.columns
# Out:
# Index(['Unnamed: 0', 'barcode', '# raw reads',
#        '# reads after homology filtering', '# reads after length filtering',
#        '# for use', 'path to raw reads', 'path to homology filtering',
#        'path to length filtering', 'path for use'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    print(x)
    fn_subsampling[x] = wheat_ref_df[wheat_ref_df['Unnamed: 0'] == x]['path for use'].tolist()[0]
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# barcode01
# barcode02
# barcode03
# barcode04
# barcode05
# barcode06
# barcode07
# barcode08
# barcode09
# barcode10
# barcode11
# barcode12
# {'barcode01': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta',
#  'barcode02': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta',
#  'barcode03': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta',
#  'barcode04': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta',
#  'barcode05': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta',
#  'barcode06': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta',
#  'barcode07': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta',
#  'barcode08': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta',
#  'barcode09': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta',
#  'barcode10': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta',
#  'barcode11': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta',
#  'barcode12': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode12/length_restricted_reads.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    print(key)
    print(value)
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
# Out:
# barcode01
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.200.fasta!!
#
# barcode02
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.200.fasta!!
#
# barcode03
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.200.fasta!!
#
# barcode04
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.200.fasta!!
#
# barcode05
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.200.fasta!!
#
# barcode06
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.200.fasta
#
# barcode07
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.200.fasta
#
# barcode08
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.200.fasta
#
# barcode09
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.200.fasta
#
# barcode10
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.200.fasta
#
# barcode11
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.200.fasta
#
# barcode12
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode12/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode12/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode12.200.fasta

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    print(x)
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# ../../analysis/Mapping/gsref.subdb.fasta
# ../../analysis/Mapping/gsref.db.fasta
# {'../../analysis/Mapping/gsref.subdb.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb',
#  '../../analysis/Mapping/gsref.db.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode03.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode04.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode05.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode06.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode07.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode08.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode09.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode10.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode11.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode12.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode12.minimap2.paf

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode03.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode04.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode05.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode06.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode07.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode08.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode09.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode10.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode11.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode12.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode12.minimap2.paf

# %%
def mapping_results_v2(fn, species,expected_species, tax_rank):
    import numpy as np
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    if tax_rank == 's' or tax_rank == 'species':
        new_new_hit_series = hit_series
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    else:
        new_hit_series = pd.Series()
        new_new_hit_series = pd.Series()
        for index in hit_series.index.unique():
            new_hit_series.at[index] = data=np.sum(hit_series[index])
        for index in new_hit_series.index.unique():
            new_new_hit_series.at[index] = data=np.sum(new_hit_series[index])
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the sample type expected:", barcode,"\n")
    print(F"These are the results:")
    print(new_new_hit_series,'\n')
    new_new_hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/custom_results/%s_%s.json' % (tax_rank,expected_species[species]))

# %%
expected_rank_s = {}
expected_rank_g = {}
expected_rank_f = {}
expected_rank_o = {}
expected_rank_c = {}
expected_rank_p = {}

for column, row in wheat_ref_df.iterrows():
    expected_rank_s[row['Unnamed: 0']] = row['barcode']

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 's')
# Out:
# True
# ##########
#
# This was the sample type expected: barcode01
#
# These are the results:
# tname
# cryptococcus_zero                0.582090
# blastobotrys_proliferans         0.208955
# cortinarius_globuliformis        0.029851
# saccharomyces_cerevisiae         0.024876
# aspergillus_unidentified         0.014925
# cladophialophora_unidentified    0.014925
# entoleuca_unidentified           0.009950
# dothiorella_vidmadera            0.009950
# candida_orthopsilosis            0.009950
# candida_unidentified             0.009950
# debaryomyces_unidentified        0.009950
# aspergillus_flavus               0.009950
# quambalaria_cyanescens           0.009950
# yamadazyma_mexicana              0.009950
# yarrowia_lipolytica              0.004975
# meyerozyma_guilliermondii        0.004975
# oculimacula_yallundae-ccl029     0.004975
# penicillium_chrysogenum          0.004975
# pichia_membranifaciens           0.004975
# rhodotorula_mucilaginosa         0.004975
# candida_metapsilosis             0.004975
# tuber_brumale                    0.004975
# zymoseptoria_tritici             0.004975
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode02
#
# These are the results:
# tname
# zymoseptoria_tritici             0.515
# cryptococcus_zero                0.190
# debaryomyces_unidentified        0.050
# pyrenophora_tritici-repentis     0.045
# blastobotrys_proliferans         0.040
# entoleuca_unidentified           0.030
# cortinarius_globuliformis        0.030
# cladophialophora_unidentified    0.015
# aspergillus_unidentified         0.010
# candida_albicans                 0.010
# dothiorella_vidmadera            0.010
# wickerhamomyces_anomalus         0.010
# candida_unidentified             0.010
# candida_parapsilosis             0.005
# candida_orthopsilosis            0.005
# quambalaria_cyanescens           0.005
# meyerozyma_guilliermondii        0.005
# oculimacula_yallundae-ccl029     0.005
# oculimacula_yallundae-ccl031     0.005
# rhodotorula_mucilaginosa         0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode03
#
# These are the results:
# tname
# cryptococcus_zero                0.411765
# candida_albicans                 0.186275
# cortinarius_globuliformis        0.068627
# blastobotrys_proliferans         0.063725
# galactomyces_geotrichum          0.053922
# aspergillus_flavus               0.024510
# rhodotorula_mucilaginosa         0.019608
# pyrenophora_tritici-repentis     0.019608
# dothiorella_vidmadera            0.014706
# candida_orthopsilosis            0.014706
# candida_parapsilosis             0.014706
# diaporthe_ccl067                 0.014706
# quambalaria_cyanescens           0.014706
# saccharomyces_cerevisiae         0.009804
# zymoseptoria_tritici             0.009804
# entoleuca_unidentified           0.004902
# yamadazyma_scolyti               0.004902
# debaryomyces_unidentified        0.004902
# meyerozyma_guilliermondii        0.004902
# oculimacula_yallundae-ccl029     0.004902
# clavispora_lusitaniae            0.004902
# cladophialophora_unidentified    0.004902
# candida_unidentified             0.004902
# candida_metapsilosis             0.004902
# tuber_brumale                    0.004902
# wickerhamomyces_anomalus         0.004902
# asteroma_ccl060                  0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode04
#
# These are the results:
# tname
# cryptococcus_zero                0.415459
# cortinarius_globuliformis        0.149758
# blastobotrys_proliferans         0.096618
# kodamaea_ohmeri                  0.057971
# zymoseptoria_tritici             0.053140
# candida_metapsilosis             0.048309
# rhodotorula_mucilaginosa         0.024155
# diaporthe_unidentified           0.019324
# wickerhamomyces_anomalus         0.014493
# candida_albicans                 0.014493
# meyerozyma_guilliermondii        0.014493
# candida_unidentified             0.009662
# aspergillus_flavus               0.009662
# kluyveromyces_marxianus          0.009662
# oculimacula_yallundae-ccl029     0.009662
# entoleuca_unidentified           0.004831
# fusarium_oxysporum               0.004831
# debaryomyces_unidentified        0.004831
# kluyveromyces_unidentified       0.004831
# clavispora_lusitaniae            0.004831
# cladophialophora_unidentified    0.004831
# candida_orthopsilosis            0.004831
# pyrenophora_tritici-repentis     0.004831
# quambalaria_cyanescens           0.004831
# tuber_brumale                    0.004831
# dothiorella_vidmadera            0.004831
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode05
#
# These are the results:
# tname
# pyrenophora_tritici-repentis     0.374384
# cryptococcus_zero                0.206897
# cortinarius_globuliformis        0.078818
# meyerozyma_guilliermondii        0.073892
# candida_orthopsilosis            0.059113
# blastobotrys_proliferans         0.049261
# tuber_brumale                    0.019704
# oculimacula_yallundae-ccl031     0.019704
# candida_metapsilosis             0.014778
# candida_unidentified             0.014778
# aspergillus_flavus               0.009852
# rhodotorula_mucilaginosa         0.009852
# candida_albicans                 0.009852
# dothiorella_vidmadera            0.009852
# cladophialophora_unidentified    0.004926
# aspergillus_unidentified         0.004926
# zymoseptoria_tritici             0.004926
# yamadazyma_mexicana              0.004926
# oculimacula_yallundae-ccl029     0.004926
# penicillium_chrysogenum          0.004926
# pichia_kudriavzevii              0.004926
# quambalaria_cyanescens           0.004926
# wickerhamomyces_anomalus         0.004926
# kluyveromyces_unidentified       0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode06
#
# These are the results:
# tname
# cortinarius_globuliformis        0.333333
# cryptococcus_zero                0.308458
# candida_parapsilosis             0.089552
# wickerhamomyces_anomalus         0.079602
# blastobotrys_proliferans         0.059701
# candida_albicans                 0.019900
# zymoseptoria_tritici             0.009950
# dothiorella_vidmadera            0.009950
# rhodotorula_mucilaginosa         0.009950
# cladophialophora_unidentified    0.009950
# meyerozyma_guilliermondii        0.009950
# aspergillus_unidentified         0.004975
# clavispora_lusitaniae            0.004975
# kluyveromyces_unidentified       0.004975
# entoleuca_unidentified           0.004975
# yarrowia_lipolytica              0.004975
# oculimacula_yallundae-ccl029     0.004975
# oculimacula_yallundae-ccl031     0.004975
# penicillium_chrysogenum          0.004975
# quambalaria_cyanescens           0.004975
# saccharomyces_cerevisiae         0.004975
# yamadazyma_scolyti               0.004975
# aspergillus_niger                0.004975
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode07
#
# These are the results:
# tname
# cryptococcus_zero                0.415
# cortinarius_globuliformis        0.155
# blastobotrys_proliferans         0.110
# dothiorella_vidmadera            0.065
# yamadazyma_mexicana              0.040
# rhodotorula_mucilaginosa         0.035
# meyerozyma_guilliermondii        0.025
# candida_unidentified             0.020
# candida_orthopsilosis            0.015
# candida_parapsilosis             0.015
# candida_albicans                 0.010
# aspergillus_flavus               0.010
# kluyveromyces_unidentified       0.010
# quambalaria_cyanescens           0.010
# saccharomyces_cerevisiae         0.010
# entoleuca_unidentified           0.005
# yamadazyma_scolyti               0.005
# diaporthe_unidentified           0.005
# oculimacula_yallundae-ccl029     0.005
# cladophialophora_unidentified    0.005
# oculimacula_yallundae-ccl031     0.005
# pichia_kudriavzevii              0.005
# wickerhamomyces_anomalus         0.005
# aspergillus_unidentified         0.005
# aspergillus_niger                0.005
# zymoseptoria_tritici             0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode08
#
# These are the results:
# tname
# cryptococcus_zero                0.415
# cortinarius_globuliformis        0.125
# blastobotrys_proliferans         0.080
# quambalaria_cyanescens           0.080
# yamadazyma_scolyti               0.070
# clavispora_lusitaniae            0.050
# rhodotorula_mucilaginosa         0.030
# candida_unidentified             0.020
# entoleuca_unidentified           0.015
# puccinia_striiformis             0.015
# cladophialophora_unidentified    0.010
# aspergillus_flavus               0.010
# kluyveromyces_unidentified       0.010
# meyerozyma_guilliermondii        0.010
# wickerhamomyces_anomalus         0.010
# fusarium_oxysporum               0.005
# dothiorella_vidmadera            0.005
# debaryomyces_unidentified        0.005
# galactomyces_geotrichum          0.005
# oculimacula_yallundae-ccl031     0.005
# pyrenophora_tritici-repentis     0.005
# candida_orthopsilosis            0.005
# candida_metapsilosis             0.005
# candida_albicans                 0.005
# zymoseptoria_tritici             0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode09
#
# These are the results:
# tname
# cryptococcus_zero                0.445545
# candida_unidentified             0.168317
# blastobotrys_proliferans         0.094059
# cortinarius_globuliformis        0.069307
# kluyveromyces_unidentified       0.039604
# meyerozyma_guilliermondii        0.024752
# yarrowia_lipolytica              0.019802
# candida_albicans                 0.014851
# entoleuca_unidentified           0.014851
# dothiorella_vidmadera            0.014851
# wickerhamomyces_anomalus         0.009901
# penicillium_chrysogenum          0.009901
# aspergillus_niger                0.004950
# candida_metapsilosis             0.004950
# cladophialophora_unidentified    0.004950
# clavispora_lusitaniae            0.004950
# zymoseptoria_tritici             0.004950
# debaryomyces_unidentified        0.004950
# oculimacula_yallundae-ccl031     0.004950
# puccinia_striiformis             0.004950
# quambalaria_cyanescens           0.004950
# rhodotorula_mucilaginosa         0.004950
# saccharomyces_cerevisiae         0.004950
# tuber_brumale                    0.004950
# yamadazyma_mexicana              0.004950
# yamadazyma_scolyti               0.004950
# aspergillus_flavus               0.004950
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode10
#
# These are the results:
# tname
# cryptococcus_zero                0.447761
# blastobotrys_proliferans         0.124378
# cortinarius_globuliformis        0.089552
# kluyveromyces_marxianus          0.069652
# penicillium_chrysogenum          0.034826
# zymoseptoria_tritici             0.024876
# rhodotorula_mucilaginosa         0.024876
# quambalaria_cyanescens           0.014925
# meyerozyma_guilliermondii        0.014925
# candida_metapsilosis             0.014925
# candida_unidentified             0.014925
# dothiorella_vidmadera            0.014925
# saccharomyces_cerevisiae         0.014925
# entoleuca_unidentified           0.009950
# candida_albicans                 0.009950
# wickerhamomyces_anomalus         0.009950
# kluyveromyces_unidentified       0.004975
# yarrowia_lipolytica              0.004975
# oculimacula_yallundae-ccl029     0.004975
# puccinia_striiformis             0.004975
# tuber_brumale                    0.004975
# clavispora_lusitaniae            0.004975
# cladophialophora_unidentified    0.004975
# oculimacula_yallundae-ccl031     0.004975
# candida_parapsilosis             0.004975
# candida_orthopsilosis            0.004975
# pichia_kudriavzevii              0.004975
# asteroma_ccl068                  0.004975
# aspergillus_unidentified         0.004975
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: barcode11
#
# These are the results:
# tname
# cryptococcus_zero               0.403941
# cortinarius_globuliformis       0.118227
# rhodotorula_mucilaginosa        0.088670
# blastobotrys_proliferans        0.083744
# zymoseptoria_tritici            0.039409
# zygoascus_hellenicus            0.039409
# dothiorella_vidmadera           0.029557
# aspergillus_flavus              0.029557
# pichia_kudriavzevii             0.024631
# candida_unidentified            0.024631
# asteroma_ccl060                 0.024631
# meyerozyma_guilliermondii       0.019704
# quambalaria_cyanescens          0.014778
# candida_albicans                0.014778
# oculimacula_yallundae-ccl029    0.009852
# wickerhamomyces_anomalus        0.009852
# oculimacula_yallundae-ccl031    0.004926
# penicillium_chrysogenum         0.004926
# clavispora_lusitaniae           0.004926
# candida_parapsilosis            0.004926
# candida_metapsilosis            0.004926
# dtype: float64
# True
# ##########
#
# This was the sample type expected: barcode12
#
# These are the results:
# tname
# cryptococcus_zero            0.666667
# cortinarius_globuliformis    0.333333
# dtype: float64
