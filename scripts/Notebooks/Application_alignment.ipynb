# %% [markdown]
# ## Apply to wheat species for qiime and consensus respectively

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')
subsampling_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/subsample_reads')
mapping_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/qiime_results')

wheat_reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/wheat_reference_dataframe.csv')
wheat_max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/wheat_database_labelled.fasta')
wheat_taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/wheat_taxonomy_file_qiime.csv')

qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10

wheat_ref_df = pd.read_csv(wheat_reference_dataframe_fn)
wheat_ref_df
# Out:
#   Unnamed: 0                       species         genus              family  \
# 0  barcode01          puccinia_striiformis      puccinia        pucciniaceae
# 1  barcode02          zymoseptoria_tritici  zymoseptoria  mycosphaerellaceae
# 2  barcode05  pyrenophora_tritici-repentis   pyrenophora       pleosporaceae
#
#           order            class         phylum kingdom  # raw reads  \
# 0   pucciniales  pucciniomycetes  basidiomycota   fungi       115052
# 1   capnodiales  dothideomycetes     ascomycota   fungi       151005
# 2  pleosporales  dothideomycetes     ascomycota   fungi       134094
#
#    # reads after homology filtering  # reads after length filtering  \
# 0                             23477                           21590
# 1                             20416                           18100
# 2                             24785                           22433
#
#    # for use                                  path to raw reads  \
# 0    21590.0  analysis/Concatenated/wheat/barcode01/merged.f...
# 1    18100.0  analysis/Concatenated/wheat/barcode02/merged.f...
# 2    22433.0  analysis/Concatenated/wheat/barcode05/merged.f...
#
#                           path to homology filtering  \
# 0  analysis/Python_Processing/wheat/barcode01/com...
# 1  analysis/Python_Processing/wheat/barcode02/com...
# 2  analysis/Python_Processing/wheat/barcode05/com...
#
#                             path to length filtering  \
# 0  analysis/Length_Filtered/wheat/barcode01/lengt...
# 1  analysis/Length_Filtered/wheat/barcode02/lengt...
# 2  analysis/Length_Filtered/wheat/barcode05/lengt...
#
#                                         path for use
# 0  analysis/Length_Filtered/wheat/barcode01/lengt...
# 1  analysis/Length_Filtered/wheat/barcode02/lengt...
# 2  analysis/Length_Filtered/wheat/barcode05/lengt...

# %% [markdown]
# ##### Qiime Database

# %%
import json
from collections import OrderedDict

def assign_taxranks_results(mapping_df, tax_fn, ref_df_fn = False):
    """
    This function assigns the taxonomic ranks for each hit in the mapping results dataframe.
    It takes a mapping_df, taxonomy assignment file, and if required a reference dataframe filename.
    Returns the mapping dataframe with assignment. 
    """
    for tname in mapping_df.index:
        if ref_df_fn:
            tmp_taxfileid = getquery_taxfileid(ref_df_fn, tname)
        else:
            tmp_taxfileid = tname
        tmp_tax_dict = get_taxid_dict(tax_fn, tmp_taxfileid)
        for key, value in tmp_tax_dict.items():
            mapping_df.loc[tname, key] = value
    return mapping_df

def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarises the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = OrderedDict()
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        tmps_df = pd.DataFrame(data=None)
        if tax_rank == 's':
            for index, row in mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]].iterrows():
                if row['s'] == 'unidentified' and row['g'] != query_tax_dict['g']:
                    mapping_df.drop(index, axis=0, inplace=True)
                else:
                    continue
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        else:
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

def getquery_taxfileid(refdf_fn, species):
    """
    Takes the reference dataframe filename and the species name.
    Returns the taxfileid, which is the date/flowcellid (column 0 value) of the ref_df.
    """
    ref_df = pd.read_csv(refdf_fn)
    return ref_df[ref_df.species == species].iloc[:,0].values[0]

def get_taxid_dict(taxid_fn, taxfileid):
    """
    Takes a taxonomy assignment file filename in the Qiime format and a taxonomic identifier.
    Returns the a dictionary with the taxonomic assignment at each rank.
    """
    tax_dict = {}
    with open(taxid_fn, 'r') as fh:
        for line in fh:
            if line.startswith(taxfileid):
                taxrankids = line.rstrip().split('\t')[1].split(';')
                for taxrank in taxrankids:
                    tax_dict[taxrank.split('__')[0]] = taxrank.split('__')[1]
    return tax_dict

def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/%s.json' % species)

def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)

def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df
    
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)

test_species_list = []
for entry in wheat_ref_df.species.tolist():
#     if entry[-7:] != '-ccl031' and entry[-7:] != '-ccl029':
#         test_species_list.append(entry)
#     else:
#         test_species_list.append(entry[:-7])
#         print(entry[:-7])
    test_species_list.append(entry)
    
for test_species in test_species_list:
    
    print(test_species)
    
    #subsample tests species
    fn_subsampling = {}
    test_species = [test_species]
    for x in test_species:
#         print((wheat_ref_df['species'] == x))
        fn_subsampling[x] = (wheat_ref_df[(wheat_ref_df['species'] == x) & (wheat_ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
        fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

    sub_reads_fn = {}
    n_reads = 200
    for key, value in fn_subsampling.items():
        species = key
        in_fn = value
        out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
        subsamplereads(in_fn, out_fn, n_reads)
        sub_reads_fn[species] = out_fn
        
    ###Map the reads
    db_fn = qiime_db_fn
    sub_db_mapping_fn = {}
    for species, fasta_fn in sub_reads_fn.items():
        db_name = os.path.basename(db_fn).replace('.fasta', '')
        out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
        sub_db_mapping_fn[species] = out_fn
        minimapmapping(fasta_fn, db_fn, out_fn, threads)
        
    ###Test out the summary results statistic for a single mapping result
    species = test_species[0]
    mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
    mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
    taxfileid = getquery_taxfileid(wheat_reference_dataframe_fn, species)
    
    query_tax_dict = get_taxid_dict(wheat_taxonomy_file_fn, taxfileid)
    print(query_tax_dict)
    
    sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)
        
    print(json.dumps(sensitivity_dict, indent=1))
    print('\n')
    with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/qiime_results/%s.json' % species, 'w+') as fp:
        json.dump(sensitivity_dict, fp)
# Out:
# puccinia_striiformis
# {'k': 'Fungi', 'p': 'Basidiomycota', 'c': 'Pucciniomycetes', 'o': 'Pucciniales', 'f': 'Pucciniaceae', 'g': 'Puccinia', 's': 'Puccinia_striiformis'}
# {
#  "k": 1.0,
#  "p": 0.4479638009049774,
#  "c": 0.0,
#  "o": 0.0,
#  "f": 0.0,
#  "g": 0.0,
#  "s": 0.0
# }
#
#
# zymoseptoria_tritici
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Dothideomycetes', 'o': 'Capnodiales', 'f': 'Mycosphaerellaceae', 'g': 'Zymoseptoria', 's': 'Zymoseptoria_tritici'}
# {
#  "k": 1.0,
#  "p": 0.6832579185520362,
#  "c": 0.20361990950226244,
#  "o": 0.09049773755656108,
#  "f": 0.08597285067873303,
#  "g": 0.08597285067873303,
#  "s": 0.0
# }
#
#
# pyrenophora_tritici-repentis
# {'k': 'Fungi', 'p': 'Ascomycota', 'c': 'Dothideomycetes', 'o': 'Pleosporales', 'f': 'Pleosporaceae', 'g': 'Pyrenophora', 's': 'Pyrenophora_tritici-repentis'}
# {
#  "k": 1.0,
#  "p": 0.6635514018691588,
#  "c": 0.2570093457943925,
#  "o": 0.2570093457943925,
#  "f": 0.10747663551401869,
#  "g": 0.08411214953271028,
#  "s": 0.08411214953271028
# }

# %% [markdown]
# ##### Custom Database

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']
references = {}
for species in max_species:
    references[species] = species

# %%
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_wheat.csv')
species_file = {}
genus_file = {}
family_file = {}
order_file = {}
class_file = {}
phylum_file = {}

with open(taxonomy_file_fn, 'r') as fh:
        for line in fh:
            species_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]
            genus_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[5].split('__')[1].split('\n')[0]
            family_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[4].split('__')[1].split('\n')[0]
            order_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[3].split('__')[1].split('\n')[0]
            class_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[2].split('__')[1].split('\n')[0]
            phylum_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[1].split('__')[1].split('\n')[0]

# %%
species_file
# Out:
# {'puccinia_striiformis': 'Puccinia_striiformis',
#  'zymoseptoria_tritici': 'Zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis': 'Pyrenophora_tritici-repentis',
#  'fusarium_oxysporum': 'Fusarium_oxysporum',
#  'tuber_brumale': 'Tuber_brumale',
#  'cortinarius_globuliformis': 'Cortinarius_globuliformis',
#  'aspergillus_niger': 'Aspergillus_niger',
#  'clavispora_lusitaniae': 'Clavispora_lusitaniae',
#  'kluyveromyces_unidentified': 'Kluyveromyces_unidentified',
#  'penicillium_chrysogenum': 'Penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa': 'Rhodotorula_mucilaginosa',
#  'scedosporium_boydii': 'Scedosporium_boydii',
#  'blastobotrys_proliferans': 'Blastobotrys_proliferans',
#  'debaryomyces_unidentified': 'Debaryomyces_unidentified',
#  'galactomyces_geotrichum': 'Galactomyces_geotrichum',
#  'kodamaea_ohmeri': 'Kodamaea_ohmeri',
#  'meyerozyma_guilliermondii': 'Meyerozyma_guilliermondii',
#  'wickerhamomyces_anomalus': 'Wickerhamomyces_anomalus',
#  'yamadazyma_mexicana': 'Yamadazyma_mexicana',
#  'yamadazyma_scolyti': 'Yamadazyma_scolyti',
#  'yarrowia_lipolytica': 'Yarrowia_lipolytica',
#  'zygoascus_hellenicus': 'Zygoascus_hellenicus',
#  'aspergillus_flavus': 'Aspergillus_flavus',
#  'cryptococcus_zero': 'Cryptococcus_zero',
#  'aspergillus_unidentified': 'Aspergillus_unidentified',
#  'diaporthe_ccl067': 'Diaporthe_CCL067',
#  'diaporthe_unidentified': 'Diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031': 'Oculimacula_yallundae-CCL031',
#  'oculimacula_yallundae-ccl029': 'Oculimacula_yallundae-CCL029',
#  'dothiorella_vidmadera': 'Dothiorella_vidmadera',
#  'quambalaria_cyanescens': 'Quambalaria_cyanescens',
#  'entoleuca_unidentified': 'Entoleuca_unidentified',
#  'asteroma_ccl060': 'Asteroma_CCL060',
#  'asteroma_ccl068': 'Asteroma_CCL068',
#  'saccharomyces_cerevisiae': 'Saccharomyces_cerevisiae',
#  'cladophialophora_unidentified': 'Cladophialophora_unidentified',
#  'candida_albicans': 'Candida_albicans',
#  'candida_metapsilosis': 'Candida_metapsilosis',
#  'candida_orthopsilosis': 'Candida_orthopsilosis',
#  'candida_parapsilosis': 'Candida_parapsilosis',
#  'candida_unidentified': 'Candida_unidentified',
#  'kluyveromyces_marxianus': 'Kluyveromyces_marxianus',
#  'pichia_kudriavzevii': 'Pichia_kudriavzevii',
#  'pichia_membranifaciens': 'Pichia_membranifaciens'}

# %%
mock_community = ['barcode01','barcode02',
                 'barcode05']

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 2000

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping/wheat')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)
sub_db_fn = os.path.join('../../analysis/Mapping/gsref.subdb.fasta')
new_db_fn = os.path.join('../../analysis/Mapping/gsref.db.fasta')

# %%
wheat_ref_df.columns
# Out:
# Index(['Unnamed: 0', 'species', 'genus', 'family', 'order', 'class', 'phylum',
#        'kingdom', '# raw reads', '# reads after homology filtering',
#        '# reads after length filtering', '# for use', 'path to raw reads',
#        'path to homology filtering', 'path to length filtering',
#        'path for use'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    print(x)
    fn_subsampling[x] = wheat_ref_df[wheat_ref_df['Unnamed: 0'] == x]['path for use'].tolist()[0]
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# barcode01
# barcode02
# barcode05
# {'barcode01': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta',
#  'barcode02': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta',
#  'barcode05': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    print(key)
    print(value)
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
# Out:
# barcode01
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta!!
#
# barcode02
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta!!
#
# barcode05
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta
# :(check one reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta!!

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    print(x)
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# ../../analysis/Mapping/gsref.subdb.fasta
# ../../analysis/Mapping/gsref.db.fasta
# {'../../analysis/Mapping/gsref.subdb.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb',
#  '../../analysis/Mapping/gsref.db.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode05.minimap2.paf

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode05.minimap2.paf

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results_v2(fn, species,expected_species, tax_rank, tax_rank_file):
    import numpy as np
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    if tax_rank == 's' or tax_rank == 'species':
        new_new_hit_series = hit_series
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    else:
        new_hit_series = pd.Series()
        new_new_hit_series = pd.Series()
        for index in hit_series.index.unique():
            new_hit_series.at[index] = data=np.sum(hit_series[index])
        new_hit_series = new_hit_series.rename(tax_rank_file, axis='index')
        for index in new_hit_series.index.unique():
            new_new_hit_series.at[index] = data=np.sum(new_hit_series[index])
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the sample type expected: {tax_rank_file[expected_species[species]]}\n")
    print(F"These are the results:")
    print(new_new_hit_series,'\n')
    new_new_hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/custom_results/%s_%s.json' % (tax_rank,expected_species[species]))

# %%
expected_rank_s = {}
expected_rank_g = {}
expected_rank_f = {}
expected_rank_o = {}
expected_rank_c = {}
expected_rank_p = {}

for column, row in wheat_ref_df.iterrows():
    expected_rank_s[row['Unnamed: 0']] = row['species']
    expected_rank_g[row['Unnamed: 0']] = row['genus']
    expected_rank_f[row['Unnamed: 0']] = row['family']
    expected_rank_o[row['Unnamed: 0']] = row['order']
    expected_rank_c[row['Unnamed: 0']] = row['class']
    expected_rank_p[row['Unnamed: 0']] = row['phylum']

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 's', species_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Puccinia_striiformis
#
# These are the results:
# tname
# cryptococcus_zero                0.569652
# blastobotrys_proliferans         0.208458
# cortinarius_globuliformis        0.053234
# saccharomyces_cerevisiae         0.023881
# rhodotorula_mucilaginosa         0.015920
# meyerozyma_guilliermondii        0.011940
# dothiorella_vidmadera            0.010945
# candida_albicans                 0.010448
# candida_unidentified             0.010448
# entoleuca_unidentified           0.007960
# zymoseptoria_tritici             0.006965
# aspergillus_flavus               0.006965
# wickerhamomyces_anomalus         0.006468
# puccinia_striiformis             0.005970
# quambalaria_cyanescens           0.005970
# cladophialophora_unidentified    0.004478
# tuber_brumale                    0.003483
# candida_metapsilosis             0.003483
# pyrenophora_tritici-repentis     0.003483
# clavispora_lusitaniae            0.003483
# oculimacula_yallundae-ccl031     0.002488
# oculimacula_yallundae-ccl029     0.002488
# kluyveromyces_unidentified       0.002488
# debaryomyces_unidentified        0.002488
# candida_parapsilosis             0.001990
# yarrowia_lipolytica              0.001493
# yamadazyma_scolyti               0.001493
# yamadazyma_mexicana              0.001493
# pichia_kudriavzevii              0.001493
# penicillium_chrysogenum          0.001493
# diaporthe_unidentified           0.000995
# candida_orthopsilosis            0.000995
# aspergillus_unidentified         0.000995
# aspergillus_niger                0.000995
# kluyveromyces_marxianus          0.000995
# fusarium_oxysporum               0.000498
# zygoascus_hellenicus             0.000498
# kodamaea_ohmeri                  0.000498
# asteroma_ccl068                  0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria_tritici
#
# These are the results:
# tname
# zymoseptoria_tritici             0.520916
# cryptococcus_zero                0.165339
# debaryomyces_unidentified        0.066235
# cortinarius_globuliformis        0.046813
# pyrenophora_tritici-repentis     0.045319
# blastobotrys_proliferans         0.039343
# aspergillus_unidentified         0.018426
# cladophialophora_unidentified    0.015936
# dothiorella_vidmadera            0.010956
# candida_albicans                 0.007470
# aspergillus_flavus               0.006474
# quambalaria_cyanescens           0.006474
# candida_unidentified             0.005976
# rhodotorula_mucilaginosa         0.005976
# candida_metapsilosis             0.003984
# candida_orthopsilosis            0.003984
# candida_parapsilosis             0.003486
# saccharomyces_cerevisiae         0.002988
# penicillium_chrysogenum          0.002490
# oculimacula_yallundae-ccl031     0.002490
# wickerhamomyces_anomalus         0.002490
# meyerozyma_guilliermondii        0.002490
# kluyveromyces_unidentified       0.001992
# entoleuca_unidentified           0.001992
# zygoascus_hellenicus             0.001992
# kodamaea_ohmeri                  0.001494
# clavispora_lusitaniae            0.000996
# fusarium_oxysporum               0.000996
# tuber_brumale                    0.000996
# oculimacula_yallundae-ccl029     0.000996
# puccinia_striiformis             0.000498
# diaporthe_ccl067                 0.000498
# pichia_membranifaciens           0.000498
# yamadazyma_mexicana              0.000498
# pichia_kudriavzevii              0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pyrenophora_tritici-repentis
#
# These are the results:
# tname
# pyrenophora_tritici-repentis     0.374133
# cryptococcus_zero                0.243806
# meyerozyma_guilliermondii        0.063429
# blastobotrys_proliferans         0.062438
# cortinarius_globuliformis        0.060951
# candida_orthopsilosis            0.047076
# oculimacula_yallundae-ccl031     0.019822
# candida_albicans                 0.015857
# candida_unidentified             0.012884
# dothiorella_vidmadera            0.009911
# zymoseptoria_tritici             0.008920
# rhodotorula_mucilaginosa         0.007433
# wickerhamomyces_anomalus         0.006938
# entoleuca_unidentified           0.006442
# aspergillus_flavus               0.006442
# quambalaria_cyanescens           0.006442
# tuber_brumale                    0.005451
# candida_metapsilosis             0.004955
# oculimacula_yallundae-ccl029     0.003964
# cladophialophora_unidentified    0.003964
# aspergillus_unidentified         0.002973
# candida_parapsilosis             0.002973
# aspergillus_niger                0.001982
# yamadazyma_mexicana              0.001982
# clavispora_lusitaniae            0.001982
# debaryomyces_unidentified        0.001487
# diaporthe_unidentified           0.001487
# saccharomyces_cerevisiae         0.001487
# pichia_kudriavzevii              0.001487
# yamadazyma_scolyti               0.001487
# kluyveromyces_unidentified       0.001487
# galactomyces_geotrichum          0.001487
# penicillium_chrysogenum          0.000991
# pichia_membranifaciens           0.000991
# kluyveromyces_marxianus          0.000991
# yarrowia_lipolytica              0.000991
# fusarium_oxysporum               0.000496
# zygoascus_hellenicus             0.000496
# asteroma_ccl068                  0.000496
# asteroma_ccl060                  0.000496
# kodamaea_ohmeri                  0.000496
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'g', genus_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Puccinia
#
# These are the results:
# Cryptococcus        0.569652
# Blastobotrys        0.208458
# Cortinarius         0.053234
# Candida             0.027363
# Saccharomyces       0.023881
# Rhodotorula         0.015920
# Meyerozyma          0.011940
# Dothiorella         0.010945
# Aspergillus         0.008955
# Entoleuca           0.007960
# Zymoseptoria        0.006965
# Wickerhamomyces     0.006468
# Puccinia            0.005970
# Quambalaria         0.005970
# Oculimacula         0.004975
# Cladophialophora    0.004478
# Kluyveromyces       0.003483
# Pyrenophora         0.003483
# Tuber               0.003483
# Clavispora          0.003483
# Yamadazyma          0.002985
# Debaryomyces        0.002488
# Pichia              0.001493
# Yarrowia            0.001493
# Penicillium         0.001493
# Diaporthe           0.000995
# Fusarium            0.000498
# Zygoascus           0.000498
# Asteroma            0.000498
# Kodamaea            0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria
#
# These are the results:
# Zymoseptoria        0.520916
# Cryptococcus        0.165339
# Debaryomyces        0.066235
# Cortinarius         0.046813
# Pyrenophora         0.045319
# Blastobotrys        0.039343
# Aspergillus         0.024900
# Candida             0.024900
# Cladophialophora    0.015936
# Dothiorella         0.010956
# Quambalaria         0.006474
# Rhodotorula         0.005976
# Oculimacula         0.003486
# Saccharomyces       0.002988
# Penicillium         0.002490
# Meyerozyma          0.002490
# Wickerhamomyces     0.002490
# Entoleuca           0.001992
# Kluyveromyces       0.001992
# Zygoascus           0.001992
# Kodamaea            0.001494
# Fusarium            0.000996
# Tuber               0.000996
# Clavispora          0.000996
# Pichia              0.000996
# Diaporthe           0.000498
# Puccinia            0.000498
# Yamadazyma          0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pyrenophora
#
# These are the results:
# Pyrenophora         0.374133
# Cryptococcus        0.243806
# Candida             0.083746
# Meyerozyma          0.063429
# Blastobotrys        0.062438
# Cortinarius         0.060951
# Oculimacula         0.023786
# Aspergillus         0.011397
# Dothiorella         0.009911
# Zymoseptoria        0.008920
# Rhodotorula         0.007433
# Wickerhamomyces     0.006938
# Entoleuca           0.006442
# Quambalaria         0.006442
# Tuber               0.005451
# Cladophialophora    0.003964
# Yamadazyma          0.003469
# Pichia              0.002478
# Kluyveromyces       0.002478
# Clavispora          0.001982
# Saccharomyces       0.001487
# Debaryomyces        0.001487
# Galactomyces        0.001487
# Diaporthe           0.001487
# Penicillium         0.000991
# Yarrowia            0.000991
# Asteroma            0.000991
# Fusarium            0.000496
# Zygoascus           0.000496
# Kodamaea            0.000496
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'f', family_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Pucciniaceae
#
# These are the results:
# Tremellaceae           0.569652
# Trichomonascaceae      0.208955
# Saccharomycetaceae     0.054726
# Cortinariaceae         0.053234
# Debaryomycetaceae      0.017413
# Sporidiobolaceae       0.015920
# Botryosphaeriaceae     0.010945
# Aspergillaceae         0.010448
# Xylariaceae            0.007960
# Mycosphaerellaceae     0.006965
# Phaffomycetaceae       0.006468
# Pucciniaceae           0.005970
# Quambalariaceae        0.005970
# Dermateaceae           0.004975
# Herpotrichiellaceae    0.004478
# Metschnikowiaceae      0.003980
# Pleosporaceae          0.003483
# Tuberaceae             0.003483
# Dipodascaceae          0.001493
# Pichiaceae             0.001493
# Diaporthaceae          0.000995
# Nectriaceae            0.000498
# Gnomoniaceae           0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Mycosphaerellaceae
#
# These are the results:
# Mycosphaerellaceae     0.520916
# Tremellaceae           0.165339
# Debaryomycetaceae      0.069223
# Cortinariaceae         0.046813
# Pleosporaceae          0.045319
# Trichomonascaceae      0.041335
# Saccharomycetaceae     0.029880
# Aspergillaceae         0.027390
# Herpotrichiellaceae    0.015936
# Botryosphaeriaceae     0.010956
# Quambalariaceae        0.006474
# Sporidiobolaceae       0.005976
# Dermateaceae           0.003486
# Phaffomycetaceae       0.002490
# Metschnikowiaceae      0.002490
# Xylariaceae            0.001992
# Nectriaceae            0.000996
# Pichiaceae             0.000996
# Tuberaceae             0.000996
# Diaporthaceae          0.000498
# Pucciniaceae           0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pleosporaceae
#
# These are the results:
# Pleosporaceae          0.374133
# Tremellaceae           0.243806
# Saccharomycetaceae     0.087711
# Debaryomycetaceae      0.068385
# Trichomonascaceae      0.062934
# Cortinariaceae         0.060951
# Dermateaceae           0.023786
# Aspergillaceae         0.012389
# Botryosphaeriaceae     0.009911
# Mycosphaerellaceae     0.008920
# Sporidiobolaceae       0.007433
# Phaffomycetaceae       0.006938
# Xylariaceae            0.006442
# Quambalariaceae        0.006442
# Tuberaceae             0.005451
# Herpotrichiellaceae    0.003964
# Dipodascaceae          0.002478
# Pichiaceae             0.002478
# Metschnikowiaceae      0.002478
# Diaporthaceae          0.001487
# Gnomoniaceae           0.000991
# Nectriaceae            0.000496
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'o', order_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Pucciniales
#
# These are the results:
# Tremellales          0.569652
# Saccharomycetales    0.294527
# Agaricales           0.053234
# Sporidiobolales      0.015920
# Botryosphaeriales    0.010945
# Eurotiales           0.010448
# Xylariales           0.007960
# Capnodiales          0.006965
# Microstromatales     0.005970
# Pucciniales          0.005970
# Helotiales           0.004975
# Chaetothyriales      0.004478
# Pezizales            0.003483
# Pleosporales         0.003483
# Diaporthales         0.001493
# Hypocreales          0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Capnodiales
#
# These are the results:
# Capnodiales          0.520916
# Tremellales          0.165339
# Saccharomycetales    0.146414
# Agaricales           0.046813
# Pleosporales         0.045319
# Eurotiales           0.027390
# Chaetothyriales      0.015936
# Botryosphaeriales    0.010956
# Microstromatales     0.006474
# Sporidiobolales      0.005976
# Helotiales           0.003486
# Xylariales           0.001992
# Pezizales            0.000996
# Hypocreales          0.000996
# Pucciniales          0.000498
# Diaporthales         0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pleosporales
#
# These are the results:
# Pleosporales         0.374133
# Tremellales          0.243806
# Saccharomycetales    0.233399
# Agaricales           0.060951
# Helotiales           0.023786
# Eurotiales           0.012389
# Botryosphaeriales    0.009911
# Capnodiales          0.008920
# Sporidiobolales      0.007433
# Microstromatales     0.006442
# Xylariales           0.006442
# Pezizales            0.005451
# Chaetothyriales      0.003964
# Diaporthales         0.002478
# Hypocreales          0.000496
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'c', class_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Pucciniomycetes
#
# These are the results:
# Tremellomycetes       0.569652
# Saccharomycetes       0.294527
# Agaricomycetes        0.053234
# Dothideomycetes       0.021393
# Microbotryomycetes    0.015920
# Eurotiomycetes        0.014925
# Sordariomycetes       0.009950
# Exobasidiomycetes     0.005970
# Pucciniomycetes       0.005970
# Leotiomycetes         0.004975
# Pezizomycetes         0.003483
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Dothideomycetes
#
# These are the results:
# Dothideomycetes       0.577191
# Tremellomycetes       0.165339
# Saccharomycetes       0.146414
# Agaricomycetes        0.046813
# Eurotiomycetes        0.043327
# Exobasidiomycetes     0.006474
# Microbotryomycetes    0.005976
# Leotiomycetes         0.003486
# Sordariomycetes       0.003486
# Pezizomycetes         0.000996
# Pucciniomycetes       0.000498
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Dothideomycetes
#
# These are the results:
# Dothideomycetes       0.392963
# Tremellomycetes       0.243806
# Saccharomycetes       0.233399
# Agaricomycetes        0.060951
# Leotiomycetes         0.023786
# Eurotiomycetes        0.016353
# Sordariomycetes       0.009415
# Microbotryomycetes    0.007433
# Exobasidiomycetes     0.006442
# Pezizomycetes         0.005451
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'p', phylum_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Basidiomycota
#
# These are the results:
# Basidiomycota    0.650746
# Ascomycota       0.349254
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota       0.7749
# Basidiomycota    0.2251
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota       0.681368
# Basidiomycota    0.318632
# dtype: float64

# %% [markdown]
# ## Apply to mock_database for qiime and consensus respectively

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')
subsampling_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads')
mapping_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/qiime_results')

mock_reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/mock_reference_dataframe.csv')
mock_max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/mock_database_labelled.fasta')
mock_taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/mock_taxonomy_file_qiime.csv')

qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10

mock_ref_df = pd.read_csv(mock_reference_dataframe_fn)
mock_ref_df
# Out:
#                      Unnamed: 0                       species          genus  \
# 0   20171212_FAH18688/barcode03              diaporthe_ccl067      diaporthe
# 1   20171212_FAH18688/barcode04        diaporthe_unidentified      diaporthe
# 2   20171103_FAH15473/barcode01          puccinia_striiformis       puccinia
# 3   20171103_FAH15473/barcode02          zymoseptoria_tritici   zymoseptoria
# 4   20171103_FAH15473/barcode03  pyrenophora_tritici-repentis    pyrenophora
# 5   20171103_FAH15473/barcode07             aspergillus_niger    aspergillus
# 6   20171103_FAH15473/barcode11      rhodotorula_mucilaginosa    rhodotorula
# 7   20171103_FAH15473/barcode12           scedosporium_boydii   scedosporium
# 8   20171207_FAH18654/barcode12            aspergillus_flavus    aspergillus
# 9   20180108_FAH18647/barcode01      saccharomyces_cerevisiae  saccharomyces
# 10  20180108_FAH18647/barcode03              candida_albicans        candida
# 11  20180108_FAH18647/barcode05         candida_orthopsilosis        candida
# 12  20180108_FAH18647/barcode04          candida_metapsilosis        candida
#
#                 family              order               class         phylum  \
# 0        diaporthaceae       diaporthales     sordariomycetes     ascomycota
# 1        diaporthaceae       diaporthales     sordariomycetes     ascomycota
# 2         pucciniaceae        pucciniales     pucciniomycetes  basidiomycota
# 3   mycosphaerellaceae        capnodiales     dothideomycetes     ascomycota
# 4        pleosporaceae       pleosporales     dothideomycetes     ascomycota
# 5       aspergillaceae         eurotiales      eurotiomycetes     ascomycota
# 6     sporidiobolaceae    sporidiobolales  microbotryomycetes  basidiomycota
# 7        microascaceae       microascales     sordariomycetes     ascomycota
# 8       aspergillaceae         eurotiales      eurotiomycetes     ascomycota
# 9   saccharomycetaceae  saccharomycetales     saccharomycetes     ascomycota
# 10  saccharomycetaceae  saccharomycetales     saccharomycetes     ascomycota
# 11  saccharomycetaceae  saccharomycetales     saccharomycetes     ascomycota
# 12  saccharomycetaceae  saccharomycetales     saccharomycetes     ascomycota
#
#    kingdom  # raw reads  # reads after homology filtering  \
# 0    fungi       172601                             32847
# 1    fungi       198500                             29833
# 2    fungi       272465                            122080
# 3    fungi       413127                            143363
# 4    fungi       260896                             97584
# 5    fungi       171615                             65065
# 6    fungi       318405                            127801
# 7    fungi       331947                            102481
# 8    fungi       125014                             54061
# 9    fungi        96837                             33025
# 10   fungi        91031                             26114
# 11   fungi       104214                             32490
# 12   fungi       127633                             40257
#
#     # reads after length filtering  # for use  \
# 0                            30504    30504.0
# 1                            27941    27941.0
# 2                           113337   113337.0
# 3                           133089   133089.0
# 4                            90015    90015.0
# 5                            59406    59406.0
# 6                           117801   117801.0
# 7                            93723    93723.0
# 8                            51340    51340.0
# 9                            30260    30260.0
# 10                           25597    25597.0
# 11                           29765    29765.0
# 12                           37426    37426.0
#
#                                     path to raw reads  \
# 0   analysis/Concatenated/20171212_FAH18688/barcod...
# 1   analysis/Concatenated/20171212_FAH18688/barcod...
# 2   analysis/Concatenated/20171103_FAH15473/barcod...
# 3   analysis/Concatenated/20171103_FAH15473/barcod...
# 4   analysis/Concatenated/20171103_FAH15473/barcod...
# 5   analysis/Concatenated/20171103_FAH15473/barcod...
# 6   analysis/Concatenated/20171103_FAH15473/barcod...
# 7   analysis/Concatenated/20171103_FAH15473/barcod...
# 8   analysis/Concatenated/20171207_FAH18654/barcod...
# 9   analysis/Concatenated/20180108_FAH18647/barcod...
# 10  analysis/Concatenated/20180108_FAH18647/barcod...
# 11  analysis/Concatenated/20180108_FAH18647/barcod...
# 12  analysis/Concatenated/20180108_FAH18647/barcod...
#
#                            path to homology filtering  \
# 0   analysis/Python_Processing/20171212_FAH18688/b...
# 1   analysis/Python_Processing/20171212_FAH18688/b...
# 2   analysis/Python_Processing/20171103_FAH15473/b...
# 3   analysis/Python_Processing/20171103_FAH15473/b...
# 4   analysis/Python_Processing/20171103_FAH15473/b...
# 5   analysis/Python_Processing/20171103_FAH15473/b...
# 6   analysis/Python_Processing/20171103_FAH15473/b...
# 7   analysis/Python_Processing/20171103_FAH15473/b...
# 8   analysis/Python_Processing/20171207_FAH18654/b...
# 9   analysis/Python_Processing/20180108_FAH18647/b...
# 10  analysis/Python_Processing/20180108_FAH18647/b...
# 11  analysis/Python_Processing/20180108_FAH18647/b...
# 12  analysis/Python_Processing/20180108_FAH18647/b...
#
#                              path to length filtering  \
# 0   analysis/Length_Filtered/20171212_FAH18688/bar...
# 1   analysis/Length_Filtered/20171212_FAH18688/bar...
# 2   analysis/Length_Filtered/20171103_FAH15473/bar...
# 3   analysis/Length_Filtered/20171103_FAH15473/bar...
# 4   analysis/Length_Filtered/20171103_FAH15473/bar...
# 5   analysis/Length_Filtered/20171103_FAH15473/bar...
# 6   analysis/Length_Filtered/20171103_FAH15473/bar...
# 7   analysis/Length_Filtered/20171103_FAH15473/bar...
# 8   analysis/Length_Filtered/20171207_FAH18654/bar...
# 9   analysis/Length_Filtered/20180108_FAH18647/bar...
# 10  analysis/Length_Filtered/20180108_FAH18647/bar...
# 11  analysis/Length_Filtered/20180108_FAH18647/bar...
# 12  analysis/Length_Filtered/20180108_FAH18647/bar...
#
#                                          path for use
# 0   analysis/Length_Filtered/20171212_FAH18688/bar...
# 1   analysis/Length_Filtered/20171212_FAH18688/bar...
# 2   analysis/Length_Filtered/20171103_FAH15473/bar...
# 3   analysis/Length_Filtered/20171103_FAH15473/bar...
# 4   analysis/Length_Filtered/20171103_FAH15473/bar...
# 5   analysis/Length_Filtered/20171103_FAH15473/bar...
# 6   analysis/Length_Filtered/20171103_FAH15473/bar...
# 7   analysis/Length_Filtered/20171103_FAH15473/bar...
# 8   analysis/Length_Filtered/20171207_FAH18654/bar...
# 9   analysis/Length_Filtered/20180108_FAH18647/bar...
# 10  analysis/Length_Filtered/20180108_FAH18647/bar...
# 11  analysis/Length_Filtered/20180108_FAH18647/bar...
# 12  analysis/Length_Filtered/20180108_FAH18647/bar...

# %% [markdown]
# ##### Qiime Database

# %%
import json
from collections import OrderedDict

def assign_taxranks_results(mapping_df, tax_fn, ref_df_fn = False):
    """
    This function assigns the taxonomic ranks for each hit in the mapping results dataframe.
    It takes a mapping_df, taxonomy assignment file, and if required a reference dataframe filename.
    Returns the mapping dataframe with assignment. 
    """
    for tname in mapping_df.index:
        if ref_df_fn:
            tmp_taxfileid = getquery_taxfileid(ref_df_fn, tname)
        else:
            tmp_taxfileid = tname
        tmp_tax_dict = get_taxid_dict(tax_fn, tmp_taxfileid)
        for key, value in tmp_tax_dict.items():
            mapping_df.loc[tname, key] = value
    return mapping_df

def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarises the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = OrderedDict()
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        tmps_df = pd.DataFrame(data=None)
        if tax_rank == 's':
            for index, row in mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]].iterrows():
                if row['s'] == 'unidentified' and row['g'] != query_tax_dict['g']:
                    mapping_df.drop(index, axis=0, inplace=True)
                else:
                    continue
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        else:
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

def getquery_taxfileid(refdf_fn, species):
    """
    Takes the reference dataframe filename and the species name.
    Returns the taxfileid, which is the date/flowcellid (column 0 value) of the ref_df.
    """
    ref_df = pd.read_csv(refdf_fn)
    return ref_df[ref_df.species == species].iloc[:,0].values[0]

def get_taxid_dict(taxid_fn, taxfileid):
    """
    Takes a taxonomy assignment file filename in the Qiime format and a taxonomic identifier.
    Returns the a dictionary with the taxonomic assignment at each rank.
    """
    tax_dict = {}
    with open(taxid_fn, 'r') as fh:
        for line in fh:
            if line.startswith(taxfileid):
                taxrankids = line.rstrip().split('\t')[1].split(';')
                for taxrank in taxrankids:
                    tax_dict[taxrank.split('__')[0]] = taxrank.split('__')[1]
    return tax_dict

def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/%s.json' % species)

def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)

def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df
    
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)

test_species_list = []
for entry in mock_ref_df.species.tolist():
#     if entry[-7:] != '-ccl031' and entry[-7:] != '-ccl029':
#         test_species_list.append(entry)
#     else:
#         test_species_list.append(entry[:-7])
#         print(entry[:-7])
    test_species_list.append(entry)
    
for test_species in test_species_list:
    
    print(test_species)
    
    #subsample tests species
    fn_subsampling = {}
    test_species = [test_species]
    for x in test_species:
#         print((mock_ref_df['species'] == x))
        fn_subsampling[x] = (mock_ref_df[(mock_ref_df['species'] == x) & (mock_ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
        fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

    sub_reads_fn = {}
    n_reads = 200
    for key, value in fn_subsampling.items():
        species = key
        in_fn = value
        out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
        subsamplereads(in_fn, out_fn, n_reads)
        sub_reads_fn[species] = out_fn
        
    ###Map the reads
    db_fn = qiime_db_fn
    sub_db_mapping_fn = {}
    for species, fasta_fn in sub_reads_fn.items():
        db_name = os.path.basename(db_fn).replace('.fasta', '')
        out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
        sub_db_mapping_fn[species] = out_fn
        minimapmapping(fasta_fn, db_fn, out_fn, threads)
        
    ###Test out the summary results statistic for a single mapping result
    species = test_species[0]
    mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
    mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
    taxfileid = getquery_taxfileid(mock_reference_dataframe_fn, species)
    query_tax_dict = get_taxid_dict(mock_taxonomy_file_fn, taxfileid)
    
    sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)
        
    print(json.dumps(sensitivity_dict, indent=1))
    print('\n')
    with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/qiime_results/%s.json' % species, 'w+') as fp:
        json.dump(sensitivity_dict, fp)
# Out:
# diaporthe_ccl067
# {
#  "k": 1.0,
#  "p": 0.9724770642201835,
#  "c": 0.7844036697247706,
#  "o": 0.4954128440366973,
#  "f": 0.0,
#  "g": 0.0,
#  "s": 0.0
# }
#
#
# diaporthe_unidentified
# {
#  "k": 1.0,
#  "p": 0.9912663755458515,
#  "c": 0.7030567685589519,
#  "o": 0.27510917030567683,
#  "f": 0.25327510917030566,
#  "g": 0.25327510917030566,
#  "s": 0.0
# }
#
#
# puccinia_striiformis
# {
#  "k": 1.0,
#  "p": 0.9748743718592965,
#  "c": 0.8894472361809045,
#  "o": 0.8894472361809045,
#  "f": 0.8894472361809045,
#  "g": 0.8793969849246231,
#  "s": 0.8492462311557789
# }
#
#
# zymoseptoria_tritici
# {
#  "k": 1.0,
#  "p": 0.8709677419354839,
#  "c": 0.3778801843317972,
#  "o": 0.2350230414746544,
#  "f": 0.2350230414746544,
#  "g": 0.22119815668202766,
#  "s": 0.0
# }
#
#
# pyrenophora_tritici-repentis
# {
#  "k": 1.0,
#  "p": 0.8293838862559242,
#  "c": 0.5829383886255924,
#  "o": 0.5687203791469194,
#  "f": 0.3933649289099526,
#  "g": 0.33649289099526064,
#  "s": 0.3127962085308057
# }
#
#
# aspergillus_niger
# {
#  "k": 1.0,
#  "p": 0.9489795918367347,
#  "c": 0.5782312925170068,
#  "o": 0.5782312925170068,
#  "f": 0.5782312925170068,
#  "g": 0.4489795918367347,
#  "s": 0.14965986394557823
# }
#
#
# rhodotorula_mucilaginosa
# {
#  "k": 1.0,
#  "p": 0.8944954128440367,
#  "c": 0.7201834862385321,
#  "o": 0.7201834862385321,
#  "f": 0.7201834862385321,
#  "g": 0.7155963302752294,
#  "s": 0.555045871559633
# }
#
#
# scedosporium_boydii
# {
#  "k": 1.0,
#  "p": 0.9696969696969697,
#  "c": 0.8744588744588745,
#  "o": 0.7359307359307359,
#  "f": 0.48484848484848486,
#  "g": 0.2987012987012987,
#  "s": 0.2857142857142857
# }
#
#
# aspergillus_flavus
# {
#  "k": 1.0,
#  "p": 0.9735294117647059,
#  "c": 0.8294117647058824,
#  "o": 0.8294117647058824,
#  "f": 0.8294117647058824,
#  "g": 0.6647058823529411,
#  "s": 0.6235294117647059
# }
#
#
# saccharomyces_cerevisiae
# {
#  "k": 1.0,
#  "p": 0.9414634146341463,
#  "c": 0.7804878048780488,
#  "o": 0.7804878048780488,
#  "f": 0.697560975609756,
#  "g": 0.6585365853658537,
#  "s": 0.5073170731707317
# }
#
#
# candida_albicans
# {
#  "k": 1.0,
#  "p": 0.9398148148148148,
#  "c": 0.6111111111111112,
#  "o": 0.6111111111111112,
#  "f": 0.18518518518518517,
#  "g": 0.4166666666666667,
#  "s": 0.3472222222222222
# }
#
#
# candida_orthopsilosis
# {
#  "k": 1.0,
#  "p": 0.9476190476190476,
#  "c": 0.7047619047619048,
#  "o": 0.7047619047619048,
#  "f": 0.01904761904761905,
#  "g": 0.680952380952381,
#  "s": 0.3380952380952381
# }
#
#
# candida_metapsilosis
# {
#  "k": 1.0,
#  "p": 0.9333333333333333,
#  "c": 0.7095238095238096,
#  "o": 0.7095238095238096,
#  "f": 0.004761904761904762,
#  "g": 0.7,
#  "s": 0.0
# }

# %% [markdown]
# ##### Custom Database

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']
references = {}
for species in max_species:
    references[species] = species

# %%
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_mock.csv')
species_file = {}
genus_file = {}
family_file = {}
order_file = {}
class_file = {}
phylum_file = {}

with open(taxonomy_file_fn, 'r') as fh:
        for line in fh:
            species_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]
            genus_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[5].split('__')[1].split('\n')[0]
            family_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[4].split('__')[1].split('\n')[0]
            order_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[3].split('__')[1].split('\n')[0]
            class_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[2].split('__')[1].split('\n')[0]
            phylum_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[1].split('__')[1].split('\n')[0]

# %%
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_mock.csv')
species_file = {}
genus_file = {}
family_file = {}
order_file = {}

with open(taxonomy_file_fn, 'r') as fh:
        for line in fh:
            species_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]
            genus_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[5].split('__')[1].split('\n')[0]
            family_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[4].split('__')[1].split('\n')[0]
            order_file[references[line.split('\t')[1].split(';')[6].split('__')[1].split('\n')[0]].lower()] = line.split('\t')[1].split(';')[3].split('__')[1].split('\n')[0]

# %%
mock_community = ['aspergillus_flavus',
                  'aspergillus_niger',
                  'candida_albicans',
                  'candida_metapsilosis',
                  'candida_orthopsilosis',
                  'diaporthe_unidentified',
                  'diaporthe_ccl067',
                  'puccinia_striiformis',
                  'pyrenophora_tritici-repentis',
                  'rhodotorula_mucilaginosa',
                  'saccharomyces_cerevisiae',
                  'scedosporium_boydii',
                  'zymoseptoria_tritici']

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 200

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping/mock')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)
MC_READ_DIR = os.path.join(OUT_DIR, 'subsample_reads')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)
sub_db_fn = os.path.join('../../analysis/Mapping/gsref.subdb.fasta')
new_db_fn = os.path.join('../../analysis/Mapping/gsref.db.fasta')

# %%
mock_ref_df.columns
# Out:
# Index(['Unnamed: 0', 'species', 'genus', 'family', 'order', 'class', 'phylum',
#        'kingdom', '# raw reads', '# reads after homology filtering',
#        '# reads after length filtering', '# for use', 'path to raw reads',
#        'path to homology filtering', 'path to length filtering',
#        'path for use'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    print(x)
    fn_subsampling[x] = mock_ref_df[mock_ref_df['species'] == x]['path for use'].tolist()[0]
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# aspergillus_flavus
# aspergillus_niger
# candida_albicans
# candida_metapsilosis
# candida_orthopsilosis
# diaporthe_unidentified
# diaporthe_ccl067
# puccinia_striiformis
# pyrenophora_tritici-repentis
# rhodotorula_mucilaginosa
# saccharomyces_cerevisiae
# scedosporium_boydii
# zymoseptoria_tritici
# {'aspergillus_flavus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta',
#  'aspergillus_niger': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta',
#  'candida_albicans': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta',
#  'candida_metapsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta',
#  'candida_orthopsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta',
#  'diaporthe_unidentified': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode04/length_restricted_for_use.fasta',
#  'diaporthe_ccl067': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode03/length_restricted_for_use.fasta',
#  'puccinia_striiformis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode01/length_restricted_for_use.fasta',
#  'pyrenophora_tritici-repentis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode03/length_restricted_for_use.fasta',
#  'rhodotorula_mucilaginosa': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode11/length_restricted_for_use.fasta',
#  'saccharomyces_cerevisiae': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode01/length_restricted_for_use.fasta',
#  'scedosporium_boydii': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode12/length_restricted_for_use.fasta',
#  'zymoseptoria_tritici': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode02/length_restricted_for_use.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    print(key)
    print(value)
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
# Out:
# aspergillus_flavus
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_flavus.200.fasta!!
#
# aspergillus_niger
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_niger.200.fasta!!
#
# candida_albicans
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_albicans.200.fasta!!
#
# candida_metapsilosis
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_metapsilosis.200.fasta!!
#
# candida_orthopsilosis
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_orthopsilosis.200.fasta!!
#
# diaporthe_unidentified
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode04/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode04/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_unidentified.200.fasta!!
#
# diaporthe_ccl067
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode03/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171212_FAH18688/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_ccl067.200.fasta!!
#
# puccinia_striiformis
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode01/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/puccinia_striiformis.200.fasta!!
#
# pyrenophora_tritici-repentis
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode03/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode03/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/pyrenophora_tritici-repentis.200.fasta!!
#
# rhodotorula_mucilaginosa
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode11/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode11/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/rhodotorula_mucilaginosa.200.fasta!!
#
# saccharomyces_cerevisiae
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode01/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode01/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/saccharomyces_cerevisiae.200.fasta!!
#
# scedosporium_boydii
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode12/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode12/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/scedosporium_boydii.200.fasta!!
#
# zymoseptoria_tritici
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode02/length_restricted_for_use.fasta
# :(check one reformat.sh samplereadstarget=200 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode02/length_restricted_for_use.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/zymoseptoria_tritici.200.fasta!!

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    print(x)
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# ../../analysis/Mapping/gsref.subdb.fasta
# ../../analysis/Mapping/gsref.db.fasta
# {'../../analysis/Mapping/gsref.subdb.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb',
#  '../../analysis/Mapping/gsref.db.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_flavus.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.aspergillus_flavus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_niger.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.aspergillus_niger.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_albicans.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.candida_albicans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_metapsilosis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.candida_metapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_orthopsilosis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.candida_orthopsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_unidentified.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.diaporthe_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_ccl067.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.diaporthe_ccl067.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/puccinia_striiformis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.puccinia_striiformis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/pyrenophora_tritici-repentis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.pyrenophora_tritici-repentis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/rhodotorula_mucilaginosa.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.rhodotorula_mucilaginosa.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/saccharomyces_cerevisiae.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.saccharomyces_cerevisiae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/scedosporium_boydii.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.scedosporium_boydii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/zymoseptoria_tritici.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_subdb/gsref.subdb.zymoseptoria_tritici.minimap2.paf

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_flavus.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.aspergillus_flavus.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/aspergillus_niger.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.aspergillus_niger.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_albicans.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.candida_albicans.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_metapsilosis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.candida_metapsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/candida_orthopsilosis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.candida_orthopsilosis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_unidentified.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.diaporthe_unidentified.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/diaporthe_ccl067.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.diaporthe_ccl067.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/puccinia_striiformis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.puccinia_striiformis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/pyrenophora_tritici-repentis.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.pyrenophora_tritici-repentis.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/rhodotorula_mucilaginosa.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.rhodotorula_mucilaginosa.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/saccharomyces_cerevisiae.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.saccharomyces_cerevisiae.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/scedosporium_boydii.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.scedosporium_boydii.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/subsample_reads/zymoseptoria_tritici.200.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/gsref_db/gsref.db.zymoseptoria_tritici.minimap2.paf

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results_v2(fn, species,expected_species, tax_rank, tax_rank_file):
    import numpy as np
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    if tax_rank == 's' or tax_rank == 'species':
        new_new_hit_series = hit_series
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    else:
        new_hit_series = pd.Series()
        new_new_hit_series = pd.Series()
        for index in hit_series.index.unique():
            new_hit_series.at[index] = data=np.sum(hit_series[index])
        new_hit_series = new_hit_series.rename(tax_rank_file, axis='index')
        for index in new_hit_series.index.unique():
            new_new_hit_series.at[index] = data=np.sum(new_hit_series[index])
        new_new_hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the sample type expected: {tax_rank_file[expected_species[species]]}\n")
    print(F"These are the results:")
    print(new_new_hit_series,'\n')
    new_new_hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/mock/custom_results/%s_%s.json' % (tax_rank,expected_species[species]))

# %%
expected_rank_s = {}
expected_rank_g = {}
expected_rank_f = {}
expected_rank_o = {}
expected_rank_c = {}
expected_rank_p = {}

for column, row in mock_ref_df.iterrows():
    expected_rank_s[row['species']] = row['species']
    expected_rank_g[row['species']] = row['genus']
    expected_rank_f[row['species']] = row['family']
    expected_rank_o[row['species']] = row['order']
    expected_rank_c[row['species']] = row['class']
    expected_rank_p[row['species']] = row['phylum']

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    print(barcode)
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 's', species_file)
# Out:
# aspergillus_flavus
# True
# ##########
#
# This was the sample type expected: Aspergillus_flavus
#
# These are the results:
# tname
# aspergillus_flavus    1.0
# dtype: float64
#
# aspergillus_niger
# True
# ##########
#
# This was the sample type expected: Aspergillus_niger
#
# These are the results:
# tname
# aspergillus_niger            0.763547
# aspergillus_unidentified     0.211823
# yamadazyma_mexicana          0.004926
# dothiorella_vidmadera        0.004926
# debaryomyces_unidentified    0.004926
# candida_parapsilosis         0.004926
# aspergillus_flavus           0.004926
# dtype: float64
#
# candida_albicans
# True
# ##########
#
# This was the sample type expected: Candida_albicans
#
# These are the results:
# tname
# candida_unidentified            0.450980
# candida_albicans                0.377451
# candida_orthopsilosis           0.088235
# candida_metapsilosis            0.034314
# candida_parapsilosis            0.019608
# tuber_brumale                   0.004902
# pyrenophora_tritici-repentis    0.004902
# meyerozyma_guilliermondii       0.004902
# kluyveromyces_marxianus         0.004902
# galactomyces_geotrichum         0.004902
# diaporthe_ccl067                0.004902
# dtype: float64
#
# candida_metapsilosis
# True
# ##########
#
# This was the sample type expected: Candida_metapsilosis
#
# These are the results:
# tname
# candida_orthopsilosis     0.517073
# candida_metapsilosis      0.400000
# candida_parapsilosis      0.048780
# kodamaea_ohmeri           0.019512
# diaporthe_unidentified    0.009756
# fusarium_oxysporum        0.004878
# dtype: float64
#
# candida_orthopsilosis
# True
# ##########
#
# This was the sample type expected: Candida_orthopsilosis
#
# These are the results:
# tname
# candida_orthopsilosis           0.628713
# candida_metapsilosis            0.301980
# candida_parapsilosis            0.034653
# meyerozyma_guilliermondii       0.019802
# oculimacula_yallundae-ccl031    0.009901
# entoleuca_unidentified          0.004950
# dtype: float64
#
# diaporthe_unidentified
# True
# ##########
#
# This was the sample type expected: Diaporthe_unidentified
#
# These are the results:
# tname
# diaporthe_unidentified        0.602941
# asteroma_ccl060               0.367647
# kodamaea_ohmeri               0.009804
# kluyveromyces_unidentified    0.004902
# kluyveromyces_marxianus       0.004902
# fusarium_oxysporum            0.004902
# candida_metapsilosis          0.004902
# dtype: float64
#
# diaporthe_ccl067
# True
# ##########
#
# This was the sample type expected: Diaporthe_CCL067
#
# These are the results:
# tname
# diaporthe_ccl067            0.510
# asteroma_ccl068             0.460
# asteroma_ccl060             0.015
# fusarium_oxysporum          0.005
# entoleuca_unidentified      0.005
# aspergillus_unidentified    0.005
# dtype: float64
#
# puccinia_striiformis
# True
# ##########
#
# This was the sample type expected: Puccinia_striiformis
#
# These are the results:
# tname
# puccinia_striiformis            0.995
# pyrenophora_tritici-repentis    0.005
# dtype: float64
#
# pyrenophora_tritici-repentis
# True
# ##########
#
# This was the sample type expected: Pyrenophora_tritici-repentis
#
# These are the results:
# tname
# pyrenophora_tritici-repentis    0.950
# zymoseptoria_tritici            0.045
# scedosporium_boydii             0.005
# dtype: float64
#
# rhodotorula_mucilaginosa
# True
# ##########
#
# This was the sample type expected: Rhodotorula_mucilaginosa
#
# These are the results:
# tname
# rhodotorula_mucilaginosa    0.980296
# zygoascus_hellenicus        0.004926
# pichia_kudriavzevii         0.004926
# penicillium_chrysogenum     0.004926
# asteroma_ccl060             0.004926
# dtype: float64
#
# saccharomyces_cerevisiae
# True
# ##########
#
# This was the sample type expected: Saccharomyces_cerevisiae
#
# These are the results:
# tname
# saccharomyces_cerevisiae    1.0
# dtype: float64
#
# scedosporium_boydii
# True
# ##########
#
# This was the sample type expected: Scedosporium_boydii
#
# These are the results:
# tname
# scedosporium_boydii              0.995
# cladophialophora_unidentified    0.005
# dtype: float64
#
# zymoseptoria_tritici
# True
# ##########
#
# This was the sample type expected: Zymoseptoria_tritici
#
# These are the results:
# tname
# zymoseptoria_tritici        0.990050
# saccharomyces_cerevisiae    0.004975
# kluyveromyces_marxianus     0.004975
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'g', genus_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Aspergillus
#
# These are the results:
# Aspergillus    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Aspergillus
#
# These are the results:
# Aspergillus     0.980296
# Yamadazyma      0.004926
# Dothiorella     0.004926
# Debaryomyces    0.004926
# Candida         0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Candida
#
# These are the results:
# Candida          0.970588
# Tuber            0.004902
# Pyrenophora      0.004902
# Meyerozyma       0.004902
# Kluyveromyces    0.004902
# Galactomyces     0.004902
# Diaporthe        0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Candida
#
# These are the results:
# Candida      0.965854
# Kodamaea     0.019512
# Diaporthe    0.009756
# Fusarium     0.004878
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Candida
#
# These are the results:
# Candida        0.965347
# Meyerozyma     0.019802
# Oculimacula    0.009901
# Entoleuca      0.004950
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthe
#
# These are the results:
# Diaporthe        0.602941
# Asteroma         0.367647
# Kodamaea         0.009804
# Kluyveromyces    0.009804
# Fusarium         0.004902
# Candida          0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthe
#
# These are the results:
# Diaporthe      0.510
# Asteroma       0.475
# Fusarium       0.005
# Entoleuca      0.005
# Aspergillus    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia
#
# These are the results:
# Puccinia       0.995
# Pyrenophora    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pyrenophora
#
# These are the results:
# Pyrenophora     0.950
# Zymoseptoria    0.045
# Scedosporium    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Rhodotorula
#
# These are the results:
# Rhodotorula    0.980296
# Zygoascus      0.004926
# Pichia         0.004926
# Penicillium    0.004926
# Asteroma       0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomyces
#
# These are the results:
# Saccharomyces    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Scedosporium
#
# These are the results:
# Scedosporium        0.995
# Cladophialophora    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria
#
# These are the results:
# Zymoseptoria     0.990050
# Saccharomyces    0.004975
# Kluyveromyces    0.004975
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'f', family_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Aspergillaceae
#
# These are the results:
# Aspergillaceae    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Aspergillaceae
#
# These are the results:
# Aspergillaceae        0.980296
# Debaryomycetaceae     0.009852
# Botryosphaeriaceae    0.004926
# Saccharomycetaceae    0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetaceae
#
# These are the results:
# Saccharomycetaceae    0.975490
# Tuberaceae            0.004902
# Pleosporaceae         0.004902
# Debaryomycetaceae     0.004902
# Dipodascaceae         0.004902
# Diaporthaceae         0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetaceae
#
# These are the results:
# Saccharomycetaceae    0.965854
# Metschnikowiaceae     0.019512
# Diaporthaceae         0.009756
# Nectriaceae           0.004878
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetaceae
#
# These are the results:
# Saccharomycetaceae    0.965347
# Debaryomycetaceae     0.019802
# Dermateaceae          0.009901
# Xylariaceae           0.004950
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthaceae
#
# These are the results:
# Diaporthaceae         0.602941
# Gnomoniaceae          0.367647
# Saccharomycetaceae    0.014706
# Metschnikowiaceae     0.009804
# Nectriaceae           0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthaceae
#
# These are the results:
# Diaporthaceae     0.510
# Gnomoniaceae      0.475
# Nectriaceae       0.005
# Xylariaceae       0.005
# Aspergillaceae    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pucciniaceae
#
# These are the results:
# Pucciniaceae     0.995
# Pleosporaceae    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pleosporaceae
#
# These are the results:
# Pleosporaceae         0.950
# Mycosphaerellaceae    0.045
# Microascaceae         0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Sporidiobolaceae
#
# These are the results:
# Sporidiobolaceae     0.980296
# Trichomonascaceae    0.004926
# Pichiaceae           0.004926
# Aspergillaceae       0.004926
# Gnomoniaceae         0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetaceae
#
# These are the results:
# Saccharomycetaceae    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Microascaceae
#
# These are the results:
# Microascaceae          0.995
# Herpotrichiellaceae    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Mycosphaerellaceae
#
# These are the results:
# Mycosphaerellaceae    0.99005
# Saccharomycetaceae    0.00995
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'o', order_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Eurotiales
#
# These are the results:
# Eurotiales    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Eurotiales
#
# These are the results:
# Eurotiales           0.980296
# Saccharomycetales    0.014778
# Botryosphaeriales    0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetales
#
# These are the results:
# Saccharomycetales    0.985294
# Pezizales            0.004902
# Pleosporales         0.004902
# Diaporthales         0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetales
#
# These are the results:
# Saccharomycetales    0.985366
# Diaporthales         0.009756
# Hypocreales          0.004878
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetales
#
# These are the results:
# Saccharomycetales    0.985149
# Helotiales           0.009901
# Xylariales           0.004950
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthales
#
# These are the results:
# Diaporthales         0.970588
# Saccharomycetales    0.024510
# Hypocreales          0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Diaporthales
#
# These are the results:
# Diaporthales    0.985
# Hypocreales     0.005
# Xylariales      0.005
# Eurotiales      0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pucciniales
#
# These are the results:
# Pucciniales     0.995
# Pleosporales    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pleosporales
#
# These are the results:
# Pleosporales    0.950
# Capnodiales     0.045
# Microascales    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Sporidiobolales
#
# These are the results:
# Sporidiobolales      0.980296
# Saccharomycetales    0.009852
# Eurotiales           0.004926
# Diaporthales         0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetales
#
# These are the results:
# Saccharomycetales    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Microascales
#
# These are the results:
# Microascales       0.995
# Chaetothyriales    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Capnodiales
#
# These are the results:
# Capnodiales          0.99005
# Saccharomycetales    0.00995
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'c', class_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Eurotiomycetes
#
# These are the results:
# Eurotiomycetes    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Eurotiomycetes
#
# These are the results:
# Eurotiomycetes     0.980296
# Saccharomycetes    0.014778
# Dothideomycetes    0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetes
#
# These are the results:
# Saccharomycetes    0.985294
# Pezizomycetes      0.004902
# Dothideomycetes    0.004902
# Sordariomycetes    0.004902
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetes
#
# These are the results:
# Saccharomycetes    0.985366
# Sordariomycetes    0.014634
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetes
#
# These are the results:
# Saccharomycetes    0.985149
# Leotiomycetes      0.009901
# Sordariomycetes    0.004950
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Sordariomycetes
#
# These are the results:
# Sordariomycetes    0.97549
# Saccharomycetes    0.02451
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Sordariomycetes
#
# These are the results:
# Sordariomycetes    0.995
# Eurotiomycetes     0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pucciniomycetes
#
# These are the results:
# Pucciniomycetes    0.995
# Dothideomycetes    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Dothideomycetes
#
# These are the results:
# Dothideomycetes    0.995
# Sordariomycetes    0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Microbotryomycetes
#
# These are the results:
# Microbotryomycetes    0.980296
# Saccharomycetes       0.009852
# Eurotiomycetes        0.004926
# Sordariomycetes       0.004926
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Saccharomycetes
#
# These are the results:
# Saccharomycetes    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Sordariomycetes
#
# These are the results:
# Sordariomycetes    0.995
# Eurotiomycetes     0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Dothideomycetes
#
# These are the results:
# Dothideomycetes    0.99005
# Saccharomycetes    0.00995
# dtype: float64

# %%
###this is running the reads against the full database
for barcode, hit_fn in new_db_mapping_fn.items():
    mapping_results_v2(hit_fn, barcode, expected_rank_s, 'p', phylum_file)
# Out:
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Basidiomycota
#
# These are the results:
# Basidiomycota    0.995
# Ascomycota       0.005
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Basidiomycota
#
# These are the results:
# Basidiomycota    0.980296
# Ascomycota       0.019704
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Ascomycota
#
# These are the results:
# Ascomycota    1.0
# dtype: float64
