# %% [markdown]
# ### Notebook to analyzse the efficiency of minimap mapping against a mock community

# %% [markdown]
# Starting points from Tavish
# reference_dataframe at '/media/MassStorage/tmp/TE/honours/analysis/Stats/reference_dataframe.csv'
# custom_database at '/media/MassStorage/tmp/TE/honours/database/custom_database_labelled.fasta'
# taxonomy_file at '/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file.csv'

# %% [markdown]
# #### workflow
#
# * Two databases
# * subsample 15000 reads per each mock community species. Save those out.
# * map reads against both databases with minimap safe out data in paf format.
# * get best hit per species (see what this means while looking at the data).
# * add the full taxonomy to each best match using the taxonomy file.
# * summarize data at different taxonomic ranks for each species.
# * pull this all together somehow (summary across all the samples? focus on species of interest e.g. deleted from analyis?)

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

# %% [markdown]
# #### Initial data

# %%
reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/reference_dataframe.csv')
max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/custom_database_labelled.fasta')
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file.csv')

# %%
INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping_mock_gsref')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis_tritici',
 'Zymoseptoria_tritici',
 'Pyrenophora_tritici-repentis',
 'Fusarium_oxysporum',
 'Tuber_brumale',
 'Cortinarius_globuliformis',
 'Aspergillus_niger',
 'Clavispora_lusitaniae',
 'Cryptococcus_neoformans',
 'Penicillium_chrysogenum',
 'Rhodotorula_mucilaginosa',
 'Scedosporium_boydii',
 'Blastobotrys_proliferans',
 'Candida_zeylanoides',
 'Galactomyces_geotrichum',
 'Kodamaea_ohmeri',
 'Meyerozyma_guillermondii',
 'Wickerhamomyces_anomalus',
 'Yamadazyma_mexicana',
 'Yamadazyma_scolyti',
 'Yarrowia_lipolytica',
 'Zygoascus_hellenicus',
 'Aspergillus_flavus',
 'Cryptococcus_zero',
 'Aspergillus_sp.',
 'CCL067',
 'Diaporthe_sp.',
 'Tapesia_yallundae_CCL031',
 'Tapesia_yallundae_CCL029',
 'Dothiorella_vidmadera',
 'Quambalaria_cyanescens',
 'Entoleuca_sp.',
 'CCL060',
 'CCL068',
 'Saccharomyces_cerevisiae',
 'Cladophialophora_sp.',
 'Candida_albicans',
 'Candida_metapsilosis',
 'Candida_orthopsilosis',
 'Candida_parapsilosis',
 'Geotrichum_candidum',
 'Kluyveromyces_lactis',
 'Kluyveromyces_marxianus',
 'Pichia_kudriavzevii',
 'Pichia_membranifaciens']

# %%
###Removed from second test databes
species_delete = ['Candida_orthopsilosis',
                 'Candida_metapsilosis',
                 'Aspergillus_niger']

# %%
###species to be searched against both databases
mock_community = ['Penicillium_chrysogenum',
 'Aspergillus_flavus',
 'Aspergillus_niger',
 'Pichia_kudriavzevii',
 'Pichia_membranifaciens',
 'Candida_albicans',
 'Candida_parapsilosis',
 'Candida_orthopsilosis',
 'Candida_metapsilosis']

# %%
fixed_old_names = ['Kluyveromyces_lactis',
                   'Candida_zeylanoides',
                   'Cladophialophora_sp.',
                   'Diaporthe_sp.',
                   'CCL060',
                   'CCL068',
                   'CCL067',
                   'Aspergillus_sp.',
                   'Entoleuca_sp.',
                   'Tapesia_yallundae_CCL029',
                   'Tapesia_yallundae_CCL031',
                   'Cryptococcus_neoformans']

# %%
fixed_new_names = ['candida_unidentified',
                   'debaryomyces_unidentified',
                   'cladophialophora_unidentified',
                   'diaporthe_unidentified',
                   'asteroma_ccl060',
                   'asteroma_ccl068',
                   'diaporthe_ccl067',
                   'aspergillus_unidentified',
                   'entoleuca_unidentified',
                   'oculimacula_yallundae-ccl029',
                   'oculimacula_yallundae-ccl031',
                   'kluyveromyces_unidentified']

# %%
old_to_new_names = dict(zip(fixed_old_names, fixed_new_names))

# %%
old_to_new_names
# Out:
# {'Kluyveromyces_lactis': 'candida_unidentified',
#  'Candida_zeylanoides': 'debaryomyces_unidentified',
#  'Cladophialophora_sp.': 'cladophialophora_unidentified',
#  'Diaporthe_sp.': 'diaporthe_unidentified',
#  'CCL060': 'asteroma_ccl060',
#  'CCL068': 'asteroma_ccl068',
#  'CCL067': 'diaporthe_ccl067',
#  'Aspergillus_sp.': 'aspergillus_unidentified',
#  'Entoleuca_sp.': 'entoleuca_unidentified',
#  'Tapesia_yallundae_CCL029': 'oculimacula_yallundae-ccl029',
#  'Tapesia_yallundae_CCL031': 'oculimacula_yallundae-ccl031',
#  'Cryptococcus_neoformans': 'kluyveromyces_unidentified'}

# %% [markdown]
# ### Fix databases and names

# %%
ref_df = pd.read_csv(reference_dataframe_fn)
ref_df['name_species'] = ref_df['genus'] +"_"+ ref_df['species']

# %%
ref_df.name_species.tolist()
# Out:
# ['puccinia_striiformis-tritici',
#  'zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis',
#  'fusarium_oxysporum',
#  'tuber_brumale',
#  'cortinarius_globuliformis',
#  'aspergillus_niger',
#  'clavispora_lusitaniae',
#  'kluyveromyces_unidentified',
#  'penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa',
#  'scedosporium_boydii',
#  'blastobotrys_proliferans',
#  'debaryomyces_unidentified',
#  'galactomyces_geotrichum',
#  'kodamaea_ohmeri',
#  'meyerozyma_guillermondii',
#  'wickerhamomyces_anomalus',
#  'yamadazyma_mexicana',
#  'yamadazyma_scolyti',
#  'yarrowia_lipolytica',
#  'zygoascus_hellenicus',
#  'aspergillus_flavus',
#  'cryptococcus_zero',
#  'aspergillus_unidentified',
#  'diaporthe_ccl067',
#  'diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031',
#  'oculimacula_yallundae-ccl029',
#  'dothiorella_vidmadera',
#  'quambalaria_cyanescens',
#  'entoleuca_unidentified',
#  'asteroma_ccl060',
#  'asteroma_ccl068',
#  'saccharomyces_cerevisiae',
#  'cladophialophora_unidentified',
#  'candida_albicans',
#  'candida_metapsilosis',
#  'candida_orthopsilosis',
#  'candida_parapsilosis',
#  'candida_unidentified',
#  'kluyveromyces_marxianus',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens']

# %%
new_db_fn = os.path.join(OUT_DIR, 'gsref.db.fasta')

# %%
new_db_list = []
old_db_list = []
for seq in SeqIO.parse(max_custom_database_fn, 'fasta'):
    old_db_list.append(seq.id)
    if seq.id in old_to_new_names.keys():
        #print(seq.id)
        seq.id = seq.name = seq.description = old_to_new_names[seq.id]
        new_db_list.append(seq)
    elif seq.id.lower() in ref_df.name_species.tolist():
        #print(seq.id)
        seq.id = seq.name = seq.description = seq.id.lower()
        new_db_list.append(seq)
    else:
        print(seq.id)
# Out:
# Cryptococcus_gattii
# Geotrichum_candidum

# %%
if len(new_db_list) == len(old_db_list) -2:
    SeqIO.write(new_db_list, new_db_fn, 'fasta')
else:
    print("please check!")

# %%
sub_db_fn = os.path.join(OUT_DIR, 'gsref.subdb.fasta')
sub_db_list = []
for seq in new_db_list:
    if seq.id not in [x.lower() for x in species_delete]:
        sub_db_list.append(seq)

# %%
if len(sub_db_list) + len(species_delete) == len(new_db_list):
    SeqIO.write(sub_db_list, sub_db_fn, 'fasta' )
else:
    print("please check!")

# %%
[x.id for x in sub_db_list]
# Out:
# ['puccinia_striiformis-tritici',
#  'zymoseptoria_tritici',
#  'pyrenophora_tritici-repentis',
#  'fusarium_oxysporum',
#  'tuber_brumale',
#  'cortinarius_globuliformis',
#  'clavispora_lusitaniae',
#  'kluyveromyces_unidentified',
#  'penicillium_chrysogenum',
#  'rhodotorula_mucilaginosa',
#  'scedosporium_boydii',
#  'blastobotrys_proliferans',
#  'debaryomyces_unidentified',
#  'galactomyces_geotrichum',
#  'kodamaea_ohmeri',
#  'meyerozyma_guillermondii',
#  'wickerhamomyces_anomalus',
#  'yamadazyma_mexicana',
#  'yamadazyma_scolyti',
#  'yarrowia_lipolytica',
#  'zygoascus_hellenicus',
#  'aspergillus_flavus',
#  'cryptococcus_zero',
#  'aspergillus_unidentified',
#  'diaporthe_ccl067',
#  'diaporthe_unidentified',
#  'oculimacula_yallundae-ccl031',
#  'oculimacula_yallundae-ccl029',
#  'dothiorella_vidmadera',
#  'quambalaria_cyanescens',
#  'entoleuca_unidentified',
#  'asteroma_ccl060',
#  'asteroma_ccl068',
#  'saccharomyces_cerevisiae',
#  'cladophialophora_unidentified',
#  'candida_albicans',
#  'candida_parapsilosis',
#  'candida_unidentified',
#  'kluyveromyces_marxianus',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens']

# %%
mock_community = [x.lower() for x in mock_community]

# %%
mock_community
# Out:
# ['penicillium_chrysogenum',
#  'aspergillus_flavus',
#  'aspergillus_niger',
#  'pichia_kudriavzevii',
#  'pichia_membranifaciens',
#  'candida_albicans',
#  'candida_parapsilosis',
#  'candida_orthopsilosis',
#  'candida_metapsilosis']

# %% [markdown]
# ### Subsample reads

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 1:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 15000

# %%
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)

# %%
ref_df.columns
# Out:
# Index(['Unnamed: 0', 'species', 'genus', 'family', 'order', 'class', 'phylum',
#        'kingdom', '# raw reads', '# reads after homology filtering',
#        '# reads after length filtering', '# for use', 'path to raw reads',
#        'path to homology filtering', 'path to length filtering',
#        'path for use', 'name_species'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# {'penicillium_chrysogenum': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode10/length_restricted_for_use.fasta',
#  'aspergillus_flavus': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta',
#  'aspergillus_niger': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta',
#  'pichia_kudriavzevii': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode11/length_restricted_for_use.fasta',
#  'pichia_membranifaciens': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode12/length_restricted_for_use.fasta',
#  'candida_albicans': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta',
#  'candida_parapsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode06/length_restricted_for_use.fasta',
#  'candida_orthopsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta',
#  'candida_metapsilosis': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
# Out:
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode10/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171207_FAH18654/barcode12/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20171103_FAH15473/barcode07/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode11/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode12/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode03/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode06/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode05/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta
#
# :)Completed reformat.sh samplereadstarget=15000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/20180108_FAH18647/barcode04/length_restricted_for_use.fasta out=/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn):
    command = F"minimap2 -x map-ont -t 6 {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    print(out)

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# {'/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb',
#  '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn)
# Out:
# (0, '[M::mm_idx_gen::0.009*1.19] collected minimizers\n[M::mm_idx_gen::0.012*2.11] sorted minimizers\n[M::main::0.012*2.10] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.013*2.01] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.014*1.94] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::0.982*5.32] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.penicillium_chrysogenum.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta\n[M::main] Real time: 0.983 sec; CPU: 5.226 sec; Peak RSS: 0.094 GB')
# (0, '[M::mm_idx_gen::0.007*1.17] collected minimizers\n[M::mm_idx_gen::0.009*2.08] sorted minimizers\n[M::main::0.009*2.08] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.010*1.98] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.010*1.91] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::1.126*5.46] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_flavus.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta\n[M::main] Real time: 1.127 sec; CPU: 6.152 sec; Peak RSS: 0.095 GB')
# (0, '[M::mm_idx_gen::0.012*1.15] collected minimizers\n[M::mm_idx_gen::0.014*1.91] sorted minimizers\n[M::main::0.014*1.91] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.015*1.86] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.016*1.82] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::0.949*5.29] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_niger.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta\n[M::main] Real time: 0.951 sec; CPU: 5.022 sec; Peak RSS: 0.094 GB')
# (0, '[M::mm_idx_gen::0.009*1.14] collected minimizers\n[M::mm_idx_gen::0.011*1.84] sorted minimizers\n[M::main::0.011*1.84] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.012*1.77] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.013*1.73] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::0.947*5.35] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_kudriavzevii.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta\n[M::main] Real time: 0.948 sec; CPU: 5.069 sec; Peak RSS: 0.092 GB')
# (0, '[M::mm_idx_gen::0.006*1.19] collected minimizers\n[M::mm_idx_gen::0.008*2.13] sorted minimizers\n[M::main::0.008*2.13] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.009*2.01] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.010*1.93] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::0.930*5.32] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_membranifaciens.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta\n[M::main] Real time: 0.932 sec; CPU: 4.951 sec; Peak RSS: 0.090 GB')
# (0, '[M::mm_idx_gen::0.007*1.14] collected minimizers\n[M::mm_idx_gen::0.010*2.14] sorted minimizers\n[M::main::0.010*2.13] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.010*2.04] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.011*1.98] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::1.170*5.45] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_albicans.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta\n[M::main] Real time: 1.171 sec; CPU: 6.380 sec; Peak RSS: 0.092 GB')
# (0, '[M::mm_idx_gen::0.009*1.16] collected minimizers\n[M::mm_idx_gen::0.011*2.02] sorted minimizers\n[M::main::0.011*2.02] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.012*1.96] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.012*1.92] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::1.228*5.47] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_parapsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta\n[M::main] Real time: 1.230 sec; CPU: 6.725 sec; Peak RSS: 0.093 GB')
# (0, '[M::mm_idx_gen::0.009*1.14] collected minimizers\n[M::mm_idx_gen::0.011*1.79] sorted minimizers\n[M::main::0.011*1.79] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.012*1.73] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.013*1.68] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::1.209*5.44] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_orthopsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta\n[M::main] Real time: 1.210 sec; CPU: 6.576 sec; Peak RSS: 0.092 GB')
# (0, '[M::mm_idx_gen::0.011*1.15] collected minimizers\n[M::mm_idx_gen::0.013*1.92] sorted minimizers\n[M::main::0.013*1.92] loaded/built the index for 41 target sequence(s)\n[M::mm_mapopt_update::0.014*1.85] mid_occ = 42\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 41\n[M::mm_idx_stat::0.015*1.80] distinct minimizers: 9557 (72.65% are singletons); average occurrences: 2.332; average spacing: 5.427\n[M::worker_pipeline::1.214*5.46] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_metapsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.subdb.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta\n[M::main] Real time: 1.215 sec; CPU: 6.623 sec; Peak RSS: 0.093 GB')

# %%
sub_db_mapping_fn
# Out:
# {'penicillium_chrysogenum': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.penicillium_chrysogenum.minimap2.paf',
#  'aspergillus_flavus': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_flavus.minimap2.paf',
#  'aspergillus_niger': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.aspergillus_niger.minimap2.paf',
#  'pichia_kudriavzevii': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_kudriavzevii.minimap2.paf',
#  'pichia_membranifaciens': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.pichia_membranifaciens.minimap2.paf',
#  'candida_albicans': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_albicans.minimap2.paf',
#  'candida_parapsilosis': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_parapsilosis.minimap2.paf',
#  'candida_orthopsilosis': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_orthopsilosis.minimap2.paf',
#  'candida_metapsilosis': '/media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_subdb/gsref.subdb.candida_metapsilosis.minimap2.paf'}

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn)
# Out:
# (0, '[M::mm_idx_gen::0.005*1.20] collected minimizers\n[M::mm_idx_gen::0.007*2.30] sorted minimizers\n[M::main::0.007*2.30] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.008*2.18] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.009*2.10] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.029*5.38] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.penicillium_chrysogenum.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/penicillium_chrysogenum.15000.fasta\n[M::main] Real time: 1.031 sec; CPU: 5.542 sec; Peak RSS: 0.098 GB')
# (0, '[M::mm_idx_gen::0.008*1.15] collected minimizers\n[M::mm_idx_gen::0.010*2.06] sorted minimizers\n[M::main::0.010*2.06] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.010*1.98] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.011*1.92] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.239*5.46] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.aspergillus_flavus.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_flavus.15000.fasta\n[M::main] Real time: 1.241 sec; CPU: 6.774 sec; Peak RSS: 0.098 GB')
# (0, '[M::mm_idx_gen::0.009*1.12] collected minimizers\n[M::mm_idx_gen::0.012*2.05] sorted minimizers\n[M::main::0.012*2.05] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.013*1.98] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.014*1.92] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.047*5.32] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.aspergillus_niger.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/aspergillus_niger.15000.fasta\n[M::main] Real time: 1.048 sec; CPU: 5.566 sec; Peak RSS: 0.098 GB')
# (0, '[M::mm_idx_gen::0.009*1.13] collected minimizers\n[M::mm_idx_gen::0.010*1.86] sorted minimizers\n[M::main::0.011*1.86] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.011*1.80] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.012*1.75] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.008*5.38] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.pichia_kudriavzevii.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_kudriavzevii.15000.fasta\n[M::main] Real time: 1.010 sec; CPU: 5.425 sec; Peak RSS: 0.096 GB')
# (0, '[M::mm_idx_gen::0.009*1.10] collected minimizers\n[M::mm_idx_gen::0.011*1.82] sorted minimizers\n[M::main::0.011*1.82] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.011*1.76] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.012*1.72] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::0.978*5.36] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.pichia_membranifaciens.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/pichia_membranifaciens.15000.fasta\n[M::main] Real time: 0.980 sec; CPU: 5.246 sec; Peak RSS: 0.094 GB')
# (0, '[M::mm_idx_gen::0.007*1.19] collected minimizers\n[M::mm_idx_gen::0.009*2.13] sorted minimizers\n[M::main::0.009*2.12] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.010*2.03] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.011*1.96] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.269*5.46] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_albicans.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_albicans.15000.fasta\n[M::main] Real time: 1.271 sec; CPU: 6.932 sec; Peak RSS: 0.095 GB')
# (0, '[M::mm_idx_gen::0.010*1.14] collected minimizers\n[M::mm_idx_gen::0.013*1.93] sorted minimizers\n[M::main::0.013*1.93] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.014*1.86] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.014*1.81] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.381*5.48] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_parapsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_parapsilosis.15000.fasta\n[M::main] Real time: 1.382 sec; CPU: 7.562 sec; Peak RSS: 0.096 GB')
# (0, '[M::mm_idx_gen::0.011*1.13] collected minimizers\n[M::mm_idx_gen::0.013*1.82] sorted minimizers\n[M::main::0.013*1.82] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.014*1.77] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.014*1.73] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.347*5.48] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_orthopsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_orthopsilosis.15000.fasta\n[M::main] Real time: 1.349 sec; CPU: 7.383 sec; Peak RSS: 0.096 GB')
# (0, '[M::mm_idx_gen::0.011*1.11] collected minimizers\n[M::mm_idx_gen::0.013*1.82] sorted minimizers\n[M::main::0.013*1.81] loaded/built the index for 44 target sequence(s)\n[M::mm_mapopt_update::0.014*1.76] mid_occ = 45\n[M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 44\n[M::mm_idx_stat::0.015*1.72] distinct minimizers: 9696 (71.01% are singletons); average occurrences: 2.462; average spacing: 5.428\n[M::worker_pipeline::1.372*5.47] mapped 15000 sequences\n[M::main] Version: 2.17-r941\n[M::main] CMD: minimap2 -x map-ont -t 6 -o /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref_db/gsref.db.candida_metapsilosis.minimap2.paf /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/gsref.db.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/Mapping_mock_gsref/MC_READS/candida_metapsilosis.15000.fasta\n[M::main] Real time: 1.374 sec; CPU: 7.509 sec; Peak RSS: 0.096 GB')

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    sub_df = sub_df[tmp_df['nmatch'] == tmp_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')

# %%
###this is running the reads against the full database
for species, hit_fn in new_db_mapping_fn.items():
    mapping_results(hit_fn, species)
# Out:
# ##########
#
# This was the query species: penicillium_chrysogenum
#
# These are the results:
# tname
# penicillium_chrysogenum          0.987957
# aspergillus_niger                0.002348
# aspergillus_flavus               0.001894
# aspergillus_unidentified         0.001515
# tuber_brumale                    0.000682
# kluyveromyces_unidentified       0.000606
# kluyveromyces_marxianus          0.000606
# zymoseptoria_tritici             0.000454
# cortinarius_globuliformis        0.000454
# pyrenophora_tritici-repentis     0.000303
# puccinia_striiformis-tritici     0.000303
# clavispora_lusitaniae            0.000303
# meyerozyma_guillermondii         0.000227
# kodamaea_ohmeri                  0.000227
# dothiorella_vidmadera            0.000151
# asteroma_ccl060                  0.000151
# cladophialophora_unidentified    0.000151
# debaryomyces_unidentified        0.000151
# rhodotorula_mucilaginosa         0.000151
# oculimacula_yallundae-ccl031     0.000151
# zygoascus_hellenicus             0.000076
# candida_metapsilosis             0.000076
# yamadazyma_scolyti               0.000076
# yamadazyma_mexicana              0.000076
# pichia_membranifaciens           0.000076
# asteroma_ccl068                  0.000076
# blastobotrys_proliferans         0.000076
# candida_albicans                 0.000076
# candida_parapsilosis             0.000076
# diaporthe_unidentified           0.000076
# candida_unidentified             0.000076
# pichia_kudriavzevii              0.000076
# scedosporium_boydii              0.000076
# wickerhamomyces_anomalus         0.000076
# quambalaria_cyanescens           0.000076
# diaporthe_ccl067                 0.000076
# dtype: float64
#
# ##########
#
# This was the query species: aspergillus_flavus
#
# These are the results:
# tname
# aspergillus_flavus               0.990205
# aspergillus_niger                0.003437
# aspergillus_unidentified         0.002320
# penicillium_chrysogenum          0.001718
# blastobotrys_proliferans         0.000258
# kodamaea_ohmeri                  0.000258
# zymoseptoria_tritici             0.000258
# pyrenophora_tritici-repentis     0.000172
# rhodotorula_mucilaginosa         0.000172
# dothiorella_vidmadera            0.000172
# yamadazyma_scolyti               0.000172
# entoleuca_unidentified           0.000172
# quambalaria_cyanescens           0.000086
# zygoascus_hellenicus             0.000086
# debaryomyces_unidentified        0.000086
# cryptococcus_zero                0.000086
# cladophialophora_unidentified    0.000086
# candida_metapsilosis             0.000086
# tuber_brumale                    0.000086
# yamadazyma_mexicana              0.000086
# dtype: float64
# /home/ben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# ##########
#
# This was the query species: aspergillus_niger
#
# These are the results:
# tname
# aspergillus_niger                0.770105
# aspergillus_unidentified         0.167564
# aspergillus_flavus               0.049178
# penicillium_chrysogenum          0.007175
# entoleuca_unidentified           0.000747
# yamadazyma_mexicana              0.000598
# oculimacula_yallundae-ccl031     0.000598
# dothiorella_vidmadera            0.000448
# meyerozyma_guillermondii         0.000448
# pyrenophora_tritici-repentis     0.000448
# diaporthe_ccl067                 0.000299
# asteroma_ccl060                  0.000299
# pichia_membranifaciens           0.000149
# yarrowia_lipolytica              0.000149
# yamadazyma_scolyti               0.000149
# candida_metapsilosis             0.000149
# cladophialophora_unidentified    0.000149
# debaryomyces_unidentified        0.000149
# tuber_brumale                    0.000149
# saccharomyces_cerevisiae         0.000149
# galactomyces_geotrichum          0.000149
# kodamaea_ohmeri                  0.000149
# zygoascus_hellenicus             0.000149
# oculimacula_yallundae-ccl029     0.000149
# rhodotorula_mucilaginosa         0.000149
# zymoseptoria_tritici             0.000149
# dtype: float64
#
# ##########
#
# This was the query species: pichia_kudriavzevii
#
# These are the results:
# tname
# pichia_kudriavzevii              0.994644
# pichia_membranifaciens           0.002232
# clavispora_lusitaniae            0.000446
# candida_metapsilosis             0.000298
# candida_orthopsilosis            0.000298
# tuber_brumale                    0.000223
# kodamaea_ohmeri                  0.000223
# cladophialophora_unidentified    0.000223
# galactomyces_geotrichum          0.000149
# candida_parapsilosis             0.000149
# candida_unidentified             0.000149
# aspergillus_unidentified         0.000074
# asteroma_ccl060                  0.000074
# candida_albicans                 0.000074
# yarrowia_lipolytica              0.000074
# debaryomyces_unidentified        0.000074
# yamadazyma_scolyti               0.000074
# kluyveromyces_unidentified       0.000074
# meyerozyma_guillermondii         0.000074
# oculimacula_yallundae-ccl029     0.000074
# oculimacula_yallundae-ccl031     0.000074
# saccharomyces_cerevisiae         0.000074
# yamadazyma_mexicana              0.000074
# aspergillus_flavus               0.000074
# dtype: float64
#
# ##########
#
# This was the query species: pichia_membranifaciens
#
# These are the results:
# tname
# pichia_membranifaciens           0.991393
# pichia_kudriavzevii              0.002134
# kodamaea_ohmeri                  0.000782
# candida_orthopsilosis            0.000569
# candida_parapsilosis             0.000427
# wickerhamomyces_anomalus         0.000427
# candida_metapsilosis             0.000427
# debaryomyces_unidentified        0.000427
# galactomyces_geotrichum          0.000427
# clavispora_lusitaniae            0.000356
# kluyveromyces_unidentified       0.000285
# yarrowia_lipolytica              0.000285
# candida_unidentified             0.000213
# kluyveromyces_marxianus          0.000213
# yamadazyma_scolyti               0.000213
# zygoascus_hellenicus             0.000213
# meyerozyma_guillermondii         0.000213
# yamadazyma_mexicana              0.000142
# quambalaria_cyanescens           0.000142
# rhodotorula_mucilaginosa         0.000142
# saccharomyces_cerevisiae         0.000142
# candida_albicans                 0.000142
# zymoseptoria_tritici             0.000071
# cladophialophora_unidentified    0.000071
# tuber_brumale                    0.000071
# blastobotrys_proliferans         0.000071
# dtype: float64
#
# ##########
#
# This was the query species: candida_albicans
#
# These are the results:
# tname
# candida_albicans                0.416895
# candida_unidentified            0.278387
# candida_orthopsilosis           0.124383
# candida_metapsilosis            0.075699
# candida_parapsilosis            0.072682
# meyerozyma_guillermondii        0.006445
# debaryomyces_unidentified       0.004251
# galactomyces_geotrichum         0.003017
# kluyveromyces_marxianus         0.002468
# yamadazyma_mexicana             0.002057
# kluyveromyces_unidentified      0.001646
# kodamaea_ohmeri                 0.001509
# yamadazyma_scolyti              0.001371
# pyrenophora_tritici-repentis    0.001097
# saccharomyces_cerevisiae        0.000960
# tuber_brumale                   0.000960
# wickerhamomyces_anomalus        0.000960
# blastobotrys_proliferans        0.000823
# clavispora_lusitaniae           0.000823
# entoleuca_unidentified          0.000549
# diaporthe_ccl067                0.000549
# zygoascus_hellenicus            0.000411
# pichia_membranifaciens          0.000274
# puccinia_striiformis-tritici    0.000274
# rhodotorula_mucilaginosa        0.000274
# oculimacula_yallundae-ccl029    0.000274
# asteroma_ccl068                 0.000137
# zymoseptoria_tritici            0.000137
# cortinarius_globuliformis       0.000137
# cryptococcus_zero               0.000137
# pichia_kudriavzevii             0.000137
# quambalaria_cyanescens          0.000137
# asteroma_ccl060                 0.000137
# dtype: float64
#
# ##########
#
# This was the query species: candida_parapsilosis
#
# These are the results:
# tname
# candida_parapsilosis            0.819925
# candida_orthopsilosis           0.076185
# candida_metapsilosis            0.069259
# candida_albicans                0.008702
# candida_unidentified            0.008524
# debaryomyces_unidentified       0.001953
# meyerozyma_guillermondii        0.001953
# oculimacula_yallundae-ccl029    0.001243
# yamadazyma_scolyti              0.001066
# yamadazyma_mexicana             0.001066
# galactomyces_geotrichum         0.000888
# kluyveromyces_marxianus         0.000888
# wickerhamomyces_anomalus        0.000888
# kodamaea_ohmeri                 0.000888
# entoleuca_unidentified          0.000710
# kluyveromyces_unidentified      0.000710
# aspergillus_niger               0.000533
# scedosporium_boydii             0.000533
# saccharomyces_cerevisiae        0.000533
# zygoascus_hellenicus            0.000355
# tuber_brumale                   0.000355
# pichia_kudriavzevii             0.000355
# fusarium_oxysporum              0.000355
# pichia_membranifaciens          0.000355
# pyrenophora_tritici-repentis    0.000178
# asteroma_ccl060                 0.000178
# blastobotrys_proliferans        0.000178
# yarrowia_lipolytica             0.000178
# cortinarius_globuliformis       0.000178
# cryptococcus_zero               0.000178
# diaporthe_unidentified          0.000178
# dothiorella_vidmadera           0.000178
# oculimacula_yallundae-ccl031    0.000178
# clavispora_lusitaniae           0.000178
# dtype: float64
#
# ##########
#
# This was the query species: candida_orthopsilosis
#
# These are the results:
# tname
# candida_orthopsilosis            0.595565
# candida_metapsilosis             0.217829
# candida_parapsilosis             0.131310
# candida_unidentified             0.018238
# meyerozyma_guillermondii         0.011380
# candida_albicans                 0.010213
# debaryomyces_unidentified        0.003356
# kodamaea_ohmeri                  0.001459
# yamadazyma_scolyti               0.001167
# yamadazyma_mexicana              0.001167
# galactomyces_geotrichum          0.001021
# wickerhamomyces_anomalus         0.000875
# oculimacula_yallundae-ccl029     0.000730
# blastobotrys_proliferans         0.000730
# saccharomyces_cerevisiae         0.000584
# clavispora_lusitaniae            0.000438
# yarrowia_lipolytica              0.000438
# kluyveromyces_marxianus          0.000438
# entoleuca_unidentified           0.000292
# pichia_kudriavzevii              0.000292
# kluyveromyces_unidentified       0.000292
# tuber_brumale                    0.000292
# cladophialophora_unidentified    0.000292
# asteroma_ccl060                  0.000146
# zymoseptoria_tritici             0.000146
# cryptococcus_zero                0.000146
# diaporthe_ccl067                 0.000146
# dothiorella_vidmadera            0.000146
# zygoascus_hellenicus             0.000146
# pichia_membranifaciens           0.000146
# pyrenophora_tritici-repentis     0.000146
# quambalaria_cyanescens           0.000146
# scedosporium_boydii              0.000146
# aspergillus_niger                0.000146
# dtype: float64
#
# ##########
#
# This was the query species: candida_metapsilosis
#
# These are the results:
# tname
# candida_metapsilosis             0.425555
# candida_orthopsilosis            0.349892
# candida_parapsilosis             0.166892
# candida_unidentified             0.020303
# candida_albicans                 0.012723
# kodamaea_ohmeri                  0.005143
# meyerozyma_guillermondii         0.003249
# debaryomyces_unidentified        0.003113
# diaporthe_unidentified           0.002166
# fusarium_oxysporum               0.001760
# yamadazyma_scolyti               0.000947
# galactomyces_geotrichum          0.000947
# oculimacula_yallundae-ccl029     0.000812
# yamadazyma_mexicana              0.000812
# kluyveromyces_unidentified       0.000677
# tuber_brumale                    0.000677
# pichia_kudriavzevii              0.000541
# blastobotrys_proliferans         0.000541
# clavispora_lusitaniae            0.000541
# wickerhamomyces_anomalus         0.000406
# penicillium_chrysogenum          0.000271
# saccharomyces_cerevisiae         0.000271
# entoleuca_unidentified           0.000271
# kluyveromyces_marxianus          0.000271
# asteroma_ccl060                  0.000135
# zygoascus_hellenicus             0.000135
# cladophialophora_unidentified    0.000135
# cortinarius_globuliformis        0.000135
# yarrowia_lipolytica              0.000135
# puccinia_striiformis-tritici     0.000135
# quambalaria_cyanescens           0.000135
# rhodotorula_mucilaginosa         0.000135
# aspergillus_flavus               0.000135
# dtype: float64

# %%
###this is running against a database that have ['Candida_orthopsilosis', 'Candida_metapsilosis', 'Aspergillus_niger'] deleted
for species, hit_fn in sub_db_mapping_fn.items():
    mapping_results(hit_fn, species)
# Out:
# ##########
#
# This was the query species: penicillium_chrysogenum
#
# These are the results:
# tname
# penicillium_chrysogenum          0.989973
# aspergillus_unidentified         0.002302
# aspergillus_flavus               0.001783
# kluyveromyces_marxianus          0.000743
# tuber_brumale                    0.000594
# zymoseptoria_tritici             0.000520
# kluyveromyces_unidentified       0.000446
# cortinarius_globuliformis        0.000446
# puccinia_striiformis-tritici     0.000371
# pyrenophora_tritici-repentis     0.000371
# rhodotorula_mucilaginosa         0.000297
# meyerozyma_guillermondii         0.000223
# kodamaea_ohmeri                  0.000223
# clavispora_lusitaniae            0.000223
# cladophialophora_unidentified    0.000223
# asteroma_ccl068                  0.000149
# debaryomyces_unidentified        0.000149
# oculimacula_yallundae-ccl031     0.000149
# quambalaria_cyanescens           0.000074
# candida_parapsilosis             0.000074
# scedosporium_boydii              0.000074
# asteroma_ccl060                  0.000074
# blastobotrys_proliferans         0.000074
# pichia_membranifaciens           0.000074
# candida_unidentified             0.000074
# pichia_kudriavzevii              0.000074
# diaporthe_unidentified           0.000074
# wickerhamomyces_anomalus         0.000074
# diaporthe_ccl067                 0.000074
# dtype: float64
#
# ##########
#
# This was the query species: aspergillus_flavus
#
# These are the results:
# tname
# aspergillus_flavus              0.995077
# aspergillus_unidentified        0.002121
# penicillium_chrysogenum         0.001136
# blastobotrys_proliferans        0.000227
# pyrenophora_tritici-repentis    0.000151
# kodamaea_ohmeri                 0.000151
# entoleuca_unidentified          0.000151
# dothiorella_vidmadera           0.000151
# cryptococcus_zero               0.000151
# zymoseptoria_tritici            0.000151
# yamadazyma_mexicana             0.000076
# tuber_brumale                   0.000076
# rhodotorula_mucilaginosa        0.000076
# quambalaria_cyanescens          0.000076
# zygoascus_hellenicus            0.000076
# debaryomyces_unidentified       0.000076
# yamadazyma_scolyti              0.000076
# dtype: float64
# /home/ben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# ##########
#
# This was the query species: aspergillus_niger
#
# These are the results:
# tname
# aspergillus_unidentified         0.940982
# aspergillus_flavus               0.040535
# penicillium_chrysogenum          0.011217
# dothiorella_vidmadera            0.001530
# zymoseptoria_tritici             0.001147
# meyerozyma_guillermondii         0.000510
# pyrenophora_tritici-repentis     0.000510
# entoleuca_unidentified           0.000510
# cladophialophora_unidentified    0.000382
# tuber_brumale                    0.000255
# diaporthe_ccl067                 0.000255
# yamadazyma_mexicana              0.000255
# zygoascus_hellenicus             0.000255
# oculimacula_yallundae-ccl031     0.000255
# puccinia_striiformis-tritici     0.000255
# oculimacula_yallundae-ccl029     0.000255
# saccharomyces_cerevisiae         0.000127
# diaporthe_unidentified           0.000127
# wickerhamomyces_anomalus         0.000127
# debaryomyces_unidentified        0.000127
# candida_albicans                 0.000127
# asteroma_ccl068                  0.000127
# yamadazyma_scolyti               0.000127
# dtype: float64
#
# ##########
#
# This was the query species: pichia_kudriavzevii
#
# These are the results:
# tname
# pichia_kudriavzevii              0.995168
# pichia_membranifaciens           0.002081
# clavispora_lusitaniae            0.000446
# tuber_brumale                    0.000297
# candida_parapsilosis             0.000297
# zymoseptoria_tritici             0.000149
# blastobotrys_proliferans         0.000149
# cladophialophora_unidentified    0.000149
# galactomyces_geotrichum          0.000149
# debaryomyces_unidentified        0.000149
# aspergillus_unidentified         0.000074
# asteroma_ccl060                  0.000074
# candida_albicans                 0.000074
# candida_unidentified             0.000074
# kodamaea_ohmeri                  0.000074
# zygoascus_hellenicus             0.000074
# meyerozyma_guillermondii         0.000074
# oculimacula_yallundae-ccl029     0.000074
# saccharomyces_cerevisiae         0.000074
# wickerhamomyces_anomalus         0.000074
# yamadazyma_scolyti               0.000074
# yarrowia_lipolytica              0.000074
# aspergillus_flavus               0.000074
# dtype: float64
#
# ##########
#
# This was the query species: pichia_membranifaciens
#
# These are the results:
# tname
# pichia_membranifaciens           0.991194
# pichia_kudriavzevii              0.002131
# kodamaea_ohmeri                  0.000781
# candida_parapsilosis             0.000639
# debaryomyces_unidentified        0.000568
# galactomyces_geotrichum          0.000497
# meyerozyma_guillermondii         0.000497
# clavispora_lusitaniae            0.000426
# candida_albicans                 0.000426
# wickerhamomyces_anomalus         0.000426
# candida_unidentified             0.000355
# kluyveromyces_unidentified       0.000355
# zygoascus_hellenicus             0.000213
# yamadazyma_mexicana              0.000213
# kluyveromyces_marxianus          0.000213
# yarrowia_lipolytica              0.000213
# rhodotorula_mucilaginosa         0.000142
# quambalaria_cyanescens           0.000142
# yamadazyma_scolyti               0.000142
# zymoseptoria_tritici             0.000071
# oculimacula_yallundae-ccl029     0.000071
# cladophialophora_unidentified    0.000071
# saccharomyces_cerevisiae         0.000071
# tuber_brumale                    0.000071
# blastobotrys_proliferans         0.000071
# dtype: float64
#
# ##########
#
# This was the query species: candida_albicans
#
# These are the results:
# tname
# candida_albicans                0.484864
# candida_unidentified            0.315478
# candida_parapsilosis            0.160305
# meyerozyma_guillermondii        0.009608
# debaryomyces_unidentified       0.005791
# yamadazyma_mexicana             0.002632
# kluyveromyces_unidentified      0.002369
# kluyveromyces_marxianus         0.002369
# yamadazyma_scolyti              0.002369
# galactomyces_geotrichum         0.001974
# kodamaea_ohmeri                 0.001711
# saccharomyces_cerevisiae        0.001579
# wickerhamomyces_anomalus        0.001448
# blastobotrys_proliferans        0.001316
# clavispora_lusitaniae           0.000921
# pyrenophora_tritici-repentis    0.000790
# entoleuca_unidentified          0.000658
# pichia_membranifaciens          0.000526
# tuber_brumale                   0.000526
# oculimacula_yallundae-ccl029    0.000395
# asteroma_ccl060                 0.000263
# diaporthe_ccl067                0.000263
# cryptococcus_zero               0.000263
# zygoascus_hellenicus            0.000263
# asteroma_ccl068                 0.000132
# zymoseptoria_tritici            0.000132
# cortinarius_globuliformis       0.000132
# diaporthe_unidentified          0.000132
# dothiorella_vidmadera           0.000132
# pichia_kudriavzevii             0.000132
# quambalaria_cyanescens          0.000132
# rhodotorula_mucilaginosa        0.000132
# scedosporium_boydii             0.000132
# aspergillus_flavus              0.000132
# dtype: float64
#
# ##########
#
# This was the query species: candida_parapsilosis
#
# These are the results:
# tname
# candida_parapsilosis             0.985721
# candida_unidentified             0.002487
# candida_albicans                 0.001925
# debaryomyces_unidentified        0.000963
# meyerozyma_guillermondii         0.000882
# kodamaea_ohmeri                  0.000722
# clavispora_lusitaniae            0.000562
# blastobotrys_proliferans         0.000562
# yamadazyma_mexicana              0.000562
# galactomyces_geotrichum          0.000481
# kluyveromyces_unidentified       0.000481
# kluyveromyces_marxianus          0.000481
# yamadazyma_scolyti               0.000481
# pichia_membranifaciens           0.000481
# saccharomyces_cerevisiae         0.000401
# tuber_brumale                    0.000401
# pichia_kudriavzevii              0.000321
# wickerhamomyces_anomalus         0.000321
# cladophialophora_unidentified    0.000241
# zymoseptoria_tritici             0.000241
# dothiorella_vidmadera            0.000241
# oculimacula_yallundae-ccl029     0.000241
# yarrowia_lipolytica              0.000160
# diaporthe_unidentified           0.000080
# cryptococcus_zero                0.000080
# entoleuca_unidentified           0.000080
# zygoascus_hellenicus             0.000080
# pyrenophora_tritici-repentis     0.000080
# asteroma_ccl060                  0.000080
# aspergillus_unidentified         0.000080
# aspergillus_flavus               0.000080
# dtype: float64
#
# ##########
#
# This was the query species: candida_orthopsilosis
#
# These are the results:
# tname
# candida_parapsilosis             0.939677
# meyerozyma_guillermondii         0.017758
# candida_unidentified             0.011929
# candida_albicans                 0.007998
# debaryomyces_unidentified        0.004609
# yamadazyma_scolyti               0.002982
# yamadazyma_mexicana              0.002847
# wickerhamomyces_anomalus         0.001898
# kodamaea_ohmeri                  0.001220
# clavispora_lusitaniae            0.001084
# blastobotrys_proliferans         0.001084
# tuber_brumale                    0.001084
# galactomyces_geotrichum          0.000813
# saccharomyces_cerevisiae         0.000678
# kluyveromyces_marxianus          0.000678
# kluyveromyces_unidentified       0.000678
# zygoascus_hellenicus             0.000407
# dothiorella_vidmadera            0.000407
# pichia_membranifaciens           0.000271
# entoleuca_unidentified           0.000271
# cladophialophora_unidentified    0.000271
# asteroma_ccl068                  0.000136
# zymoseptoria_tritici             0.000136
# diaporthe_ccl067                 0.000136
# diaporthe_unidentified           0.000136
# penicillium_chrysogenum          0.000136
# pichia_kudriavzevii              0.000136
# quambalaria_cyanescens           0.000136
# rhodotorula_mucilaginosa         0.000136
# yarrowia_lipolytica              0.000136
# asteroma_ccl060                  0.000136
# dtype: float64
#
# ##########
#
# This was the query species: candida_metapsilosis
#
# These are the results:
# tname
# candida_parapsilosis             0.965001
# candida_unidentified             0.007355
# candida_albicans                 0.005960
# meyerozyma_guillermondii         0.004692
# debaryomyces_unidentified        0.003424
# kodamaea_ohmeri                  0.002156
# yamadazyma_scolyti               0.001395
# yamadazyma_mexicana              0.001268
# wickerhamomyces_anomalus         0.001268
# kluyveromyces_marxianus          0.000888
# blastobotrys_proliferans         0.000888
# kluyveromyces_unidentified       0.000888
# saccharomyces_cerevisiae         0.000761
# clavispora_lusitaniae            0.000634
# galactomyces_geotrichum          0.000634
# tuber_brumale                    0.000507
# zymoseptoria_tritici             0.000380
# oculimacula_yallundae-ccl031     0.000380
# pichia_kudriavzevii              0.000254
# pyrenophora_tritici-repentis     0.000254
# yarrowia_lipolytica              0.000127
# fusarium_oxysporum               0.000127
# entoleuca_unidentified           0.000127
# cladophialophora_unidentified    0.000127
# pichia_membranifaciens           0.000127
# quambalaria_cyanescens           0.000127
# rhodotorula_mucilaginosa         0.000127
# asteroma_ccl068                  0.000127
# dtype: float64
