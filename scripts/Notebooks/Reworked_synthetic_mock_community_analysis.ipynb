# %% [markdown]
# ### Notebook to analyzse the efficiency of minimap mapping against a mock community

# %% [markdown]
# Starting points from Tavish
# reference_dataframe at '/media/MassStorage/tmp/TE/honours/analysis/Stats/reference_dataframe.csv'
# custom_database at '/media/MassStorage/tmp/TE/honours/database/custom_database_labelled.fasta'
# taxonomy_file at '/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file.csv'

# %% [markdown]
# #### workflow
#
# * Two databases
# * subsample 15000 reads per each mock community species. Save those out.
# * map reads against both databases with minimap safe out data in paf format.
# * get best hit per species (see what this means while looking at the data).
# * add the full taxonomy to each best match using the taxonomy file.
# * summarize data at different taxonomic ranks for each species.
# * pull this all together somehow (summary across all the samples? focus on species of interest e.g. deleted from analyis?)

# %% [markdown]
# #### requirment
#
# * Bbmap (conda install bbmap https://anaconda.org/bioconda/bbmap)
# * minimap2 (conda install minimap2 https://anaconda.org/bioconda/minimap2)

# %% [markdown]
# #### fixes on the command line
#
# * fixed the taxonomy file to fit with the quiime format
#
# cat /media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file.csv | sed 's/,/\t/' > /media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_v2.csv

# %% [markdown]
# #### fix the taxonomy_file_v2.csv more to reflect Qiime style
#
# * This requires to make the species name genus_species and not _species.... hope this makes sense

# %%
import re
old_taxonomy_file_fn = '/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_v2.csv'
new_taxonomy_file_fn = '/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_v3.csv'
with open(new_taxonomy_file_fn, 'w') as out_fh:
    with open(old_taxonomy_file_fn, 'r') as in_fh:
        for line in in_fh:
            line = line.rstrip()
            #print(line)
            first_half = line.split('s__')[0]
            second_half = line.split('s__')[1]
            pattern = re.compile(r'g__\w+;')
            genus = re.findall(pattern, first_half)[0].replace('g__','').replace(';','')
            new_line = F"{first_half}s__{genus}_{second_half}"
            print(new_line,file=out_fh)

# %%
# !head -2 {old_taxonomy_file_fn}

# %%
# !head -2 {new_taxonomy_file_fn}

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

# %% [markdown]
# #### Initial data

# %%
reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/reference_dataframe.csv')
max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/custom_database_labelled.fasta')
taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_qiime.csv')

# %%
#threads to use
threads = 6

# %%
INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping_mock_gsref')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis-tritici',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']

# %%
# ###Removed from second test databes
species_delete = [
# 'Candida_orthopsilosis',
#                  'Candida_metapsilosis',
#                  'Aspergillus_niger'
]

# %%
###species to be searched against both databases
# mock_community = ['Penicillium_chrysogenum',
#  'Aspergillus_flavus',
#  'Aspergillus_niger',
#  'Pichia_kudriavzevii',
#  'Pichia_membranifaciens',
#  'Candida_albicans',
#  'Candida_parapsilosis',
#  'Candida_orthopsilosis',
#  'Candida_metapsilosis']

mock_community = ['Puccinia_striiformis-tritici',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']

# %%
# fixed_old_names = ['Kluyveromyces_lactis',
#                    'Candida_zeylanoides',
#                    'Cladophialophora_sp.',
#                    'Diaporthe_sp.',
#                    'CCL060',
#                    'CCL068',
#                    'CCL067',
#                    'Aspergillus_sp.',
#                    'Entoleuca_sp.',
#                    'Tapesia_yallundae_CCL029',
#                    'Tapesia_yallundae_CCL031',
#                    'Cryptococcus_neoformans']

# %%
# fixed_new_names = ['candida_unidentified',
#                    'debaryomyces_unidentified',
#                    'cladophialophora_unidentified',
#                    'diaporthe_unidentified',
#                    'asteroma_ccl060',
#                    'asteroma_ccl068',
#                    'diaporthe_ccl067',
#                    'aspergillus_unidentified',
#                    'entoleuca_unidentified',
#                    'oculimacula_yallundae-ccl029',
#                    'oculimacula_yallundae-ccl031',
#                    'kluyveromyces_unidentified']

# %%
# old_to_new_names = dict(zip(fixed_old_names, fixed_new_names))

# %%
# old_to_new_names

# %% [markdown]
# ### Fix databases and names

# %%
ref_df = pd.read_csv(reference_dataframe_fn)
ref_df['name_species'] = ref_df['genus'] +"_"+ ref_df['species']

# %%
ref_df.name_species.tolist()

# %%
new_db_fn = os.path.join(OUT_DIR, 'gsref.db.fasta')

# %%
new_db_list = []
old_db_list = []
for seq in SeqIO.parse(max_custom_database_fn, 'fasta'):
    old_db_list.append(seq.id)
    if seq.id.lower() in ref_df.name_species.tolist():
        #print(seq.id)
        seq.id = seq.name = seq.description = seq.id.lower()
        new_db_list.append(seq)
    else:
        print(seq.id)

# %%
if len(new_db_list) == len(old_db_list):
    SeqIO.write(new_db_list, new_db_fn, 'fasta')
else:
    print("please check!")

# %%
sub_db_fn = os.path.join(OUT_DIR, 'gsref.subdb.fasta')
sub_db_list = []
for seq in new_db_list:
    if seq.id not in [x.lower() for x in species_delete]:
        sub_db_list.append(seq)

# %%
if len(sub_db_list) + len(species_delete) == len(new_db_list):
    SeqIO.write(sub_db_list, sub_db_fn, 'fasta' )
else:
    print("please check!")

# %%
[x.id for x in sub_db_list]

# %%
mock_community = [x.lower() for x in mock_community]

# %%
mock_community

# %% [markdown]
# ### Subsample reads

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 2000

# %%
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)

# %%
ref_df.columns

# %%
fn_subsampling = {}
for x in mock_community:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/%s.json' % species)

# %%
###this is running the reads against the full database
for species, hit_fn in new_db_mapping_fn.items():
    mapping_results(hit_fn, species)

# %%
###this is running against a database that have ['Candida_orthopsilosis', 'Candida_metapsilosis', 'Aspergillus_niger'] deleted
for species, hit_fn in sub_db_mapping_fn.items():
    mapping_results(hit_fn, species)

# %% [markdown]
# ### Pull in mapping results and analyse them at all available levels

# %% [markdown]
# ##### idea
#
# * pull in query taxid as a dictionary
# * assign taxid for each tname species from minimap2
# * generate a summary dictionary that checks concordance at each taxonmic rank

# %%
def pull_mapping_results(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['mquality'].count().tolist(), sub_df.groupby('tname')['mquality'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
    return hit_df

# %%
def getquery_taxfileid(refdf_fn, species):
    """
    Takes the reference dataframe filename and the species name.
    Returns the taxfileid, which is the date/flowcellid (column 0 value) of the ref_df.
    """
    ref_df = pd.read_csv(refdf_fn)
    ref_df['name_species'] = ref_df['genus'] +"_"+ ref_df['species']
    return ref_df[ref_df.name_species == species].iloc[:,0].values[0]

# %%
def get_taxid_dict(taxid_fn, taxfileid):
    """
    Takes a taxonomy assignment file filename in the Qiime format and a taxonomic identifier.
    Returns the a dictionary with the taxonomic assignment at each rank.
    """
    tax_dict = {}
    with open(taxid_fn, 'r') as fh:
        for line in fh:
            if line.startswith(taxfileid):
                taxrankids = line.rstrip().split('\t')[1].split(';')
                for taxrank in taxrankids:
                    tax_dict[taxrank.split('__')[0]] = taxrank.split('__')[1]
    return tax_dict

# %%
def assign_taxranks_results(mapping_df, tax_fn, ref_df_fn = False):
    """
    This function assigns the taxonomic ranks for each hit in the mapping results dataframe.
    It takes a mapping_df, taxonomy assignment file, and if required a reference dataframe filename.
    Returns the mapping dataframe with assignment. 
    """
    for tname in mapping_df.index:
        if ref_df_fn:
            tmp_taxfileid = getquery_taxfileid(ref_df_fn, tname)
        else:
            tmp_taxfileid = tname
        tmp_tax_dict = get_taxid_dict(tax_fn, tmp_taxfileid)
        for key, value in tmp_tax_dict.items():
            mapping_df.loc[tname, key] = value
    return mapping_df

# %%
def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarieses the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = {}
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

# %%
###Test out the summary results statistic for a single mapping result
species = 'penicillium_chrysogenum'
mapping_results = pull_mapping_results(sub_db_mapping_fn[species])

# %%
###Assign the data taxonomics ranks for all the results
mapping_results = assign_taxranks_results(mapping_results, taxonomy_file_fn, ref_df_fn=reference_dataframe_fn)

taxfileid = getquery_taxfileid(reference_dataframe_fn, species)

query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

# %%
sensitivity_dict

# %%
###Test out the summary results statistic for a single mapping result
species = 'candida_albicans'
mapping_results = pull_mapping_results(sub_db_mapping_fn[species])

# %%
###Assign the data taxonomics ranks for all the results
mapping_results = assign_taxranks_results(mapping_results, taxonomy_file_fn, ref_df_fn=reference_dataframe_fn)

taxfileid = getquery_taxfileid(reference_dataframe_fn, species)

query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

# %%
sensitivity_dict

# %%
###Test out the summary results statistic for a single mapping result
species = 'aspergillus_niger'
mapping_results = pull_mapping_results(sub_db_mapping_fn[species])

# %%
###Assign the data taxonomics ranks for all the results
mapping_results = assign_taxranks_results(mapping_results, taxonomy_file_fn, ref_df_fn=reference_dataframe_fn)

taxfileid = getquery_taxfileid(reference_dataframe_fn, species)

query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

# %%
sensitivity_dict

# %% [markdown]
# ### Test run on the qiime2 Database
#
# ##### Prep on the command line
#
# cp sh_refs_qiime_ver8_dynamic_02.02.2019.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/qiime2/db/.
# cp sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt /media/WorkingStorage/ben.working/students/tavish/analysis/qiime2/db/.

# %%
def pull_mapping_results_v2(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    #sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['mquality'].count().tolist(), sub_df.groupby('tname')['mquality'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df

# %%
os.path.abspath(os.curdir)

# %%
qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10
QIIME_DIR = os.path.abspath('../../analysis/qiime2/')

# %%
##mapping folder
mapping_dir = os.path.join(QIIME_DIR, os.path.basename(qiime_db_fn).replace('.fasta', '').replace('.','_'))
if not os.path.exists(mapping_dir):
    os.mkdir(mapping_dir)
subsampling_dir = os.path.join(QIIME_DIR, 'subsamplereads')
if not os.path.exists(subsampling_dir):
    os.mkdir(subsampling_dir)

# %% [markdown]
# #### Run on test species 'penicillium_chrysogenum'

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['penicillium_chrysogenum']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

###Test out the summary results statistic for a single mapping result
species = 'penicillium_chrysogenum'
mapping_results , full_results_df = pull_mapping_results_v2(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
###fix family level for 'penicillium_chrysogenum'
sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)


full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
full_results_df

# %%
###looking at unfiltered results
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %% [markdown]
# ##### These are wired results that might be linked to
#
# * database issues as you can see
#
# sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt: k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eurotiales;f__Aspergillaceae;g__Penicillium;s__Penicillium_chrysogenum

# %%
mapping_results[mapping_results['s'] == 'Penicillium_chrysogenum']

# %%
query_tax_dict = {}
taxrank = 'k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eurotiales;f__Aspergillaceae;g__Penicillium;s__Penicillium_chrysogenum'
for rank_id in taxrank.split(';'):
    query_tax_dict[rank_id.split('__')[0]] = rank_id.split('__')[1]
query_tax_dict

# %%
get_accuracy_dict(mapping_results, query_tax_dict)

# %%
###There must be more or equal number of mapping results compared to number of mapped reads
mapping_results['count'].sum() >= full_results_df.qseqid.unique().shape[0]

# %% [markdown]
# #### Testing on Candida albicans

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['candida_albicans']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

# %%
###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

# %%
###Test out the summary results statistic for a single mapping result
species = test_species[0]
print(sub_db_mapping_fn[species])
mapping_results , full_results_df = pull_mapping_results_v2(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
print(taxfileid)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
print(query_tax_dict)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df

# %%
os.path.abspath(os.curdir)

# %%
qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10
QIIME_DIR = os.path.abspath('../../analysis/qiime2/')

# %%
##mapping folder
mapping_dir = os.path.join(QIIME_DIR, os.path.basename(qiime_db_fn).replace('.fasta', '').replace('.','_'))
if not os.path.exists(mapping_dir):
    os.mkdir(mapping_dir)
subsampling_dir = os.path.join(QIIME_DIR, 'subsamplereads')
if not os.path.exists(subsampling_dir):
    os.mkdir(subsampling_dir)

# %% [markdown]
# #### Run on test species 'penicillium_chrysogenum'

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['penicillium_chrysogenum']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

###Test out the summary results statistic for a single mapping result
species = 'penicillium_chrysogenum'
mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
###fix family level for 'penicillium_chrysogenum'
sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)


full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
full_results_df

# %%
###looking at unfiltered results
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %% [markdown]
# ##### These are wired results that might be linked to
#
# * database issues as you can see
#
# sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt: k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eurotiales;f__Aspergillaceae;g__Penicillium;s__Penicillium_chrysogenum

# %%
mapping_results[mapping_results['s'] == 'Penicillium_chrysogenum']

# %%
query_tax_dict = {}
taxrank = 'k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eurotiales;f__Aspergillaceae;g__Penicillium;s__Penicillium_chrysogenum'
for rank_id in taxrank.split(';'):
    query_tax_dict[rank_id.split('__')[0]] = rank_id.split('__')[1]
query_tax_dict

# %%
get_accuracy_dict(mapping_results, query_tax_dict)

# %%
###There must be more or equal number of mapping results compared to number of mapped reads
mapping_results['count'].sum() >= full_results_df.qseqid.unique().shape[0]

# %% [markdown]
# #### Testing on Candida albicans

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['candida_albicans']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

# %%
###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

# %%
###Test out the summary results statistic for a single mapping result
species = test_species[0]
print(sub_db_mapping_fn[species])
mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
print(taxfileid)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
print(query_tax_dict)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %% [markdown]
# #### Might want to double check how your families are matched in your taxonomic input file for your known test species

# %%
# mapping_results[mapping_results['s'] == 'Candida_albicans']

# %%
# query_tax_dict['f'] = 'Saccharomycetales_fam_Incertae_sedis'

# %%
# get_accuracy_dict(mapping_results, query_tax_dict)

# %% [markdown]
# ### It appears that the filtering of results by mapping quality works well for the long ITS database but not for the qiime

# %%
full_results_df.columns

# %%
full_results_df.tname.shape

# %%
full_results_df.tname.unique().shape

# %%
full_results_df.index = full_results_df.tname

# %%
###Asign taxonomic ranks to the full_results_df
for tname in full_results_df.tname.unique():
    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
full_results_df[full_results_df['g'] == 'Candida']['qseqid'].shape

# %%
full_results_df[full_results_df['g'] == 'Candida']['qseqid'].unique().shape

# %%
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %% [markdown]
# Looking at the results unfiltered doesn't really work very well either. Might need to look into different filtering of the alignments or the qiime2 database might be just not really useful for the noise reads. Simulated reads with higher accuracy should get better here.

# %%
full_results_df.groupby('g').count()['k'].sort_values(ascending=False)

# %%
###There must be more or equal number of mapping results compared to number of mapped reads
mapping_results['count'].sum() >= full_results_df.qseqid.unique().shape[0]

# %% [markdown]
# #### Testing on other species

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['cortinarius_globuliformis']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

# %%
###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

# %%
###Test out the summary results statistic for a single mapping result
species = test_species[0]
print(sub_db_mapping_fn[species])
mapping_results , full_results_df = pull_mapping_results_v2(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
print(taxfileid)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
print(query_tax_dict)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():
    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
###Test out the summary results statistic for a single mapping result
species = test_species[0]
print(sub_db_mapping_fn[species])
mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
print(taxfileid)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
print(query_tax_dict)

sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)

full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():
    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
###looking at unfiltered results
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %% [markdown]
# #### Testing on all species using v3

# %%
import json
from collections import OrderedDict

def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarises the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = OrderedDict()
    total_count = mapping_df['count'].sum()
    for tax_rank in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        tmps_df = pd.DataFrame(data=None)
        if tax_rank == 's':
            for index, row in mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]].iterrows():
                if row['s'] == 'unidentified' and row['g'] != query_tax_dict['g']:
                    mapping_df.drop(index, axis=0, inplace=True)
                else:
                    continue
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        else:
            hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)

def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df
    
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)

test_species_list = []
for entry in ref_df.name_species.tolist():
#     if entry[-7:] != '-ccl031' and entry[-7:] != '-ccl029':
#         test_species_list.append(entry)
#     else:
#         test_species_list.append(entry[:-7])
#         print(entry[:-7])
    test_species_list.append(entry)
    
for test_species in test_species_list:
    
    print(test_species)
    
    #subsample tests species
    fn_subsampling = {}
    test_species = [test_species]
    for x in test_species:
        fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
        fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

    sub_reads_fn = {}
    n_reads = 20000
    for key, value in fn_subsampling.items():
        species = key
        in_fn = value
        out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
        subsamplereads(in_fn, out_fn, n_reads)
        sub_reads_fn[species] = out_fn
        
    ###Map the reads
    db_fn = qiime_db_fn
    sub_db_mapping_fn = {}
    for species, fasta_fn in sub_reads_fn.items():
        db_name = os.path.basename(db_fn).replace('.fasta', '')
        out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
        sub_db_mapping_fn[species] = out_fn
        minimapmapping(fasta_fn, db_fn, out_fn, threads)
        
    ###Test out the summary results statistic for a single mapping result
    species = test_species[0]
    mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[species])
    mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
    taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
    
    query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)

    print(type(query_tax_dict))
    print(query_tax_dict)
    
#     sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)
        
#     print(json.dumps(sensitivity_dict, indent=1))
#     print('\n')
#     with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/qiime_results/%s.json' % species, 'w+') as fp:
#         json.dump(sensitivity_dict, fp)

# %% [markdown]
# ### Test run on the qiime2 Database 99
#
# ##### Prep on the command line
#
# cp sh_refs_qiime_ver8_99_02.02.2019.fasta /media/WorkingStorage/ben.working/students/tavish/analysis/qiime2/db/.
# cp sh_taxonomy_qiime_ver8_99_02.02.2019.txt /media/WorkingStorage/ben.working/students/tavish/analysis/qiime2/db/.

# %%
qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_99_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_99_02.02.2019.txt')
threads = 10
QIIME_DIR = os.path.abspath('../../analysis/qiime2/')

# %%
##mapping folder
mapping_dir = os.path.join(QIIME_DIR, os.path.basename(qiime_db_fn).replace('.fasta', '').replace('.','_'))
print(mapping_dir)
if not os.path.exists(mapping_dir):
    os.mkdir(mapping_dir)
subsampling_dir = os.path.join(QIIME_DIR, 'subsamplereads')
if not os.path.exists(subsampling_dir):
    os.mkdir(subsampling_dir)

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['penicillium_chrysogenum']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

###Test out the summary results statistic for a single mapping result
species = 'penicillium_chrysogenum'
mapping_results , full_results_df = pull_mapping_results_v2(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
###fix family level for 'penicillium_chrysogenum'
sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)


full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
###looking at unfiltered results
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %%
###fix the query_tax_dict with the data found in the qiime database
query_tax_dict = {}
taxrank = 'k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eurotiales;f__Aspergillaceae;g__Penicillium;s__Penicillium_chrysogenum'
for rank_id in taxrank.split(';'):
    query_tax_dict[rank_id.split('__')[0]] = rank_id.split('__')[1]

# %%
get_accuracy_dict(mapping_results, query_tax_dict)

# %% [markdown]
# Use with Candida albicans

# %%
#subsample tests species
fn_subsampling = {}
test_species = ['candida_albicans']
for x in test_species:
    fn_subsampling[x] = (ref_df[(ref_df['species'] == x.split('_')[1]) & (ref_df['genus'] == x.split('_')[0])]['path for use'].tolist()[0])
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

sub_reads_fn = {}
n_reads = 20000
for key, value in fn_subsampling.items():
    species = key
    in_fn = value
    out_fn = os.path.join(subsampling_dir, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn

###Map the reads
db_fn = qiime_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(mapping_dir, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)

###Test out the summary results statistic for a single mapping result
species = 'candida_albicans'
mapping_results , full_results_df = pull_mapping_results_v2(sub_db_mapping_fn[species])
mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
taxfileid = getquery_taxfileid(reference_dataframe_fn, species)
query_tax_dict = get_taxid_dict(taxonomy_file_fn, taxfileid)
###fix family level for 'penicillium_chrysogenum'
sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)


full_results_df.index = full_results_df.tname
###Also look at the full results dataframe to explore results a bit more
for tname in full_results_df.tname.unique():

    tmp_tax_dict = get_taxid_dict(qiime_tax_fn, tname)
    for key, value in tmp_tax_dict.items():
        full_results_df.loc[tname, key] = value

# %%
sensitivity_dict

# %%
###looking at unfiltered results
###look at the results unfiltered
full_results_df['count'] = 1

get_accuracy_dict(full_results_df, query_tax_dict)

# %% [markdown]
# ## Apply to wheat species for qiime and consensus respectively

# %%
from Bio import SeqIO
import os
import random
import subprocess
import pandas as pd

INPUT_BASEDIR = os.path.abspath('/media/MassStorage/tmp/TE/honours')
subsampling_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/subsample_reads')
mapping_dir = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/qiime_results')

wheat_reference_dataframe_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/wheat_reference_dataframe.csv')
wheat_max_custom_database_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/database/wheat_database_labelled.fasta')
# taxonomy_file_fn = os.path.abspath('/media/MassStorage/tmp/TE/honours/analysis/Stats/taxonomy_file_qiime.csv')

qiime_db_fn = os.path.abspath('../../analysis/qiime2/db/sh_refs_qiime_ver8_dynamic_02.02.2019.fasta')
qiime_tax_fn = os.path.abspath('../../analysis/qiime2/db/sh_taxonomy_qiime_ver8_dynamic_02.02.2019.txt')
threads = 10

wheat_ref_df = pd.read_csv(wheat_reference_dataframe_fn)
wheat_ref_df
# Out:
#    Unnamed: 0                      species1                      species2  \
# 0   barcode01          Puccinia_striiformis                           NaN
# 1   barcode02          Zymoseptoria_tritici                           NaN
# 2   barcode03                       unknown                           NaN
# 3   barcode04          Puccinia_striiformis          Zymoseptoria_tritici
# 4   barcode05  Pyrenophora_tritici-repentis                           NaN
# 5   barcode06                       unknown                           NaN
# 6   barcode07                       unknown                           NaN
# 7   barcode08          Puccinia_striiformis                           NaN
# 8   barcode09          Puccinia_striiformis  Pyrenophora_tritici-repentis
# 9   barcode10          Puccinia_striiformis          Zymoseptoria_tritici
# 10  barcode11          Zymoseptoria_tritici          Puccinia_striiformis
#
#     # raw reads  # reads after homology filtering  \
# 0        115052                             23477
# 1        151005                             20416
# 2         92927                             23616
# 3        115407                             22716
# 4        134094                             24785
# 5        150739                             25462
# 6        109201                             24688
# 7        114215                             21725
# 8        106976                             22012
# 9        108583                             21514
# 10       118345                             22462
#
#     # reads after length filtering  # for use  \
# 0                            21590    21590.0
# 1                            18100    18100.0
# 2                            21919    21919.0
# 3                            20568    20568.0
# 4                            22433    22433.0
# 5                            23769    23769.0
# 6                            22931    22931.0
# 7                            20105    20105.0
# 8                            20451    20451.0
# 9                            19810    19810.0
# 10                           20832    20832.0
#
#                                     path to raw reads  \
# 0   analysis/Concatenated/wheat/barcode01/merged.f...
# 1   analysis/Concatenated/wheat/barcode02/merged.f...
# 2   analysis/Concatenated/wheat/barcode03/merged.f...
# 3   analysis/Concatenated/wheat/barcode04/merged.f...
# 4   analysis/Concatenated/wheat/barcode05/merged.f...
# 5   analysis/Concatenated/wheat/barcode06/merged.f...
# 6   analysis/Concatenated/wheat/barcode07/merged.f...
# 7   analysis/Concatenated/wheat/barcode08/merged.f...
# 8   analysis/Concatenated/wheat/barcode09/merged.f...
# 9   analysis/Concatenated/wheat/barcode10/merged.f...
# 10  analysis/Concatenated/wheat/barcode11/merged.f...
#
#                            path to homology filtering  \
# 0   analysis/Python_Processing/wheat/barcode01/com...
# 1   analysis/Python_Processing/wheat/barcode02/com...
# 2   analysis/Python_Processing/wheat/barcode03/com...
# 3   analysis/Python_Processing/wheat/barcode04/com...
# 4   analysis/Python_Processing/wheat/barcode05/com...
# 5   analysis/Python_Processing/wheat/barcode06/com...
# 6   analysis/Python_Processing/wheat/barcode07/com...
# 7   analysis/Python_Processing/wheat/barcode08/com...
# 8   analysis/Python_Processing/wheat/barcode09/com...
# 9   analysis/Python_Processing/wheat/barcode10/com...
# 10  analysis/Python_Processing/wheat/barcode11/com...
#
#                              path to length filtering  \
# 0   analysis/Length_Filtered/wheat/barcode01/lengt...
# 1   analysis/Length_Filtered/wheat/barcode02/lengt...
# 2   analysis/Length_Filtered/wheat/barcode03/lengt...
# 3   analysis/Length_Filtered/wheat/barcode04/lengt...
# 4   analysis/Length_Filtered/wheat/barcode05/lengt...
# 5   analysis/Length_Filtered/wheat/barcode06/lengt...
# 6   analysis/Length_Filtered/wheat/barcode07/lengt...
# 7   analysis/Length_Filtered/wheat/barcode08/lengt...
# 8   analysis/Length_Filtered/wheat/barcode09/lengt...
# 9   analysis/Length_Filtered/wheat/barcode10/lengt...
# 10  analysis/Length_Filtered/wheat/barcode11/lengt...
#
#                                          path for use
# 0   analysis/Length_Filtered/wheat/barcode01/lengt...
# 1   analysis/Length_Filtered/wheat/barcode02/lengt...
# 2   analysis/Length_Filtered/wheat/barcode03/lengt...
# 3   analysis/Length_Filtered/wheat/barcode04/lengt...
# 4   analysis/Length_Filtered/wheat/barcode05/lengt...
# 5   analysis/Length_Filtered/wheat/barcode06/lengt...
# 6   analysis/Length_Filtered/wheat/barcode07/lengt...
# 7   analysis/Length_Filtered/wheat/barcode08/lengt...
# 8   analysis/Length_Filtered/wheat/barcode09/lengt...
# 9   analysis/Length_Filtered/wheat/barcode10/lengt...
# 10  analysis/Length_Filtered/wheat/barcode11/lengt...

# %%
import json
from collections import OrderedDict
pd.set_option('display.max_rows', None)

def assign_taxranks_results(mapping_df, tax_fn, ref_df_fn = False):
    """
    This function assigns the taxonomic ranks for each hit in the mapping results dataframe.
    It takes a mapping_df, taxonomy assignment file, and if required a reference dataframe filename.
    Returns the mapping dataframe with assignment. 
    """
    for tname in mapping_df.index:
        if ref_df_fn:
            tmp_taxfileid = getquery_taxfileid(ref_df_fn, tname)
        else:
            tmp_taxfileid = tname
        tmp_tax_dict = get_taxid_dict(tax_fn, tmp_taxfileid)
        for key, value in tmp_tax_dict.items():
            mapping_df.loc[tname, key] = value
    return mapping_df

def get_accuracy_dict(mapping_df, query_tax_dict):
    """
    Summarises the mapping accuracy of the mapping results at all taxonomic ranks.
    Takes the mapping_df with taxnomonic assignments and a taxnomic dictionary of the known query.
    Returns an accuracy dictionary for each taxnomic rank ['k', 'p', 'c', 'o', 'f', 'g', 's']. 
    Right now this function takes a qiime tax 
    """
    accuracy_dict = OrderedDict()
    total_count = mapping_df['count'].sum()
    for tax_rank in ['s']:
        tmps_df = pd.DataFrame(data=None)
        hit_count = mapping_df[mapping_df[tax_rank] == query_tax_dict[tax_rank]]['count'].sum()
        accuracy_dict[tax_rank] = hit_count/total_count
    return accuracy_dict

def get_taxid_dict(taxid_fn, taxfileid):
    """
    Takes a taxonomy assignment file filename in the Qiime format and a taxonomic identifier.
    Returns the a dictionary with the taxonomic assignment at each rank.
    """
    tax_dict = {}
    with open(taxid_fn, 'r') as fh:
        for line in fh:
            if line.startswith(taxfileid):
                taxrankids = line.rstrip().split('\t')[1].split(';')
                for taxrank in taxrankids:
                    tax_dict[taxrank.split('__')[0]] = taxrank.split('__')[1]
    return tax_dict

def mapping_results(fn, species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the query species: {species}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/custom_results/%s.json' % species)

def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)

def pull_mapping_results_v3(fn):
    """
    Takes a minimap2 paf and reads it in with the first 12 columns. Ignores the rest.
    Filters for each read the best hit on mquality first taking the highest value.
    Filters for each read by the number of nmatches in the second step.
    Returns a dataframe that has the tnames as index and the counts of hits as column 'count'.
    The dataframe has also the taxrank columns ['k', 'p', 'c', 'o', 'f', 'g', 's'] that are all False to start with.
    """
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    tmp_df['cscore'] = tmp_df['alen']/(tmp_df['alen']-tmp_df['nmatch'])
    sub_df = tmp_df[tmp_df['cscore'] == tmp_df.groupby('qseqid')['cscore'].transform(max)].reset_index(drop=True)
#     sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_df = pd.DataFrame(sub_df.groupby('tname')['cscore'].count().tolist(), sub_df.groupby('tname')['cscore'].count().index, columns=['count'])
    hit_df.sort_values(by='count', ascending=False, inplace=True)
    for key in ['k', 'p', 'c', 'o', 'f', 'g', 's']:
        hit_df[key] = False
        tmp_df[key] = False
    return hit_df, tmp_df
    
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)

barcode_list = []
for entry in wheat_ref_df['Unnamed: 0']:
#     if entry[-7:] != '-ccl031' and entry[-7:] != '-ccl029':
#         test_species_list.append(entry)
#     else:
#         test_species_list.append(entry[:-7])
#         print(entry[:-7])
    barcode_list.append(entry)
    
counter = 0
for barcode in barcode_list:
    
    print(barcode)
    
    #subsample tests species
    fn_subsampling = {}
    barcode = [barcode]
    for x in barcode:
        fn_subsampling[x] = wheat_ref_df[wheat_ref_df['Unnamed: 0'] == x]['path for use'].tolist()[0]
        fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])

    sub_reads_fn = {}
    n_reads = 2000
    for key, value in fn_subsampling.items():
        barcode = key
        in_fn = value
        out_fn = os.path.join(subsampling_dir, F'{barcode}.{n_reads}.fasta')
        subsamplereads(in_fn, out_fn, n_reads)
        sub_reads_fn[barcode] = out_fn
        
    ###Map the reads
    db_fn = qiime_db_fn
    sub_db_mapping_fn = {}
    for barcode, fasta_fn in sub_reads_fn.items():
        db_name = os.path.basename(db_fn).replace('.fasta', '')
        out_fn = os.path.join(mapping_dir, F"{db_name}.{barcode}.minimap2.paf")
        sub_db_mapping_fn[barcode] = out_fn
        minimapmapping(fasta_fn, db_fn, out_fn, threads)
        
    ###Test out the summary results statistic for a single mapping result
    mapping_results , full_results_df = pull_mapping_results_v3(sub_db_mapping_fn[barcode])
    mapping_results = assign_taxranks_results(mapping_results, qiime_tax_fn)
    print(mapping_results.loc[:,['count', 's']])
#     print("\n\n\n")
    
    specs = []
    if wheat_ref_df[wheat_ref_df['Unnamed: 0'] == barcode]['species2'].any():
        specs = [wheat_ref_df[wheat_ref_df['Unnamed: 0'] == barcode].loc[counter,'species1'],wheat_ref_df[wheat_ref_df['Unnamed: 0'] == barcode].loc[counter,'species2']]
    else:
        specs = [wheat_ref_df[wheat_ref_df['Unnamed: 0'] == barcode].loc[counter,'species1']]

    counter += 1
    
    for element in specs:
        query_tax_dict = {'s': element}
        print(query_tax_dict)
        sensitivity_dict = get_accuracy_dict(mapping_results, query_tax_dict)
        
        print(json.dumps(sensitivity_dict, indent=1))
#     print('\n')
#     with open('/media/MassStorage/tmp/TE/honours/analysis/Mapping/qiime_results/%s.json' % species, 'w+') as fp:
#         json.dump(sensitivity_dict, fp)
# Out:
# barcode01
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    514                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             364                    unidentified
# SH1538821.08FU_AB035719_reps              278            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             206                    unidentified
# SH1563344.08FU_AM267268_reps              159          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              144                    unidentified
# SH1563343.08FU_FJ430715_reps              123                    unidentified
# SH1560162.08FU_AY225488_reps              119               Lignincola_laevis
# SH1680040.08FU_KC992945_refs_singleton    110  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps              88                    unidentified
# SH1566136.08FU_KC992951_refs               75        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               26       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               18                    unidentified
# SH1598232.08FU_HM057122_refs                7            Puccinia_striiformis
# SH1516349.08FU_KY242684_reps                5                    unidentified
# SH2127282.08FU_AY762947_refs                1          Alternaria_oregonensis
# SH1920677.08FU_KT389479_refs                1                Ascochyta_rabiei
# SH2232092.08FU_GU237898_refs                1             Ascochyta_herbicola
# SH1505864.08FU_JQ693660_refs                1       Alternaria_metachromatica
# SH1650816.08FU_FM178254_refs                1              Papiliotrema_frias
# SH1598253.08FU_AY956558_reps                1            Puccinia_striiformis
# SH1573994.08FU_KP170660_reps                1  Sphaerellopsis_macroconidialis
# SH1505885.08FU_HQ873338_reps                1              Alternaria_molesta
# SH1572792.08FU_EF679363_refs                1         Mycosphaerella_tassiana
# SH1549852.08FU_UDB024177_reps               1             Toninia_physaroides
# SH1528219.08FU_JF495242_reps                1                    unidentified
# SH2232193.08FU_KT389475_refs                1                Ascochyta_phacae
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.0035587188612099642
# }
# barcode02
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    572                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             228                    unidentified
# SH1558908.08FU_KF800655_reps              186                    unidentified
# SH1538821.08FU_AB035719_reps              139            Bannoa_ogasawarensis
# SH1523077.08FU_MH019936_reps              109                    unidentified
# SH1654757.08FU_UDB014954_reps              95                    unidentified
# SH1680040.08FU_KC992945_refs_singleton     91  Cystoagaricus_hirtosquamulosus
# SH1577464.08FU_JF700867_refs               82             Zymoseptoria_brevis
# SH1563344.08FU_AM267268_reps               72          Knoxdaviesia_cecropiae
# SH1563342.08FU_UDB028691_reps              72                    unidentified
# SH1563343.08FU_FJ430715_reps               69                    unidentified
# SH1577481.08FU_AF181701_reps               51          Zymoseptoria_halophila
# SH1541142.08FU_KR015769_reps               50                    unidentified
# SH1566136.08FU_KC992951_refs               45        Lacrymaria_subcinnamomea
# SH1560162.08FU_AY225488_reps               39               Lignincola_laevis
# SH1523966.08FU_HE820879_reps               36                    unidentified
# SH2127280.08FU_AF347034_refs               23           Alternaria_infectoria
# SH1573885.08FU_MF594688_reps               23       Deltopyxis_triangulispora
# SH1577471.08FU_KC005781_refs               21           Zymoseptoria_verkleyi
# SH1613737.08FU_GQ303275_refs               17                    unidentified
# SH1505864.08FU_JQ693660_refs               14       Alternaria_metachromatica
# SH1541263.08FU_KF436104_reps               11                    unidentified
# SH2127282.08FU_AY762947_refs               11          Alternaria_oregonensis
# SH1554120.08FU_KU747561_reps               11                Xylaria_cubensis
# SH1541118.08FU_KR016816_reps                9                    unidentified
# SH1651389.08FU_KY782284_reps                8                    unidentified
# SH1649730.08FU_HE820818_reps                7                    unidentified
# SH1554929.08FU_JF773605_reps                7                    unidentified
# SH1546322.08FU_JF433037_refs                7         Fusarium_pseudensiforme
# SH1515312.08FU_KJ713215_reps                5                    unidentified
# SH1516349.08FU_KY242684_reps                5                    unidentified
# SH1853051.08FU_KF924559_refs_singleton      4         Conioscypha_minutispora
# SH1507266.08FU_LC177377_reps                4                    unidentified
# SH1645391.08FU_FJ415474_refs                4         Elasticomyces_elasticus
# SH1505584.08FU_MF767833_reps                3                    unidentified
# SH1546461.08FU_JF433034_refs                3            Fusarium_rectiphorum
# SH1651458.08FU_EF536346_refs                3                    unidentified
# SH1750412.08FU_KF251253_refs                3    Sphaerulina_pseudovirgaureae
# SH1687540.08FU_AB042642_refs                3             Leveillula_elaeagni
# SH1508982.08FU_AY740160_reps                2             Sporisorium_lepturi
# SH1549852.08FU_UDB024177_reps               2             Toninia_physaroides
# SH1612303.08FU_EU715613_reps                2                    unidentified
# SH1516182.08FU_FJ430752_reps                2                    unidentified
# SH1548073.08FU_FJ839626_reps                2                    unidentified
# SH1718969.08FU_AF173308_refs                2           Dissoconium_aciculare
# SH1552276.08FU_EU707897_refs                2             Dissoconium_proteae
# SH1524268.08FU_FJ820763_reps                2                    unidentified
# SH1930245.08FU_EF394855_refs                2           Dissoconium_eucalypti
# SH1548076.08FU_EU514291_refs                2                 Zasmidium_musae
# SH1711498.08FU_JF433036_refs_singleton      2          Fusarium_kurunegalense
# SH1919165.08FU_JF433041_refs                1              Fusarium_kelerajum
# SH1664303.08FU_KC584202_refs_singleton      1         Alternaria_juxtiseptata
# SH1664302.08FU_KC584224_refs_singleton      1         Alternaria_vaccariicola
# SH1664237.08FU_JN383490_refs                1               Alternaria_eureka
# SH1820842.08FU_AF444354_refs                1          Filobasidium_chernovii
# SH1652815.08FU_MF509780_reps                1             Peziza_retrocurvata
# SH1858974.08FU_JQ693639_refs                1                Alternaria_rosae
# SH1849720.08FU_JF433035_refs_singleton      1          Fusarium_haematococcum
# SH1577480.08FU_KC677913_refs                1            Zasmidium_dalbergiae
# SH1650852.08FU_HE820847_reps                1                    unidentified
# SH1645457.08FU_EF394833_reps                1     Xenomycosphaerella_elongata
# SH1505885.08FU_HQ873338_reps                1              Alternaria_molesta
# SH1505898.08FU_DQ420888_reps                1                    unidentified
# SH1526446.08FU_KC584194_reps                1          Alternaria_dianthicola
# SH1528207.08FU_AF444469_refs                1         Vishniacozyma_victoriae
# SH1546365.08FU_JF433045_refs                1              Fusarium_mahasenii
# SH1570265.08FU_DQ303009_reps                1                    unidentified
# SH1572792.08FU_EF679363_refs                1         Mycosphaerella_tassiana
# SH1575716.08FU_EF452459_reps                1               Pyrenophora_bromi
# SH1577467.08FU_JF770452_refs                1       Mycosphaerella_etlingerae
# SH1577485.08FU_EU853477_reps                1                    unidentified
# SH1577495.08FU_KX287497_reps                1               Ramularia_rubella
# SH1577503.08FU_KT328901_reps                1                    unidentified
# SH1577538.08FU_KX287556_reps                1                    unidentified
# SH1598232.08FU_HM057122_refs                1            Puccinia_striiformis
# SH1619615.08FU_FJ501296_reps                1                    unidentified
# SH1630812.08FU_KX444437_reps                1                    unidentified
# SH1631055.08FU_EU561491_reps                1                    unidentified
# SH1645444.08FU_AB277789_reps                1      Cercospora_cryptomeriicola
# SH1645454.08FU_AY646479_reps                1         Mycosphaerella_musicola
# SH2127294.08FU_FJ196308_refs                1              Alternaria_molesta
# {'s': 'Zymoseptoria_tritici'}
# {
#  "s": 0.0
# }
# barcode03
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    513                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             386                    unidentified
# SH1538821.08FU_AB035719_reps              319            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             198                    unidentified
# SH1558908.08FU_KF800655_reps              156                    unidentified
# SH1563344.08FU_AM267268_reps              156          Knoxdaviesia_cecropiae
# SH1563343.08FU_FJ430715_reps              137                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    132  Cystoagaricus_hirtosquamulosus
# SH1566136.08FU_KC992951_refs               92        Lacrymaria_subcinnamomea
# SH1560162.08FU_AY225488_reps               88               Lignincola_laevis
# SH1563342.08FU_UDB028691_reps              75                    unidentified
# SH1573885.08FU_MF594688_reps               29       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               26                    unidentified
# SH1516349.08FU_KY242684_reps                6                    unidentified
# SH1508982.08FU_AY740160_reps                1             Sporisorium_lepturi
# {'s': 'unknown'}
# {
#  "s": 0.0
# }
# barcode04
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    518                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             365                    unidentified
# SH1538821.08FU_AB035719_reps              300            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             181                    unidentified
# SH1563344.08FU_AM267268_reps              153          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              146                    unidentified
# SH1563343.08FU_FJ430715_reps              120                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    110  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps              84                    unidentified
# SH1560162.08FU_AY225488_reps               83               Lignincola_laevis
# SH1566136.08FU_KC992951_refs               73        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               39       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               18                    unidentified
# SH1523077.08FU_MH019936_reps               12                    unidentified
# SH1577464.08FU_JF700867_refs                9             Zymoseptoria_brevis
# SH1523966.08FU_HE820879_reps                8                    unidentified
# SH1554120.08FU_KU747561_reps                5                Xylaria_cubensis
# SH1577481.08FU_AF181701_reps                4          Zymoseptoria_halophila
# SH1541263.08FU_KF436104_reps                4                    unidentified
# SH1516349.08FU_KY242684_reps                4                    unidentified
# SH2127280.08FU_AF347034_refs                4           Alternaria_infectoria
# SH1541142.08FU_KR015769_reps                3                    unidentified
# SH1541118.08FU_KR016816_reps                3                    unidentified
# SH1528207.08FU_AF444469_refs                3         Vishniacozyma_victoriae
# SH1609774.08FU_AF444379_refs                3             Dioszegia_hungarica
# SH1598232.08FU_HM057122_refs                3            Puccinia_striiformis
# SH1853051.08FU_KF924559_refs_singleton      2         Conioscypha_minutispora
# SH1649730.08FU_HE820818_reps                2                    unidentified
# SH2525086.08FU_DQ222455_refs                2          Filobasidium_stepposum
# SH1577471.08FU_KC005781_refs                2           Zymoseptoria_verkleyi
# SH1508982.08FU_AY740160_reps                2             Sporisorium_lepturi
# SH1548073.08FU_FJ839626_reps                2                    unidentified
# SH1598238.08FU_GU598104_reps                1            Puccinia_striiformis
# SH2320230.08FU_EF679384_refs                1       Cladosporium_ramotenellum
# SH2320203.08FU_HM148081_refs                1        Cladosporium_delicatulum
# SH2179746.08FU_KC584242_refs                1               Alternaria_aspera
# SH1549852.08FU_UDB024177_reps               1             Toninia_physaroides
# SH1688430.08FU_KC584249_refs                1        Alternaria_subcucurbitae
# SH1552276.08FU_EU707897_refs                1             Dissoconium_proteae
# SH1554929.08FU_JF773605_reps                1                    unidentified
# SH1651458.08FU_EF536346_refs                1                    unidentified
# SH1570378.08FU_MF767825_reps                1                Candida_albicans
# SH1650089.08FU_AF444329_refs                1      Cystofilobasidium_macerans
# SH1572792.08FU_EF679363_refs                1         Mycosphaerella_tassiana
# SH1576431.08FU_JQ747672_reps                1                    unidentified
# SH1645391.08FU_FJ415474_refs                1         Elasticomyces_elasticus
# SH1613737.08FU_GQ303275_refs                1                    unidentified
# SH1612303.08FU_EU715613_reps                1                    unidentified
# SH1610809.08FU_HG936981_reps                1      Holtermanniella_takashimae
# SH1505875.08FU_EU747141_reps                1                    unidentified
# SH1598253.08FU_AY956558_reps                1            Puccinia_striiformis
# SH1598251.08FU_KM391669_reps                1            Puccinia_brachypodii
# SH1505584.08FU_MF767833_reps                1                    unidentified
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.0021853146853146855
# }
# {'s': 'Zymoseptoria_tritici'}
# {
#  "s": 0.0
# }
# barcode05
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    374                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             240                    unidentified
# SH1575705.08FU_AM887506_reps              230    Pyrenophora_tritici-repentis
# SH1538821.08FU_AB035719_reps              174            Bannoa_ogasawarensis
# SH1523966.08FU_HE820879_reps              137                    unidentified
# SH1654757.08FU_UDB014954_reps             132                    unidentified
# SH1558908.08FU_KF800655_reps              120                    unidentified
# SH1563344.08FU_AM267268_reps              117          Knoxdaviesia_cecropiae
# SH1563343.08FU_FJ430715_reps               91                    unidentified
# SH1563342.08FU_UDB028691_reps              89                    unidentified
# SH1680040.08FU_KC992945_refs_singleton     74  Cystoagaricus_hirtosquamulosus
# SH1560162.08FU_AY225488_reps               68               Lignincola_laevis
# SH1541142.08FU_KR015769_reps               64                    unidentified
# SH1566136.08FU_KC992951_refs               57        Lacrymaria_subcinnamomea
# SH1523077.08FU_MH019936_reps               25                    unidentified
# SH1549852.08FU_UDB024177_reps              22             Toninia_physaroides
# SH1573885.08FU_MF594688_reps               19       Deltopyxis_triangulispora
# SH1853051.08FU_KF924559_refs_singleton     15         Conioscypha_minutispora
# SH1651458.08FU_EF536346_refs               15                    unidentified
# SH1508982.08FU_AY740160_reps               14             Sporisorium_lepturi
# SH1515312.08FU_KJ713215_reps               12                    unidentified
# SH1651389.08FU_KY782284_reps               11                    unidentified
# SH1649730.08FU_HE820818_reps                8                    unidentified
# SH1541118.08FU_KR016816_reps                8                    unidentified
# SH1575708.08FU_KP097730_reps                6                    unidentified
# SH1575712.08FU_MF491854_reps                5                    unidentified
# SH2127280.08FU_AF347034_refs                4           Alternaria_infectoria
# SH1575717.08FU_JN943658_reps                4                Drechslera_phlei
# SH1575716.08FU_EF452459_reps                4               Pyrenophora_bromi
# SH1575714.08FU_AY004801_reps                4                 Drechslera_poae
# SH2127282.08FU_AY762947_refs                3          Alternaria_oregonensis
# SH1505584.08FU_MF767833_reps                3                    unidentified
# SH1505864.08FU_JQ693660_refs                3       Alternaria_metachromatica
# SH1541263.08FU_KF436104_reps                2                    unidentified
# SH1572792.08FU_EF679363_refs                2         Mycosphaerella_tassiana
# SH1516182.08FU_FJ430752_reps                2                    unidentified
# SH1554929.08FU_JF773605_reps                2                    unidentified
# SH1554120.08FU_KU747561_reps                2                Xylaria_cubensis
# SH1546322.08FU_JF433037_refs                2         Fusarium_pseudensiforme
# SH1526441.08FU_FJ357315_refs                1           Alternaria_planifunda
# SH2179828.08FU_JF780937_refs                1              Alternaria_simsimi
# SH1505887.08FU_KU935649_reps                1          Alternaria_botryospora
# SH1507266.08FU_LC177377_reps                1                    unidentified
# SH1820842.08FU_AF444354_refs                1          Filobasidium_chernovii
# SH1524234.08FU_KX452348_reps                1                    unidentified
# SH1711498.08FU_JF433036_refs_singleton      1          Fusarium_kurunegalense
# SH1688438.08FU_KF156010_refs                1     Paradendryphiella_arenariae
# SH1687540.08FU_AB042642_refs                1             Leveillula_elaeagni
# SH1575706.08FU_JN712471_reps                1                    unidentified
# SH1664313.08FU_AY278839_refs_singleton      1              Alternaria_caricis
# SH1526444.08FU_KY883868_reps                1                Stemphylium_loti
# SH1575711.08FU_MH399405_reps                1                    unidentified
# SH1614538.08FU_KX515525_reps                1                    unidentified
# SH1613737.08FU_GQ303275_refs                1                    unidentified
# SH1609774.08FU_AF444379_refs                1             Dioszegia_hungarica
# SH1575719.08FU_AY004784_reps                1                    unidentified
# SH1566490.08FU_KX928959_reps                1              Stemphylium_solani
# SH1573369.08FU_KX953702_reps                1                    unidentified
# SH2320230.08FU_EF679384_refs                1       Cladosporium_ramotenellum
# {'s': 'Pyrenophora_tritici-repentis'}
# {
#  "s": 0.10531135531135531
# }
# barcode06
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    510                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             393                    unidentified
# SH1538821.08FU_AB035719_reps              295            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             208                    unidentified
# SH1563344.08FU_AM267268_reps              158          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              142                    unidentified
# SH1563343.08FU_FJ430715_reps              126                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    114  Cystoagaricus_hirtosquamulosus
# SH1560162.08FU_AY225488_reps              103               Lignincola_laevis
# SH1563342.08FU_UDB028691_reps              91                    unidentified
# SH1566136.08FU_KC992951_refs               83        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               29       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               20                    unidentified
# SH1516349.08FU_KY242684_reps               10                    unidentified
# {'s': 'unknown'}
# {
#  "s": 0.0
# }
# barcode07
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    508                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             386                    unidentified
# SH1538821.08FU_AB035719_reps              306            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             200                    unidentified
# SH1563344.08FU_AM267268_reps              158          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              153                    unidentified
# SH1563343.08FU_FJ430715_reps              138                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    132  Cystoagaricus_hirtosquamulosus
# SH1560162.08FU_AY225488_reps              105               Lignincola_laevis
# SH1566136.08FU_KC992951_refs               88        Lacrymaria_subcinnamomea
# SH1563342.08FU_UDB028691_reps              64                    unidentified
# SH1573885.08FU_MF594688_reps               27       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               14                    unidentified
# SH1516349.08FU_KY242684_reps               10                    unidentified
# SH1508982.08FU_AY740160_reps                1             Sporisorium_lepturi
# {'s': 'unknown'}
# {
#  "s": 0.0
# }
# barcode08
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    525                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             367                    unidentified
# SH1538821.08FU_AB035719_reps              296            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             195                    unidentified
# SH1563344.08FU_AM267268_reps              157          Knoxdaviesia_cecropiae
# SH1563343.08FU_FJ430715_reps              136                    unidentified
# SH1558908.08FU_KF800655_reps              133                    unidentified
# SH1560162.08FU_AY225488_reps              110               Lignincola_laevis
# SH1680040.08FU_KC992945_refs_singleton    109  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps              93                    unidentified
# SH1566136.08FU_KC992951_refs               69        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               42       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               20                    unidentified
# SH1516349.08FU_KY242684_reps                9                    unidentified
# SH1598232.08FU_HM057122_refs                4            Puccinia_striiformis
# SH1651458.08FU_EF536346_refs                2                    unidentified
# SH1598253.08FU_AY956558_reps                1            Puccinia_striiformis
# SH2076848.08FU_AF444349_refs                1           Filobasidium_oeirense
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.0022036139268400176
# }
# barcode09
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    526                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             363                    unidentified
# SH1538821.08FU_AB035719_reps              324            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             203                    unidentified
# SH1563343.08FU_FJ430715_reps              137                    unidentified
# SH1563344.08FU_AM267268_reps              134          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              122                    unidentified
# SH1560162.08FU_AY225488_reps              116               Lignincola_laevis
# SH1680040.08FU_KC992945_refs_singleton    112  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps              84                    unidentified
# SH1566136.08FU_KC992951_refs               72        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               32       Deltopyxis_triangulispora
# SH1598232.08FU_HM057122_refs               15            Puccinia_striiformis
# SH1651389.08FU_KY782284_reps               13                    unidentified
# SH1516349.08FU_KY242684_reps                8                    unidentified
# SH1508982.08FU_AY740160_reps                1             Sporisorium_lepturi
# SH1651458.08FU_EF536346_refs                1                    unidentified
# SH1598238.08FU_GU598104_reps                1            Puccinia_striiformis
# SH1572792.08FU_EF679363_refs                1         Mycosphaerella_tassiana
# SH2320385.08FU_EF679383_refs_singleton      1        Cladosporium_pseudiridis
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.00706090026478376
# }
# {'s': 'Pyrenophora_tritici-repentis'}
# {
#  "s": 0.0
# }
# barcode10
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    563                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             346                    unidentified
# SH1538821.08FU_AB035719_reps              278            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             170                    unidentified
# SH1563344.08FU_AM267268_reps              158          Knoxdaviesia_cecropiae
# SH1558908.08FU_KF800655_reps              135                    unidentified
# SH1563343.08FU_FJ430715_reps              132                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    111  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps             101                    unidentified
# SH1560162.08FU_AY225488_reps               84               Lignincola_laevis
# SH1566136.08FU_KC992951_refs               80        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               25       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               21                    unidentified
# SH1516349.08FU_KY242684_reps               10                    unidentified
# SH2320203.08FU_HM148081_refs                3        Cladosporium_delicatulum
# SH1572792.08FU_EF679363_refs                3         Mycosphaerella_tassiana
# SH2320230.08FU_EF679384_refs                2       Cladosporium_ramotenellum
# SH1650089.08FU_AF444329_refs                2      Cystofilobasidium_macerans
# SH1650091.08FU_KU163965_reps                2      Cystofilobasidium_macerans
# SH1820842.08FU_AF444354_refs                1          Filobasidium_chernovii
# SH1858974.08FU_JQ693639_refs                1                Alternaria_rosae
# SH1515312.08FU_KJ713215_reps                1                    unidentified
# SH1549852.08FU_UDB024177_reps               1             Toninia_physaroides
# SH1541142.08FU_KR015769_reps                1                    unidentified
# SH1528208.08FU_KF036588_refs                1        Vishniacozyma_carnescens
# SH1523966.08FU_HE820879_reps                1                    unidentified
# SH1523077.08FU_MH019936_reps                1                    unidentified
# SH2525086.08FU_DQ222455_refs                1          Filobasidium_stepposum
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.0
# }
# {'s': 'Zymoseptoria_tritici'}
# {
#  "s": 0.0
# }
# barcode11
#                                         count                               s
# tname
# SH1732842.08FU_FJ430779_refs_singleton    506                  Acidea_extrema
# SH1649638.08FU_UDB016769_refs             381                    unidentified
# SH1538821.08FU_AB035719_reps              274            Bannoa_ogasawarensis
# SH1654757.08FU_UDB014954_reps             189                    unidentified
# SH1563344.08FU_AM267268_reps              140          Knoxdaviesia_cecropiae
# SH1563343.08FU_FJ430715_reps              138                    unidentified
# SH1558908.08FU_KF800655_reps              136                    unidentified
# SH1680040.08FU_KC992945_refs_singleton    133  Cystoagaricus_hirtosquamulosus
# SH1563342.08FU_UDB028691_reps              96                    unidentified
# SH1560162.08FU_AY225488_reps               94               Lignincola_laevis
# SH1566136.08FU_KC992951_refs               87        Lacrymaria_subcinnamomea
# SH1573885.08FU_MF594688_reps               36       Deltopyxis_triangulispora
# SH1651389.08FU_KY782284_reps               17                    unidentified
# SH1572792.08FU_EF679363_refs               17         Mycosphaerella_tassiana
# SH2320230.08FU_EF679384_refs                7       Cladosporium_ramotenellum
# SH1516349.08FU_KY242684_reps                4                    unidentified
# SH1598232.08FU_HM057122_refs                3            Puccinia_striiformis
# SH2320203.08FU_HM148081_refs                3        Cladosporium_delicatulum
# SH2320385.08FU_EF679383_refs_singleton      3        Cladosporium_pseudiridis
# SH1523077.08FU_MH019936_reps                3                    unidentified
# SH1820842.08FU_AF444354_refs                2          Filobasidium_chernovii
# SH2127280.08FU_AF347034_refs                2           Alternaria_infectoria
# SH1650852.08FU_HE820847_reps                2                    unidentified
# SH2525086.08FU_DQ222455_refs                2          Filobasidium_stepposum
# SH1609774.08FU_AF444379_refs                2             Dioszegia_hungarica
# SH1528207.08FU_AF444469_refs                2         Vishniacozyma_victoriae
# SH1572842.08FU_KU821452_reps                2        Cladosporium_tenuissimum
# SH1650091.08FU_KU163965_reps                1      Cystofilobasidium_macerans
# SH1547054.08FU_AB520459_reps                1                    unidentified
# SH1541142.08FU_KR015769_reps                1                    unidentified
# SH2320220.08FU_HM148092_refs                1      Cladosporium_flabelliforme
# SH1541263.08FU_KF436104_reps                1                    unidentified
# SH2179882.08FU_KC584233_refs                1            Alternaria_hyacinthi
# SH1744747.08FU_JN906979_refs_singleton      1        Cladosporium_arthropodii
# SH1554120.08FU_KU747561_reps                1                Xylaria_cubensis
# SH1610809.08FU_HG936981_reps                1      Holtermanniella_takashimae
# SH1559775.08FU_KM041828_reps                1                    unidentified
# SH1687540.08FU_AB042642_refs                1             Leveillula_elaeagni
# SH1505864.08FU_JQ693660_refs                1       Alternaria_metachromatica
# SH1651458.08FU_EF536346_refs                1                    unidentified
# SH1505584.08FU_MF767833_reps                1                    unidentified
# {'s': 'Zymoseptoria_tritici'}
# {
#  "s": 0.0
# }
# {'s': 'Puccinia_striiformis'}
# {
#  "s": 0.00130718954248366
# }

# %%
### list of species in the max database
max_species = ['Puccinia_striiformis',
             'Zymoseptoria_tritici',
             'Pyrenophora_tritici-repentis',
             'Fusarium_oxysporum',
             'Tuber_brumale',
             'Cortinarius_globuliformis',
             'Aspergillus_niger',
             'Clavispora_lusitaniae',
             'Kluyveromyces_unidentified',
             'Penicillium_chrysogenum',
             'Rhodotorula_mucilaginosa',
             'Scedosporium_boydii',
             'Blastobotrys_proliferans',
             'Debaryomyces_unidentified',
             'Galactomyces_geotrichum',
             'Kodamaea_ohmeri',
             'Meyerozyma_guilliermondii',
             'Wickerhamomyces_anomalus',
             'Yamadazyma_mexicana',
             'Yamadazyma_scolyti',
             'Yarrowia_lipolytica',
             'Zygoascus_hellenicus',
             'Aspergillus_flavus',
             'Cryptococcus_zero',
             'Aspergillus_unidentified',
             'Diaporthe_CCL067',
             'Diaporthe_unidentified',
             'Oculimacula_yallundae-CCL031',
             'Oculimacula_yallundae-CCL029',
             'Dothiorella_vidmadera',
             'Quambalaria_cyanescens',
             'Entoleuca_unidentified',
             'Asteroma_CCL060',
             'Asteroma_CCL068',
             'Saccharomyces_cerevisiae',
             'Cladophialophora_unidentified',
             'Candida_albicans',
             'Candida_metapsilosis',
             'Candida_orthopsilosis',
             'Candida_parapsilosis',
             'Candida_unidentified',
             'Kluyveromyces_marxianus',
             'Pichia_kudriavzevii',
             'Pichia_membranifaciens']

# %%
mock_community = ['barcode01','barcode02','barcode03','barcode04',
                 'barcode05','barcode06','barcode07','barcode08',
                 'barcode09','barcode10','barcode11']

# %%
def subsamplereads(in_fn, out_fn, n_reads):
    command = F'reformat.sh samplereadstarget={n_reads} in={in_fn} out={out_fn}'
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
n_reads = 2000

# %%
OUT_DIR = os.path.abspath('../../analysis/Mapping/wheat')
if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)
MC_READ_DIR = os.path.join(OUT_DIR, 'MC_READS')
if not os.path.exists(MC_READ_DIR):
    os.mkdir(MC_READ_DIR)
sub_db_fn = os.path.join('../../analysis/Mapping/gsref.subdb.fasta')
new_db_fn = os.path.join('../../analysis/Mapping/gsref.db.fasta')

# %%
wheat_ref_df.columns
# Out:
# Index(['Unnamed: 0', 'species1', 'species2', '# raw reads',
#        '# reads after homology filtering', '# reads after length filtering',
#        '# for use', 'path to raw reads', 'path to homology filtering',
#        'path to length filtering', 'path for use'],
#       dtype='object')

# %%
fn_subsampling = {}
for x in mock_community:
    print(x)
    fn_subsampling[x] = wheat_ref_df[wheat_ref_df['Unnamed: 0'] == x]['path for use'].tolist()[0]
    fn_subsampling[x] = os.path.join(INPUT_BASEDIR, fn_subsampling[x])
fn_subsampling
# Out:
# barcode01
# barcode02
# barcode03
# barcode04
# barcode05
# barcode06
# barcode07
# barcode08
# barcode09
# barcode10
# barcode11
# {'barcode01': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta',
#  'barcode02': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta',
#  'barcode03': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta',
#  'barcode04': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta',
#  'barcode05': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta',
#  'barcode06': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta',
#  'barcode07': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta',
#  'barcode08': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta',
#  'barcode09': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta',
#  'barcode10': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta',
#  'barcode11': '/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta'}

# %%
sub_reads_fn = {}
for key, value in fn_subsampling.items():
    print(key)
    print(value)
    species = key
    in_fn = value
    out_fn = os.path.join(MC_READ_DIR, F'{species}.{n_reads}.fasta')
    subsamplereads(in_fn, out_fn, n_reads)
    sub_reads_fn[species] = out_fn
# Out:
# barcode01
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode01/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta
#
# barcode02
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode02/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta
#
# barcode03
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode03/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.2000.fasta
#
# barcode04
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode04/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.2000.fasta
#
# barcode05
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode05/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta
#
# barcode06
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode06/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.2000.fasta
#
# barcode07
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode07/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.2000.fasta
#
# barcode08
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode08/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.2000.fasta
#
# barcode09
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode09/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.2000.fasta
#
# barcode10
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode10/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.2000.fasta
#
# barcode11
# /media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta
# :)Completed reformat.sh samplereadstarget=2000 in=/media/MassStorage/tmp/TE/honours/analysis/Length_Filtered/wheat/barcode11/length_restricted_reads.fasta out=/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.2000.fasta

# %% [markdown]
# ### Map with minimap against both databases

# %%
def minimapmapping(fasta_fn, ref_fn, out_fn, threads):
    command = F"minimap2 -x map-ont -t {threads} {ref_fn} {fasta_fn} -o {out_fn}"
    out = subprocess.getstatusoutput(command)
    if out[0] == 0:
        print(F":)Completed {command}\n")
    else:
        print(F":(check one {command}!!\n")

# %%
dbases_fn = {}
for x in [sub_db_fn, new_db_fn]:
    print(x)
    dbases_fn[x] = os.path.join(OUT_DIR, os.path.basename(x).replace('.fasta', '').replace('.','_'))
    if not os.path.exists(dbases_fn[x]):
        os.mkdir(dbases_fn[x])
dbases_fn
# Out:
# ../../analysis/Mapping/gsref.subdb.fasta
# ../../analysis/Mapping/gsref.db.fasta
# {'../../analysis/Mapping/gsref.subdb.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb',
#  '../../analysis/Mapping/gsref.db.fasta': '/media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db'}

# %%
db_fn = sub_db_fn
sub_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    sub_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode03.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode04.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode05.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode06.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode07.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode08.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode09.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode10.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.subdb.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_subdb/gsref.subdb.barcode11.minimap2.paf

# %%
db_fn = new_db_fn
new_db_mapping_fn = {}
for species, fasta_fn in sub_reads_fn.items():
    tmp_out = dbases_fn[db_fn]
    db_name = os.path.basename(db_fn).replace('.fasta', '')
    out_fn = os.path.join(tmp_out, F"{db_name}.{species}.minimap2.paf")
    new_db_mapping_fn[species] = out_fn
    minimapmapping(fasta_fn, db_fn, out_fn, threads)
# Out:
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode01.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode01.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode02.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode02.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode03.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode03.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode04.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode04.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode05.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode05.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode06.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode06.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode07.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode07.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode08.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode08.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode09.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode09.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode10.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode10.minimap2.paf
#
# :)Completed minimap2 -x map-ont -t 10 ../../analysis/Mapping/gsref.db.fasta /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/MC_READS/barcode11.2000.fasta -o /media/MassStorage/tmp/TE/honours/analysis/Mapping/wheat/gsref_db/gsref.db.barcode11.minimap2.paf

# %% [markdown]
# ### Look at mapping results

# %%
def mapping_results(fn, species,expected_species):
    min_header = ['qseqid', 'qlen', 'qstart', 'qstop', 'strand', 'tname', 'tlen', 'tstart', 'tend', 'nmatch', 'alen', 'mquality']
    tmp_df = pd.read_csv(fn, sep='\t', header = None, usecols=[x for x in range(0,12)], names=min_header)
    sub_df = tmp_df[tmp_df['mquality'] == tmp_df.groupby('qseqid')['mquality'].transform(max)].reset_index(drop=True)
    sub_df = sub_df[sub_df['nmatch'] == sub_df.groupby('qseqid')['nmatch'].transform(max)].reset_index(drop=True)
    hit_series = pd.Series(sub_df.groupby('tname')['mquality'].count().tolist()/sub_df.groupby('tname')['mquality'].count().sum(),
                      sub_df.groupby('tname')['mquality'].count().index)
    hit_series.sort_values(ascending=False, inplace=True)
    print(sub_df.qseqid.unique().shape == tmp_df.qseqid.unique().shape)
    print('##########\n')
    print(F"This was the sample type expected: {expected_species[species]}\n")
    print(F"These are the results:")
    print(hit_series,'\n')
    hit_series.to_json('/media/MassStorage/tmp/TE/honours/analysis/Mapping/custom_results/%s.json' % species)

# %%
expected_species = {'barcode01': "Puccinia striiformis-tritici",
                   'barcode02': 'Zymoseptoria tritici',
                   'barcode03': 'Healthy wheat sample',
                   'barcode04': 'Puccinia striiformis-tritici AND Zymoseptoria tritici',
                   'barcode05': 'Pyrenophora tritici-repentis',
                   'barcode06': 'Healthy resistant wheat sample',
                   'barcode07': 'Healthy susceptible wheat sample',
                   'barcode08': 'Puccinia striiformis-tritici',
                   'barcode09': 'Puccinia striiformis-tritici AND Pyrenophora tritici-repentis',
                   'barcode10': 'Puccinia striiformis-tritici AND Zymoseptoria tritici',
                   'barcode11': 'Zymoseptoria tritici AND Puccinia striiformis-tritici'}

# %%
###this is running the reads against the full database
for species, hit_fn in new_db_mapping_fn.items():
    mapping_results(hit_fn, species, expected_species)
# Out:
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.641251
# blastobotrys_proliferans         0.160313
# saccharomyces_cerevisiae         0.073314
# cortinarius_globuliformis        0.040567
# rhodotorula_mucilaginosa         0.008309
# aspergillus_flavus               0.007820
# meyerozyma_guillermondii         0.006354
# puccinia_striiformis-tritici     0.005376
# aspergillus_unidentified         0.003910
# candida_albicans                 0.003910
# candida_unidentified             0.003910
# kluyveromyces_unidentified       0.003910
# zymoseptoria_tritici             0.003910
# wickerhamomyces_anomalus         0.003910
# entoleuca_unidentified           0.003421
# candida_metapsilosis             0.003421
# quambalaria_cyanescens           0.003421
# debaryomyces_unidentified        0.002933
# pyrenophora_tritici-repentis     0.002933
# dothiorella_vidmadera            0.002444
# oculimacula_yallundae-ccl031     0.002444
# kluyveromyces_marxianus          0.001955
# penicillium_chrysogenum          0.001466
# zygoascus_hellenicus             0.000978
# pichia_kudriavzevii              0.000978
# oculimacula_yallundae-ccl029     0.000978
# cladophialophora_unidentified    0.000978
# tuber_brumale                    0.000978
# asteroma_ccl068                  0.000489
# aspergillus_niger                0.000489
# yarrowia_lipolytica              0.000489
# clavispora_lusitaniae            0.000489
# yamadazyma_scolyti               0.000489
# candida_orthopsilosis            0.000489
# candida_parapsilosis             0.000489
# fusarium_oxysporum               0.000489
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria tritici
#
# These are the results:
# tname
# zymoseptoria_tritici             0.517073
# debaryomyces_unidentified        0.122927
# cryptococcus_zero                0.108780
# cortinarius_globuliformis        0.060976
# pyrenophora_tritici-repentis     0.042439
# cladophialophora_unidentified    0.029756
# blastobotrys_proliferans         0.025366
# aspergillus_unidentified         0.024878
# quambalaria_cyanescens           0.007805
# aspergillus_flavus               0.006341
# saccharomyces_cerevisiae         0.006341
# candida_unidentified             0.005854
# meyerozyma_guillermondii         0.004390
# kluyveromyces_unidentified       0.004390
# rhodotorula_mucilaginosa         0.004390
# candida_albicans                 0.003902
# dothiorella_vidmadera            0.003902
# candida_orthopsilosis            0.002439
# penicillium_chrysogenum          0.002439
# candida_metapsilosis             0.002439
# candida_parapsilosis             0.001951
# entoleuca_unidentified           0.001951
# aspergillus_niger                0.001463
# wickerhamomyces_anomalus         0.001463
# zygoascus_hellenicus             0.000976
# kluyveromyces_marxianus          0.000976
# tuber_brumale                    0.000976
# yamadazyma_mexicana              0.000488
# pichia_membranifaciens           0.000488
# clavispora_lusitaniae            0.000488
# diaporthe_unidentified           0.000488
# oculimacula_yallundae-ccl029     0.000488
# oculimacula_yallundae-ccl031     0.000488
# scedosporium_boydii              0.000488
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Healthy wheat sample
#
# These are the results:
# tname
# cryptococcus_zero                0.342029
# candida_albicans                 0.270531
# cortinarius_globuliformis        0.135749
# blastobotrys_proliferans         0.086473
# saccharomyces_cerevisiae         0.013527
# galactomyces_geotrichum          0.013043
# aspergillus_flavus               0.013043
# meyerozyma_guillermondii         0.012560
# candida_unidentified             0.011111
# entoleuca_unidentified           0.011111
# rhodotorula_mucilaginosa         0.010145
# quambalaria_cyanescens           0.007729
# pyrenophora_tritici-repentis     0.006763
# dothiorella_vidmadera            0.005797
# diaporthe_ccl067                 0.005797
# candida_metapsilosis             0.005314
# zymoseptoria_tritici             0.005314
# wickerhamomyces_anomalus         0.003865
# zygoascus_hellenicus             0.003865
# candida_orthopsilosis            0.003865
# kluyveromyces_unidentified       0.003382
# candida_parapsilosis             0.003382
# aspergillus_unidentified         0.002899
# aspergillus_niger                0.002415
# yarrowia_lipolytica              0.002415
# clavispora_lusitaniae            0.002415
# oculimacula_yallundae-ccl029     0.002415
# kluyveromyces_marxianus          0.001932
# debaryomyces_unidentified        0.001932
# oculimacula_yallundae-ccl031     0.001932
# cladophialophora_unidentified    0.001449
# pichia_membranifaciens           0.000966
# penicillium_chrysogenum          0.000966
# puccinia_striiformis-tritici     0.000966
# yamadazyma_scolyti               0.000966
# tuber_brumale                    0.000966
# yamadazyma_mexicana              0.000483
# fusarium_oxysporum               0.000483
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Zymoseptoria tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.326035
# cortinarius_globuliformis        0.200857
# candida_metapsilosis             0.087577
# zymoseptoria_tritici             0.060447
# blastobotrys_proliferans         0.050452
# kodamaea_ohmeri                  0.040933
# quambalaria_cyanescens           0.020466
# saccharomyces_cerevisiae         0.018563
# pyrenophora_tritici-repentis     0.016659
# rhodotorula_mucilaginosa         0.016183
# wickerhamomyces_anomalus         0.015707
# candida_albicans                 0.014755
# meyerozyma_guillermondii         0.010471
# diaporthe_unidentified           0.010471
# aspergillus_flavus               0.009519
# candida_parapsilosis             0.009043
# entoleuca_unidentified           0.009043
# candida_unidentified             0.008091
# cladophialophora_unidentified    0.007615
# yamadazyma_scolyti               0.006663
# aspergillus_unidentified         0.006663
# dothiorella_vidmadera            0.006663
# debaryomyces_unidentified        0.006188
# puccinia_striiformis-tritici     0.006188
# kluyveromyces_unidentified       0.006188
# kluyveromyces_marxianus          0.004760
# oculimacula_yallundae-ccl029     0.003808
# candida_orthopsilosis            0.003332
# aspergillus_niger                0.002380
# zygoascus_hellenicus             0.002380
# penicillium_chrysogenum          0.001904
# yarrowia_lipolytica              0.001428
# galactomyces_geotrichum          0.001428
# oculimacula_yallundae-ccl031     0.001428
# fusarium_oxysporum               0.001428
# yamadazyma_mexicana              0.000952
# clavispora_lusitaniae            0.000952
# asteroma_ccl068                  0.000952
# tuber_brumale                    0.000952
# pichia_kudriavzevii              0.000476
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pyrenophora tritici-repentis
#
# These are the results:
# tname
# pyrenophora_tritici-repentis     0.365292
# cryptococcus_zero                0.191755
# meyerozyma_guillermondii         0.112656
# cortinarius_globuliformis        0.080537
# candida_orthopsilosis            0.044104
# blastobotrys_proliferans         0.039310
# oculimacula_yallundae-ccl031     0.030201
# candida_unidentified             0.013423
# tuber_brumale                    0.012464
# quambalaria_cyanescens           0.011505
# saccharomyces_cerevisiae         0.011505
# candida_albicans                 0.009108
# aspergillus_flavus               0.007191
# dothiorella_vidmadera            0.006711
# rhodotorula_mucilaginosa         0.006232
# kluyveromyces_unidentified       0.006232
# wickerhamomyces_anomalus         0.005753
# entoleuca_unidentified           0.004794
# candida_metapsilosis             0.004794
# zymoseptoria_tritici             0.004794
# yamadazyma_scolyti               0.003835
# aspergillus_unidentified         0.003835
# kluyveromyces_marxianus          0.003356
# cladophialophora_unidentified    0.003356
# debaryomyces_unidentified        0.002876
# oculimacula_yallundae-ccl029     0.002876
# aspergillus_niger                0.002876
# candida_parapsilosis             0.001918
# galactomyces_geotrichum          0.001918
# yamadazyma_mexicana              0.001438
# pichia_kudriavzevii              0.000959
# zygoascus_hellenicus             0.000479
# clavispora_lusitaniae            0.000479
# penicillium_chrysogenum          0.000479
# yarrowia_lipolytica              0.000479
# asteroma_ccl060                  0.000479
# dtype: float64
# True
# ##########
#
# This was the sample type expected: Healthy resistant wheat sample
#
# These are the results:
# tname
# cortinarius_globuliformis        0.550556
# cryptococcus_zero                0.172714
# wickerhamomyces_anomalus         0.106434
# candida_parapsilosis             0.046928
# blastobotrys_proliferans         0.023706
# saccharomyces_cerevisiae         0.013546
# aspergillus_flavus               0.007741
# quambalaria_cyanescens           0.007257
# oculimacula_yallundae-ccl029     0.006773
# meyerozyma_guillermondii         0.005806
# debaryomyces_unidentified        0.005806
# candida_unidentified             0.004838
# dothiorella_vidmadera            0.004838
# entoleuca_unidentified           0.004354
# rhodotorula_mucilaginosa         0.004354
# candida_albicans                 0.003870
# zymoseptoria_tritici             0.003870
# kluyveromyces_unidentified       0.003387
# aspergillus_unidentified         0.003387
# cladophialophora_unidentified    0.002903
# kluyveromyces_marxianus          0.002419
# yamadazyma_scolyti               0.002419
# candida_metapsilosis             0.002419
# penicillium_chrysogenum          0.001935
# aspergillus_niger                0.001451
# yarrowia_lipolytica              0.000968
# zygoascus_hellenicus             0.000968
# galactomyces_geotrichum          0.000484
# yamadazyma_mexicana              0.000484
# clavispora_lusitaniae            0.000484
# tuber_brumale                    0.000484
# oculimacula_yallundae-ccl031     0.000484
# kodamaea_ohmeri                  0.000484
# diaporthe_ccl067                 0.000484
# diaporthe_unidentified           0.000484
# fusarium_oxysporum               0.000484
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Healthy susceptible wheat sample
#
# These are the results:
# tname
# cryptococcus_zero                0.334871
# cortinarius_globuliformis        0.141144
# dothiorella_vidmadera            0.087638
# blastobotrys_proliferans         0.074723
# yamadazyma_mexicana              0.063192
# meyerozyma_guillermondii         0.032288
# saccharomyces_cerevisiae         0.031827
# candida_unidentified             0.029059
# aspergillus_niger                0.027214
# rhodotorula_mucilaginosa         0.023985
# quambalaria_cyanescens           0.021218
# candida_albicans                 0.016605
# aspergillus_flavus               0.013376
# candida_orthopsilosis            0.011070
# kluyveromyces_unidentified       0.010609
# wickerhamomyces_anomalus         0.009225
# candida_metapsilosis             0.008303
# entoleuca_unidentified           0.008303
# kluyveromyces_marxianus          0.007380
# zygoascus_hellenicus             0.005996
# debaryomyces_unidentified        0.005535
# yamadazyma_scolyti               0.005074
# oculimacula_yallundae-ccl031     0.004613
# candida_parapsilosis             0.004613
# zymoseptoria_tritici             0.003690
# oculimacula_yallundae-ccl029     0.003229
# cladophialophora_unidentified    0.002306
# pichia_kudriavzevii              0.002306
# aspergillus_unidentified         0.002306
# clavispora_lusitaniae            0.001845
# asteroma_ccl068                  0.001845
# fusarium_oxysporum               0.001384
# tuber_brumale                    0.001384
# puccinia_striiformis-tritici     0.000923
# diaporthe_unidentified           0.000461
# yarrowia_lipolytica              0.000461
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.259155
# cortinarius_globuliformis        0.169484
# quambalaria_cyanescens           0.167136
# yamadazyma_scolyti               0.108451
# blastobotrys_proliferans         0.052582
# saccharomyces_cerevisiae         0.023005
# clavispora_lusitaniae            0.023005
# meyerozyma_guillermondii         0.021127
# candida_unidentified             0.017840
# wickerhamomyces_anomalus         0.015493
# entoleuca_unidentified           0.013615
# candida_metapsilosis             0.012676
# dothiorella_vidmadera            0.010798
# debaryomyces_unidentified        0.009859
# rhodotorula_mucilaginosa         0.009859
# candida_orthopsilosis            0.009390
# puccinia_striiformis-tritici     0.007512
# candida_albicans                 0.007512
# kluyveromyces_unidentified       0.007042
# candida_parapsilosis             0.006573
# aspergillus_flavus               0.006573
# zymoseptoria_tritici             0.005164
# oculimacula_yallundae-ccl029     0.004695
# kluyveromyces_marxianus          0.004225
# aspergillus_niger                0.004225
# oculimacula_yallundae-ccl031     0.004225
# aspergillus_unidentified         0.003756
# cladophialophora_unidentified    0.002817
# zygoascus_hellenicus             0.002347
# kodamaea_ohmeri                  0.001408
# pyrenophora_tritici-repentis     0.001408
# yarrowia_lipolytica              0.001408
# yamadazyma_mexicana              0.000939
# penicillium_chrysogenum          0.000939
# asteroma_ccl060                  0.000939
# fusarium_oxysporum               0.000469
# tuber_brumale                    0.000469
# pichia_membranifaciens           0.000469
# diaporthe_ccl067                 0.000469
# diaporthe_unidentified           0.000469
# pichia_kudriavzevii              0.000469
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Pyrenophora tritici-repentis
#
# These are the results:
# tname
# cryptococcus_zero                0.349318
# candida_unidentified             0.167842
# cortinarius_globuliformis        0.126939
# kluyveromyces_unidentified       0.105313
# blastobotrys_proliferans         0.061119
# meyerozyma_guillermondii         0.021157
# saccharomyces_cerevisiae         0.017866
# aspergillus_flavus               0.014575
# quambalaria_cyanescens           0.012694
# rhodotorula_mucilaginosa         0.012224
# dothiorella_vidmadera            0.011283
# entoleuca_unidentified           0.010813
# puccinia_striiformis-tritici     0.009403
# candida_albicans                 0.007992
# candida_orthopsilosis            0.006112
# debaryomyces_unidentified        0.006112
# wickerhamomyces_anomalus         0.006112
# yarrowia_lipolytica              0.006112
# oculimacula_yallundae-ccl031     0.005642
# candida_metapsilosis             0.005172
# candida_parapsilosis             0.003761
# kluyveromyces_marxianus          0.003761
# yamadazyma_scolyti               0.003291
# clavispora_lusitaniae            0.002821
# cladophialophora_unidentified    0.002821
# oculimacula_yallundae-ccl029     0.002821
# aspergillus_niger                0.002821
# zymoseptoria_tritici             0.002821
# yamadazyma_mexicana              0.002351
# zygoascus_hellenicus             0.001881
# penicillium_chrysogenum          0.001881
# pichia_kudriavzevii              0.001410
# kodamaea_ohmeri                  0.000940
# tuber_brumale                    0.000940
# aspergillus_unidentified         0.000940
# diaporthe_unidentified           0.000470
# asteroma_ccl060                  0.000470
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Zymoseptoria tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.368396
# cortinarius_globuliformis        0.181818
# kluyveromyces_marxianus          0.134698
# blastobotrys_proliferans         0.084246
# penicillium_chrysogenum          0.038553
# saccharomyces_cerevisiae         0.029510
# zymoseptoria_tritici             0.014755
# rhodotorula_mucilaginosa         0.014755
# wickerhamomyces_anomalus         0.013803
# entoleuca_unidentified           0.012375
# meyerozyma_guillermondii         0.012375
# aspergillus_flavus               0.011899
# quambalaria_cyanescens           0.010471
# candida_albicans                 0.009519
# candida_unidentified             0.008091
# debaryomyces_unidentified        0.005712
# dothiorella_vidmadera            0.005236
# candida_parapsilosis             0.005236
# kluyveromyces_unidentified       0.004760
# candida_orthopsilosis            0.004284
# oculimacula_yallundae-ccl031     0.003808
# yamadazyma_mexicana              0.003332
# cladophialophora_unidentified    0.003332
# tuber_brumale                    0.002380
# candida_metapsilosis             0.002380
# yamadazyma_scolyti               0.002380
# oculimacula_yallundae-ccl029     0.001904
# aspergillus_unidentified         0.001428
# pyrenophora_tritici-repentis     0.001428
# aspergillus_niger                0.000952
# galactomyces_geotrichum          0.000952
# clavispora_lusitaniae            0.000952
# diaporthe_ccl067                 0.000952
# zygoascus_hellenicus             0.000952
# puccinia_striiformis-tritici     0.000476
# yarrowia_lipolytica              0.000476
# asteroma_ccl068                  0.000476
# asteroma_ccl060                  0.000476
# pichia_kudriavzevii              0.000476
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria tritici AND Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.332065
# rhodotorula_mucilaginosa         0.162702
# cortinarius_globuliformis        0.136061
# blastobotrys_proliferans         0.064225
# zygoascus_hellenicus             0.056613
# zymoseptoria_tritici             0.026166
# saccharomyces_cerevisiae         0.026166
# pichia_kudriavzevii              0.022360
# aspergillus_flavus               0.018554
# meyerozyma_guillermondii         0.014748
# candida_unidentified             0.014748
# candida_albicans                 0.013796
# dothiorella_vidmadera            0.012369
# wickerhamomyces_anomalus         0.009515
# asteroma_ccl060                  0.008088
# quambalaria_cyanescens           0.008088
# debaryomyces_unidentified        0.007136
# candida_parapsilosis             0.005709
# candida_metapsilosis             0.005709
# kluyveromyces_unidentified       0.005233
# kluyveromyces_marxianus          0.005233
# candida_orthopsilosis            0.004282
# entoleuca_unidentified           0.004282
# yamadazyma_mexicana              0.004282
# yamadazyma_scolyti               0.003806
# pyrenophora_tritici-repentis     0.003330
# tuber_brumale                    0.003330
# aspergillus_niger                0.002854
# puccinia_striiformis-tritici     0.002854
# oculimacula_yallundae-ccl031     0.002379
# aspergillus_unidentified         0.002379
# yarrowia_lipolytica              0.001903
# penicillium_chrysogenum          0.001903
# oculimacula_yallundae-ccl029     0.001427
# diaporthe_unidentified           0.000951
# cladophialophora_unidentified    0.000951
# diaporthe_ccl067                 0.000951
# kodamaea_ohmeri                  0.000951
# asteroma_ccl068                  0.000476
# fusarium_oxysporum               0.000476
# pichia_membranifaciens           0.000476
# galactomyces_geotrichum          0.000476
# dtype: float64

# %%
###this is running against a database that have ['Candida_orthopsilosis', 'Candida_metapsilosis', 'Aspergillus_niger'] deleted
for species, hit_fn in sub_db_mapping_fn.items():
    mapping_results(hit_fn, species, expected_species)
# Out:
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.640039
# blastobotrys_proliferans         0.159766
# saccharomyces_cerevisiae         0.073551
# cortinarius_globuliformis        0.041403
# rhodotorula_mucilaginosa         0.008281
# aspergillus_flavus               0.007793
# meyerozyma_guillermondii         0.006819
# puccinia_striiformis-tritici     0.005358
# kluyveromyces_unidentified       0.005358
# candida_albicans                 0.004384
# candida_unidentified             0.004384
# wickerhamomyces_anomalus         0.004384
# zymoseptoria_tritici             0.003897
# aspergillus_unidentified         0.003897
# quambalaria_cyanescens           0.003897
# entoleuca_unidentified           0.003897
# kluyveromyces_marxianus          0.003410
# pyrenophora_tritici-repentis     0.002923
# debaryomyces_unidentified        0.002923
# dothiorella_vidmadera            0.002435
# oculimacula_yallundae-ccl031     0.002435
# penicillium_chrysogenum          0.001461
# zygoascus_hellenicus             0.000974
# tuber_brumale                    0.000974
# cladophialophora_unidentified    0.000974
# pichia_kudriavzevii              0.000974
# fusarium_oxysporum               0.000487
# oculimacula_yallundae-ccl029     0.000487
# yamadazyma_scolyti               0.000487
# clavispora_lusitaniae            0.000487
# candida_parapsilosis             0.000487
# yarrowia_lipolytica              0.000487
# asteroma_ccl068                  0.000487
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria tritici
#
# These are the results:
# tname
# zymoseptoria_tritici             0.519080
# debaryomyces_unidentified        0.124266
# cryptococcus_zero                0.109100
# cortinarius_globuliformis        0.061155
# pyrenophora_tritici-repentis     0.042564
# cladophialophora_unidentified    0.029843
# blastobotrys_proliferans         0.025440
# aspergillus_unidentified         0.024951
# quambalaria_cyanescens           0.008317
# aspergillus_flavus               0.006360
# saccharomyces_cerevisiae         0.006360
# candida_unidentified             0.005382
# rhodotorula_mucilaginosa         0.004403
# dothiorella_vidmadera            0.004403
# meyerozyma_guillermondii         0.004403
# candida_albicans                 0.003914
# kluyveromyces_unidentified       0.003914
# candida_parapsilosis             0.003425
# penicillium_chrysogenum          0.002446
# entoleuca_unidentified           0.001957
# wickerhamomyces_anomalus         0.001957
# kluyveromyces_marxianus          0.000978
# zygoascus_hellenicus             0.000978
# tuber_brumale                    0.000978
# diaporthe_unidentified           0.000489
# scedosporium_boydii              0.000489
# clavispora_lusitaniae            0.000489
# oculimacula_yallundae-ccl029     0.000489
# oculimacula_yallundae-ccl031     0.000489
# yamadazyma_mexicana              0.000489
# pichia_membranifaciens           0.000489
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Healthy wheat sample
#
# These are the results:
# tname
# cryptococcus_zero                0.344509
# candida_albicans                 0.275024
# cortinarius_globuliformis        0.137026
# blastobotrys_proliferans         0.087949
# saccharomyces_cerevisiae         0.014091
# galactomyces_geotrichum          0.014091
# aspergillus_flavus               0.013120
# meyerozyma_guillermondii         0.013120
# candida_unidentified             0.011176
# entoleuca_unidentified           0.011176
# rhodotorula_mucilaginosa         0.010204
# quambalaria_cyanescens           0.008260
# pyrenophora_tritici-repentis     0.006803
# diaporthe_ccl067                 0.005831
# dothiorella_vidmadera            0.005831
# zymoseptoria_tritici             0.005345
# zygoascus_hellenicus             0.003887
# wickerhamomyces_anomalus         0.003887
# kluyveromyces_unidentified       0.003401
# candida_parapsilosis             0.003401
# aspergillus_unidentified         0.002915
# oculimacula_yallundae-ccl029     0.002430
# debaryomyces_unidentified        0.001944
# oculimacula_yallundae-ccl031     0.001944
# yarrowia_lipolytica              0.001944
# kluyveromyces_marxianus          0.001944
# clavispora_lusitaniae            0.001458
# cladophialophora_unidentified    0.001458
# pichia_membranifaciens           0.000972
# puccinia_striiformis-tritici     0.000972
# penicillium_chrysogenum          0.000972
# yamadazyma_scolyti               0.000972
# tuber_brumale                    0.000972
# fusarium_oxysporum               0.000486
# yamadazyma_mexicana              0.000486
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Zymoseptoria tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.339934
# cortinarius_globuliformis        0.214993
# kodamaea_ohmeri                  0.062706
# zymoseptoria_tritici             0.060349
# blastobotrys_proliferans         0.052334
# candida_albicans                 0.021216
# quambalaria_cyanescens           0.021216
# saccharomyces_cerevisiae         0.020273
# wickerhamomyces_anomalus         0.019331
# rhodotorula_mucilaginosa         0.017445
# pyrenophora_tritici-repentis     0.016502
# candida_parapsilosis             0.014144
# diaporthe_unidentified           0.013201
# entoleuca_unidentified           0.012258
# candida_unidentified             0.011787
# meyerozyma_guillermondii         0.010844
# aspergillus_flavus               0.009901
# debaryomyces_unidentified        0.009430
# kluyveromyces_unidentified       0.008487
# yamadazyma_scolyti               0.008015
# aspergillus_unidentified         0.007544
# cladophialophora_unidentified    0.007544
# dothiorella_vidmadera            0.007544
# kluyveromyces_marxianus          0.006601
# puccinia_striiformis-tritici     0.006129
# oculimacula_yallundae-ccl029     0.003772
# zygoascus_hellenicus             0.002829
# penicillium_chrysogenum          0.001886
# yamadazyma_mexicana              0.001886
# clavispora_lusitaniae            0.001414
# oculimacula_yallundae-ccl031     0.001414
# tuber_brumale                    0.001414
# fusarium_oxysporum               0.001414
# yarrowia_lipolytica              0.001414
# galactomyces_geotrichum          0.001414
# asteroma_ccl068                  0.000943
# pichia_kudriavzevii              0.000471
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Pyrenophora tritici-repentis
#
# These are the results:
# tname
# pyrenophora_tritici-repentis     0.364768
# cryptococcus_zero                0.198181
# meyerozyma_guillermondii         0.130206
# cortinarius_globuliformis        0.083772
# blastobotrys_proliferans         0.040689
# oculimacula_yallundae-ccl031     0.033030
# candida_unidentified             0.015318
# tuber_brumale                    0.012925
# quambalaria_cyanescens           0.012925
# candida_albicans                 0.012446
# saccharomyces_cerevisiae         0.011967
# kluyveromyces_unidentified       0.008138
# aspergillus_flavus               0.007180
# wickerhamomyces_anomalus         0.006702
# rhodotorula_mucilaginosa         0.006702
# dothiorella_vidmadera            0.006702
# kluyveromyces_marxianus          0.005744
# zymoseptoria_tritici             0.005744
# entoleuca_unidentified           0.004787
# yamadazyma_scolyti               0.004787
# candida_parapsilosis             0.004308
# aspergillus_unidentified         0.004308
# oculimacula_yallundae-ccl029     0.003830
# cladophialophora_unidentified    0.003830
# debaryomyces_unidentified        0.003351
# galactomyces_geotrichum          0.001915
# yamadazyma_mexicana              0.001915
# pichia_kudriavzevii              0.000957
# yarrowia_lipolytica              0.000957
# zygoascus_hellenicus             0.000479
# clavispora_lusitaniae            0.000479
# asteroma_ccl060                  0.000479
# penicillium_chrysogenum          0.000479
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Healthy resistant wheat sample
#
# These are the results:
# tname
# cortinarius_globuliformis        0.550024
# cryptococcus_zero                0.172547
# wickerhamomyces_anomalus         0.106815
# candida_parapsilosis             0.046883
# blastobotrys_proliferans         0.024166
# saccharomyces_cerevisiae         0.013533
# aspergillus_flavus               0.008217
# oculimacula_yallundae-ccl029     0.007733
# quambalaria_cyanescens           0.007250
# meyerozyma_guillermondii         0.005800
# debaryomyces_unidentified        0.005800
# candida_unidentified             0.005317
# dothiorella_vidmadera            0.004833
# entoleuca_unidentified           0.004350
# candida_albicans                 0.004350
# rhodotorula_mucilaginosa         0.004350
# zymoseptoria_tritici             0.003867
# cladophialophora_unidentified    0.003383
# kluyveromyces_unidentified       0.003383
# aspergillus_unidentified         0.003383
# yamadazyma_scolyti               0.002900
# kluyveromyces_marxianus          0.002417
# penicillium_chrysogenum          0.001933
# yarrowia_lipolytica              0.000967
# yamadazyma_mexicana              0.000967
# zygoascus_hellenicus             0.000967
# clavispora_lusitaniae            0.000483
# fusarium_oxysporum               0.000483
# tuber_brumale                    0.000483
# oculimacula_yallundae-ccl031     0.000483
# kodamaea_ohmeri                  0.000483
# diaporthe_ccl067                 0.000483
# diaporthe_unidentified           0.000483
# galactomyces_geotrichum          0.000483
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Healthy susceptible wheat sample
#
# These are the results:
# tname
# cryptococcus_zero                0.340720
# cortinarius_globuliformis        0.142659
# dothiorella_vidmadera            0.093259
# blastobotrys_proliferans         0.076177
# yamadazyma_mexicana              0.072484
# candida_unidentified             0.034164
# meyerozyma_guillermondii         0.033703
# saccharomyces_cerevisiae         0.033241
# rhodotorula_mucilaginosa         0.024469
# quambalaria_cyanescens           0.022622
# candida_albicans                 0.020776
# aspergillus_flavus               0.015235
# kluyveromyces_unidentified       0.011080
# wickerhamomyces_anomalus         0.010619
# entoleuca_unidentified           0.009234
# zygoascus_hellenicus             0.006464
# kluyveromyces_marxianus          0.006464
# candida_parapsilosis             0.005540
# oculimacula_yallundae-ccl031     0.005540
# yamadazyma_scolyti               0.005078
# debaryomyces_unidentified        0.005078
# aspergillus_unidentified         0.004155
# zymoseptoria_tritici             0.003693
# oculimacula_yallundae-ccl029     0.003232
# pichia_kudriavzevii              0.002770
# cladophialophora_unidentified    0.002308
# asteroma_ccl068                  0.001847
# clavispora_lusitaniae            0.001847
# fusarium_oxysporum               0.001385
# tuber_brumale                    0.001385
# puccinia_striiformis-tritici     0.000923
# penicillium_chrysogenum          0.000923
# diaporthe_unidentified           0.000462
# yarrowia_lipolytica              0.000462
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.263059
# cortinarius_globuliformis        0.174118
# quambalaria_cyanescens           0.168471
# yamadazyma_scolyti               0.108706
# blastobotrys_proliferans         0.051294
# saccharomyces_cerevisiae         0.025882
# clavispora_lusitaniae            0.023059
# meyerozyma_guillermondii         0.022118
# candida_unidentified             0.020706
# wickerhamomyces_anomalus         0.016000
# entoleuca_unidentified           0.014588
# dothiorella_vidmadera            0.011765
# debaryomyces_unidentified        0.010353
# rhodotorula_mucilaginosa         0.009882
# candida_parapsilosis             0.009882
# candida_albicans                 0.008000
# kluyveromyces_unidentified       0.008000
# aspergillus_flavus               0.007529
# puccinia_striiformis-tritici     0.007529
# zymoseptoria_tritici             0.005647
# kluyveromyces_marxianus          0.004235
# aspergillus_unidentified         0.004235
# oculimacula_yallundae-ccl029     0.004235
# oculimacula_yallundae-ccl031     0.004235
# cladophialophora_unidentified    0.003294
# zygoascus_hellenicus             0.002353
# yarrowia_lipolytica              0.001412
# yamadazyma_mexicana              0.001412
# pyrenophora_tritici-repentis     0.001412
# kodamaea_ohmeri                  0.001412
# penicillium_chrysogenum          0.001412
# asteroma_ccl060                  0.000941
# pichia_kudriavzevii              0.000471
# tuber_brumale                    0.000471
# diaporthe_ccl067                 0.000471
# diaporthe_unidentified           0.000471
# fusarium_oxysporum               0.000471
# pichia_membranifaciens           0.000471
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Pyrenophora tritici-repentis
#
# These are the results:
# tname
# cryptococcus_zero                0.351633
# candida_unidentified             0.170847
# cortinarius_globuliformis        0.129200
# kluyveromyces_unidentified       0.107430
# blastobotrys_proliferans         0.060104
# meyerozyma_guillermondii         0.021770
# saccharomyces_cerevisiae         0.018457
# aspergillus_flavus               0.016091
# quambalaria_cyanescens           0.012778
# rhodotorula_mucilaginosa         0.012305
# dothiorella_vidmadera            0.011832
# entoleuca_unidentified           0.010885
# puccinia_striiformis-tritici     0.009465
# candida_albicans                 0.008992
# wickerhamomyces_anomalus         0.006626
# yarrowia_lipolytica              0.006152
# oculimacula_yallundae-ccl031     0.006152
# debaryomyces_unidentified        0.006152
# kluyveromyces_marxianus          0.004259
# candida_parapsilosis             0.003313
# yamadazyma_scolyti               0.003313
# cladophialophora_unidentified    0.002840
# clavispora_lusitaniae            0.002840
# zymoseptoria_tritici             0.002840
# oculimacula_yallundae-ccl029     0.002840
# yamadazyma_mexicana              0.002366
# zygoascus_hellenicus             0.001893
# penicillium_chrysogenum          0.001420
# pichia_kudriavzevii              0.001420
# kodamaea_ohmeri                  0.000947
# tuber_brumale                    0.000947
# aspergillus_unidentified         0.000947
# asteroma_ccl060                  0.000473
# diaporthe_unidentified           0.000473
# dtype: float64
# True
# ##########
#
# This was the sample type expected: Puccinia striiformis-tritici AND Zymoseptoria tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.369928
# cortinarius_globuliformis        0.182816
# kluyveromyces_marxianus          0.136993
# blastobotrys_proliferans         0.084010
# penicillium_chrysogenum          0.038663
# saccharomyces_cerevisiae         0.030072
# rhodotorula_mucilaginosa         0.015274
# zymoseptoria_tritici             0.014797
# wickerhamomyces_anomalus         0.014320
# meyerozyma_guillermondii         0.012888
# entoleuca_unidentified           0.011933
# aspergillus_flavus               0.011933
# quambalaria_cyanescens           0.010501
# candida_albicans                 0.010501
# candida_unidentified             0.007160
# debaryomyces_unidentified        0.006205
# candida_parapsilosis             0.006205
# dothiorella_vidmadera            0.004773
# kluyveromyces_unidentified       0.004773
# oculimacula_yallundae-ccl031     0.003819
# cladophialophora_unidentified    0.003341
# tuber_brumale                    0.002864
# yamadazyma_mexicana              0.002864
# yamadazyma_scolyti               0.002387
# oculimacula_yallundae-ccl029     0.001909
# pyrenophora_tritici-repentis     0.001432
# galactomyces_geotrichum          0.000955
# aspergillus_unidentified         0.000955
# zygoascus_hellenicus             0.000955
# clavispora_lusitaniae            0.000955
# diaporthe_ccl067                 0.000955
# pichia_kudriavzevii              0.000477
# puccinia_striiformis-tritici     0.000477
# yarrowia_lipolytica              0.000477
# asteroma_ccl068                  0.000477
# asteroma_ccl060                  0.000477
# pichia_membranifaciens           0.000477
# dtype: float64
#
# True
# ##########
#
# This was the sample type expected: Zymoseptoria tritici AND Puccinia striiformis-tritici
#
# These are the results:
# tname
# cryptococcus_zero                0.334597
# rhodotorula_mucilaginosa         0.163033
# cortinarius_globuliformis        0.136967
# blastobotrys_proliferans         0.063981
# zygoascus_hellenicus             0.056398
# saccharomyces_cerevisiae         0.027488
# zymoseptoria_tritici             0.026540
# pichia_kudriavzevii              0.022275
# aspergillus_flavus               0.018483
# meyerozyma_guillermondii         0.015640
# candida_unidentified             0.015640
# candida_albicans                 0.014692
# dothiorella_vidmadera            0.012796
# wickerhamomyces_anomalus         0.009953
# asteroma_ccl060                  0.008531
# debaryomyces_unidentified        0.008531
# quambalaria_cyanescens           0.008057
# kluyveromyces_unidentified       0.006635
# candida_parapsilosis             0.006161
# kluyveromyces_marxianus          0.005687
# entoleuca_unidentified           0.004739
# yamadazyma_mexicana              0.004265
# yamadazyma_scolyti               0.003791
# pyrenophora_tritici-repentis     0.003318
# tuber_brumale                    0.002844
# aspergillus_unidentified         0.002844
# puccinia_striiformis-tritici     0.002844
# oculimacula_yallundae-ccl031     0.002370
# penicillium_chrysogenum          0.001896
# yarrowia_lipolytica              0.001896
# oculimacula_yallundae-ccl029     0.001422
# cladophialophora_unidentified    0.000948
# kodamaea_ohmeri                  0.000948
# diaporthe_ccl067                 0.000948
# diaporthe_unidentified           0.000948
# galactomyces_geotrichum          0.000474
# pichia_membranifaciens           0.000474
# asteroma_ccl068                  0.000474
# fusarium_oxysporum               0.000474
# dtype: float64
